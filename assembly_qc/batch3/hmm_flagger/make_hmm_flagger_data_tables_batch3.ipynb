# %%
import numpy as np
import pandas as pd
import sys
import os
import re
BASE_DIR="/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc"

# %% [markdown]
# ### This notebook:
#
# #### Create HiFi and ONT table for batch3 data (06 March 2025)
#
# Now we should have all ONT/HiFi sequencing data fully wrangled and also censat annotations created for all assemblies. These are the links to the related tables:
# * Assembly: https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/assemblies_pre_release_v0.6.1.index.csv
# * censat: https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/annotation/censat/censat_pre_release_v0.3.index.csv
# * ONT: https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/sequencing_data/data_ont_pre_release.index.csv
# * HiFi: https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/sequencing_data/data_hifi_pre_release.index.csv
# * HiFi(DeepConsensus): https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/sequencing_data/data_deepconsensus_pre_release.index.csv
#
# Steps for this notebook:
# * Download pre-release tables
# * Get the list of samples included in the previous batches (batch1, batch1_jan_12_2025, batch2). This will be done  for HiFi and ONT separately. The csv files created for `rerun_march_01_2025` will be used for listing those samples. They were created to rerun HMM-Flagger but with version v1.2 using all the mappings created for the batches mentioned earlier:
#     * HiFi:
#         * `rerun_march_01_2025/hmm_flagger/hifi/hmm_flagger_hifi_data_table.csv`
#     * ONT
#         * `rerun_march_01_2025/hmm_flagger/ont/hmm_flagger_ont_data_table.csv`
# * Find which samples have censat annotation but were missed in the previous batches (either because of not having read data or censat annotation)
# * Get ONT and HiFi reads for those samples
# * Download the censat annotations and make diploid bed files
# * Makes separate data tables for HiFi and ONT runs (both will contain diploid censat bed files)
# * Saves the final data tables in `hifi/` and `ont/` subdirectories and they will be used for creating input json files

# %% [markdown]
# ### Download and parse pre-release tables

# %%
#!wget https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/annotation/censat/censat_pre_release_v0.3.index.csv
#!wget https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/sequencing_data/data_ont_pre_release.index.csv
#!wget https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/sequencing_data/data_hifi_pre_release.index.csv
#!wget https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/assemblies_pre_release_v0.6.1.index.csv
#!wget https://raw.githubusercontent.com/human-pangenomics/hprc_intermediate_assembly/refs/heads/main/data_tables/sequencing_data/data_deepconsensus_pre_release.index.csv

# %%
# !ls
# Out:
# assemblies_pre_release_v0.6.1.index.csv
# censat_pre_release_v0.3.index.csv
# data_deepconsensus_pre_release.index.csv
# data_hifi_pre_release.index.csv
# data_ont_pre_release.index.csv
# diploid_censat_beds
# hifi
# make_hmm_flagger_data_tables_batch3.ipynb
# ont

# %%
assembly_pre_release = pd.read_csv("assemblies_pre_release_v0.6.1.index.csv")
censat_pre_release = pd.read_csv("censat_pre_release_v0.3.index.csv")
data_ont_pre_release = pd.read_csv("data_ont_pre_release.index.csv")
data_hifi_pre_release = pd.read_csv("data_hifi_pre_release.index.csv")
data_hifi_dc_pre_release = pd.read_csv("data_deepconsensus_pre_release.index.csv")

# %%
rerun_hifi_table_march_01 = pd.read_csv(f"{BASE_DIR}/rerun_march_01_2025/hmm_flagger/hifi/hmm_flagger_hifi_data_table.csv")
rerun_ont_table_march_01 = pd.read_csv(f"{BASE_DIR}/rerun_march_01_2025/hmm_flagger/ont/hmm_flagger_ont_data_table.csv")

# %%
rerun_hifi_table_march_01_samples = rerun_hifi_table_march_01['sample_id']
print("Number of samples already ran with HiFi data : ", len(rerun_hifi_table_march_01_samples))
# Out:
# Number of samples already ran with HiFi data :  212

# %%
rerun_ont_table_march_01_samples = rerun_ont_table_march_01['sample_id']
print("Number of samples already ran with ONT data : ", len(rerun_ont_table_march_01_samples))
# Out:
# Number of samples already ran with ONT data :  195

# %% [markdown]
# ### Find samples that were missed before but we have new data for them now

# %%
new_samples_hifi = list(set(censat_pre_release['sample_id']).difference(rerun_hifi_table_march_01_samples))
print(f"These are  {len(new_samples_hifi)}  samples with new HiFi data that should be run for batch3 : ")
print("\n".join(new_samples_hifi))
# Out:
# These are  19  samples with new HiFi data that should be run for batch3 :
# NA18959
# HG02027
# NA20762
# NA18982
# NA18940
# NA18960
# HG005
# HG01786
# HG06807
# NA20806
# NA20503
# NA18967
# NA18944
# NA18970
# NA18948
# HG00733
# NA20827
# NA18945
# NA18943

# %%
new_samples_ont = list(set(censat_pre_release['sample_id']).difference(rerun_ont_table_march_01_samples))
print(f"These are  {len(new_samples_ont)}  samples with new ONT data that should be run for batch3 : ")
print("\n".join(new_samples_ont))
# Out:
# These are  36  samples with new ONT data that should be run for batch3 :
# NA20762
# HG02109
# HG01786
# HG03486
# HG02145
# HG06807
# NA20806
# HG02055
# NA18944
# NA18906
# NA18970
# HG00733
# NA19240
# NA18945
# HG02080
# NA18943
# NA18948
# NA20752
# HG02818
# NA18959
# HG02027
# HG03098
# NA20799
# NA18982
# NA18940
# NA18960
# HG005
# NA19159
# NA20129
# HG01109
# NA21309
# NA20503
# NA18967
# NA20827
# HG02723
# HG01243

# %%
def addDownsampledColumn(merged_reads_table, coverage_threshold):
    merged_reads_table["read_files_downsampled"] = [[] for _ in range(len(merged_reads_table))]
    merged_reads_table["total_coverage_downsampled"] = 0

    for i in range(merged_reads_table.shape[0]):
        coverages = merged_reads_table["coverage"][i]
        paths = merged_reads_table["read_files"][i]
        coverage_path_tuples = [(c, p) for c, p in zip(coverages, paths)]
        coverage_path_tuples.sort(key=lambda x: x[0], reverse=True)
        summed_coverage = 0
        downsampled_paths = []
        for j in range(len(coverage_path_tuples)):
            summed_coverage += coverage_path_tuples[j][0]
            merged_reads_table.loc[i, "read_files_downsampled"].append(coverage_path_tuples[j][1])
            if summed_coverage >= coverage_threshold:
                break
        merged_reads_table.loc[i, "total_coverage_downsampled"] = round(summed_coverage,2)

    merged_reads_table["number_of_read_files_downsampled"] = merged_reads_table["read_files_downsampled"].apply(len)
    merged_reads_table["number_of_cores_per_task_downsampled"] = (totalCores / merged_reads_table["number_of_read_files_downsampled"]).astype(int)
    merged_reads_table['number_of_cores_per_task_downsampled'] = merged_reads_table['number_of_cores_per_task_downsampled'].apply(lambda x: max(4,x))

# %% [markdown]
# ### Make a merged read table for HiFi and downsample if neccessary

# %%
data_hifi_pre_release.head()
# Out:
#   sample_ID filetype                                         filename  \
# 0   HG00099      bam  m54329U_220825_174247-bc2012.5mc.hifi_reads.bam
# 1   HG00099      bam  m54329U_220827_143814-bc2050.5mc.hifi_reads.bam
# 2   HG00280      bam  m54329U_220901_221341-bc2051.5mc.hifi_reads.bam
# 3   HG00558      bam  m54329U_220107_233847-bc1016.5mc.hifi_reads.bam
# 4   HG00639      bam  m54329U_211222_104516-bc1010.5mc.hifi_reads.bam
#
#                                                 path        data_type  \
# 0  s3://human-pangenomics/working/HPRC/HG00099/ra...  unaligned reads
# 1  s3://human-pangenomics/working/HPRC/HG00099/ra...  unaligned reads
# 2  s3://human-pangenomics/working/HPRC/HG00280/ra...  unaligned reads
# 3  s3://human-pangenomics/working/HPRC/HG00558/ra...  unaligned reads
# 4  s3://human-pangenomics/working/HPRC/HG00639/ra...  unaligned reads
#
#         production  coverage  deepconsensus_coverage  \
# 0  UW_HPRC_HiFi_Y3      15.4                   18.10
# 1  UW_HPRC_HiFi_Y3      14.7                   17.07
# 2  UW_HPRC_HiFi_Y3      15.2                   17.78
# 3  UW_HPRC_HiFi_Y3      10.9                   12.77
# 4  UW_HPRC_HiFi_Y3       9.7                   12.43
#
#                           deepconsensus_filename  \
# 0  HG00099.m54329U_220825_174247.dc.q20.fastq.gz
# 1  HG00099.m54329U_220827_143814.dc.q20.fastq.gz
# 2  HG00280.m54329U_220901_221341.dc.q20.fastq.gz
# 3  HG00558.m54329U_220107_233847.dc.q20.fastq.gz
# 4  HG00639.m54329U_211222_104516.dc.q20.fastq.gz
#
#                                   deepconsensus_path        ...          \
# 0  s3://human-pangenomics/submissions/42AFCE59-29...        ...
# 1  s3://human-pangenomics/submissions/42AFCE59-29...        ...
# 2  s3://human-pangenomics/submissions/42AFCE59-29...        ...
# 3  s3://human-pangenomics/submissions/42AFCE59-29...        ...
# 4  s3://human-pangenomics/submissions/42AFCE59-29...        ...
#
#   quartile_25  quartile_50 quartile_75  ntsm_score MM_tag primrose_filename  \
# 0       17755        20124       23333         NaN   True               NaN
# 1       17274        19325       22189         NaN   True               NaN
# 2       16982        19131       22147         NaN   True               NaN
# 3       16632        20068       24477         NaN   True               NaN
# 4       15750        18909       22999         NaN   True               NaN
#
#   MM_review MM_remove  lima_version lima_float_version
# 0      True     False         2.5.1             2.0501
# 1      True     False         2.5.1             2.0501
# 2      True     False         2.5.1             2.0501
# 3      True     False         2.5.0             2.0500
# 4      True     False         2.5.0             2.0500
#
# [5 rows x 51 columns]

# %%
# merge hifi full table
totalCores = 64
merged_hifi_full_table = data_hifi_pre_release.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_hifi_full_table.rename(columns={"sample_ID": "sample_id"}, inplace=True)
merged_hifi_full_table.rename(columns={"path": "read_files"}, inplace=True)
merged_hifi_full_table["total_coverage"] = merged_hifi_full_table["coverage"].apply(sum)
merged_hifi_full_table["number_of_read_files"] = merged_hifi_full_table["read_files"].apply(len)
merged_hifi_full_table["number_of_cores_per_task"] = (totalCores / merged_hifi_full_table["number_of_read_files"]).astype(int)
merged_hifi_full_table['number_of_cores_per_task'] = merged_hifi_full_table['number_of_cores_per_task'].apply(lambda x: max(4,x))
merged_hifi_full_table["mapper_preset"] = "lr:hqae"
merged_hifi_full_table["kmer_size"] = 25

merged_hifi_full_table["hmm_flagger_preset"] = 'hifi'

# %%
# max coverage is so high
max(merged_hifi_full_table['total_coverage'])
# Out:
# 189.79999999999998

# %%
# Read files will be sorted by coverage and selected from the file with highest coverage.
# We don't include more read files once the cumulative sum of coverage is greater than 60x
addDownsampledColumn(merged_hifi_full_table, 60)
max(merged_hifi_full_table['total_coverage_downsampled'])
# Out:
# 81.6

# %% [markdown]
# ### Make a merged read table for HiFi (DeepConsensus) and downsample if neccessary

# %%
data_hifi_dc_pre_release.head()
# Out:
#      accession      study bioproject_accession biosample_accession  \
# 0  SRR25618944  SRP305758          PRJNA701308        SAMN26237490
# 1  SRR25618943  SRP305758          PRJNA701308        SAMN26237491
# 2  SRR25618932  SRP305758          PRJNA701308        SAMN26237491
# 3  SRR25618921  SRP305758          PRJNA701308        SAMN26237492
# 4  SRR25618910  SRP305758          PRJNA701308        SAMN26267378
#
#         library_ID                                              title  \
# 0  HG00423_lib1_dc  PacBio HiFi sequencing of HG00423 rebasecalled...
# 1  HG00544_lib1_dc  PacBio HiFi sequencing of HG00544 rebasecalled...
# 2  HG00544_lib2_dc  PacBio HiFi sequencing of HG00544 rebasecalled...
# 3  HG00609_lib1_dc  PacBio HiFi sequencing of HG00609 rebasecalled...
# 4  HG00642.HFSS_dc  PacBio HiFi sequencing of HG00642 rebasecalled...
#
#   library_strategy library_source   library_selection library_layout  \
# 0              WGS        GENOMIC  size fractionation         single
# 1              WGS        GENOMIC  size fractionation         single
# 2              WGS        GENOMIC  size fractionation         single
# 3              WGS        GENOMIC  size fractionation         single
# 4              WGS        GENOMIC  size fractionation         single
#
#        ...         N75 sample_ID  \
# 0      ...       20614   HG00423
# 1      ...       22870   HG00544
# 2      ...       20289   HG00544
# 3      ...       23774   HG00609
# 4      ...       23857   HG00642
#
#                                                 path  \
# 0  s3://human-pangenomics/working/HPRC/HG00423/ra...
# 1  s3://human-pangenomics/working/HPRC/HG00544/ra...
# 2  s3://human-pangenomics/working/HPRC/HG00544/ra...
# 3  s3://human-pangenomics/working/HPRC/HG00609/ra...
# 4  s3://human-pangenomics/working/HPRC/HG00642/ra...
#
#                  production        data_type notes  MM_tag coverage  \
# 0  HPRC_DEEPCONSENSUS_v1pt2  unaligned reads   NaN     NaN    12.91
# 1  HPRC_DEEPCONSENSUS_v1pt2  unaligned reads   NaN     NaN    10.26
# 2  HPRC_DEEPCONSENSUS_v1pt2  unaligned reads   NaN     NaN    13.74
# 3  HPRC_DEEPCONSENSUS_v1pt2  unaligned reads   NaN     NaN    12.60
# 4  HPRC_DEEPCONSENSUS_v1pt2  unaligned reads   NaN     NaN    13.52
#
#   ntsm_score ccs_algorithm
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
#
# [5 rows x 43 columns]

# %%
# merge hifi full table
totalCores = 64
merged_hifi_dc_full_table = data_hifi_dc_pre_release.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_hifi_dc_full_table.rename(columns={"sample_ID": "sample_id"}, inplace=True)
merged_hifi_dc_full_table.rename(columns={"path": "read_files"}, inplace=True)
merged_hifi_dc_full_table["total_coverage"] = merged_hifi_dc_full_table["coverage"].apply(sum)
merged_hifi_dc_full_table["number_of_read_files"] = merged_hifi_dc_full_table["read_files"].apply(len)
merged_hifi_dc_full_table["number_of_cores_per_task"] = (totalCores / merged_hifi_dc_full_table["number_of_read_files"]).astype(int)
merged_hifi_dc_full_table['number_of_cores_per_task'] = merged_hifi_dc_full_table['number_of_cores_per_task'].apply(lambda x: max(4,x))
merged_hifi_dc_full_table["mapper_preset"] = "lr:hqae"
merged_hifi_dc_full_table["kmer_size"] = 25

merged_hifi_dc_full_table["hmm_flagger_preset"] = 'hifi'

# %%
# max coverage is so high
max(merged_hifi_dc_full_table['total_coverage'])
# Out:
# 84.47

# %%
# Read files will be sorted by coverage and selected from the file with highest coverage.
# We don't include more read files once the cumulative sum of coverage is greater than 60x
addDownsampledColumn(merged_hifi_dc_full_table, 60)
max(merged_hifi_dc_full_table['total_coverage_downsampled'])
# Out:
# 70.21

# %% [markdown]
# ### Make a merged read table for ONT and downsample if neccessary

# %%
data_ont_pre_release.head()
# Out:
#                                             filename filetype sample_ID  \
# 0  03_14_23_R941_HG00621_1_Guppy_6.5.7_450bps_mod...      bam   HG00621
# 1  03_14_23_R941_HG00621_2_Guppy_6.5.7_450bps_mod...      bam   HG00621
# 2  03_14_23_R941_HG01952_1_Guppy_6.5.7_450bps_mod...      bam   HG01952
# 3  03_14_23_R941_HG01952_2_Guppy_6.5.7_450bps_mod...      bam   HG01952
# 4  03_14_23_R941_HG02148_1_Guppy_6.5.7_450bps_mod...      bam   HG02148
#
#   biosample_accession                                         library_ID  \
# 0        SAMN17861653  03_14_23_R941_HG00621_1_Guppy_6.5.7_450bps_mod...
# 1        SAMN17861653  03_14_23_R941_HG00621_2_Guppy_6.5.7_450bps_mod...
# 2        SAMN17861661  03_14_23_R941_HG01952_1_Guppy_6.5.7_450bps_mod...
# 3        SAMN17861661  03_14_23_R941_HG01952_2_Guppy_6.5.7_450bps_mod...
# 4        SAMN17861663  03_14_23_R941_HG02148_1_Guppy_6.5.7_450bps_mod...
#
#   library_strategy library_source library_selection library_layout  \
# 0              WGS        GENOMIC            RANDOM         single
# 1              WGS        GENOMIC            RANDOM         single
# 2              WGS        GENOMIC            RANDOM         single
# 3              WGS        GENOMIC            RANDOM         single
# 4              WGS        GENOMIC            RANDOM         single
#
#           platform         ...          300kb+ 400kb+ 500kb+ 1Mb+ whales  \
# 0  OXFORD_NANOPORE         ...            0.35   0.07   0.01  0.0      1
# 1  OXFORD_NANOPORE         ...            0.32   0.06   0.01  0.0      0
# 2  OXFORD_NANOPORE         ...            0.20   0.02   0.01  0.0      0
# 3  OXFORD_NANOPORE         ...            0.11   0.01   0.00  0.0      0
# 4  OXFORD_NANOPORE         ...            0.23   0.04   0.01  0.0      0
#
#      accession      study bioproject_accession  \
# 0  SRR31367103  SRP305758          PRJNA701308
# 1  SRR31367102  SRP305758          PRJNA701308
# 2  SRR31366972  SRP305758          PRJNA701308
# 3  SRR31367144  SRP305758          PRJNA701308
# 4  SRR31367119  SRP305758          PRJNA701308
#
#                        production sequencing_chemistry
# 0  UCSC_HPRC_ONT_Y1_WTOPUP_GUPPY6                 R941
# 1  UCSC_HPRC_ONT_Y1_WTOPUP_GUPPY6                 R941
# 2  UCSC_HPRC_ONT_Y1_WTOPUP_GUPPY6                 R941
# 3  UCSC_HPRC_ONT_Y1_WTOPUP_GUPPY6                 R941
# 4  UCSC_HPRC_ONT_Y1_WTOPUP_GUPPY6                 R941
#
# [5 rows x 38 columns]

# %%
totalCores = 64
# merge ont table
merged_ont_full_table = data_ont_pre_release.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_ont_full_table.rename(columns={"sample_ID": "sample_id"} ,inplace=True)
merged_ont_full_table.rename(columns={"path": "read_files"}, inplace=True)
merged_ont_full_table["total_coverage"] = merged_ont_full_table["coverage"].apply(sum).apply(lambda x: round(x,2))
merged_ont_full_table["sequencing_chemistry"] = merged_ont_full_table["sequencing_chemistry"].apply(lambda x : x[0 ]if len(set(x)) == 1 else ",".join(set(x)))
merged_ont_full_table["number_of_read_files"] = merged_ont_full_table["read_files"].apply(len)
merged_ont_full_table["number_of_cores_per_task"] = (totalCores / merged_ont_full_table["number_of_read_files"]).astype(int)
merged_ont_full_table['number_of_cores_per_task'] = merged_ont_full_table['number_of_cores_per_task'].apply(lambda x: max(4,x))

# preset for R1041 is lr:hqae
# preset for R941 is map-ont
merged_ont_full_table["mapper_preset"] = ""
merged_ont_full_table["mapper_preset"][merged_ont_full_table["sequencing_chemistry"] == "R1041"] = "lr:hqae"
merged_ont_full_table["mapper_preset"][merged_ont_full_table["sequencing_chemistry"] == "R941"] = "map-ont"
merged_ont_full_table["kmer_size"] = 0
merged_ont_full_table["kmer_size"][merged_ont_full_table["sequencing_chemistry"] == "R1041"] = 25
merged_ont_full_table["kmer_size"][merged_ont_full_table["sequencing_chemistry"] == "R941"] = 15

merged_ont_full_table["hmm_flagger_preset"] = ''
merged_ont_full_table["hmm_flagger_preset"][merged_ont_full_table["sequencing_chemistry"] == "R1041"] = 'ont-r10'
merged_ont_full_table["hmm_flagger_preset"][merged_ont_full_table["sequencing_chemistry"] == "R941"] = 'ont-r9'
# Out:
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# max coverage is so high
max(merged_ont_full_table['total_coverage'])
# Out:
# 228.17

# %%
# Read files will be sorted by coverage and selected from the file with highest coverage.
# We don't include more read files once the cumulative sum of coverage is greater than 60x
addDownsampledColumn(merged_ont_full_table, 60)
max(merged_ont_full_table['total_coverage_downsampled'])
# Out:
# 87.17

# %% [markdown]
# ## Make assembly table

# %%
assembly_pre_release.head()
# Out:
#   sample_id  haplotype phasing assembly_method assembly_method_version  \
# 0   HG00408          1    trio         hifiasm                  0.19.7
# 1   HG00597          1    trio         hifiasm                  0.19.7
# 2   HG01192          1    trio         hifiasm                  0.19.7
# 3   HG01261          1    trio         hifiasm                  0.19.7
# 4   HG02015          1    trio         hifiasm                  0.19.7
#
#   assembly_date               assembly_name source genbank_accession  \
# 0       2024-08  HG00408_pat_hprc_r2_v1.0.1   hprc   GCA_041900255.1
# 1       2024-08  HG00597_pat_hprc_r2_v1.0.1   hprc   GCA_041900365.1
# 2       2024-08  HG01192_pat_hprc_r2_v1.0.1   hprc   GCA_041900145.1
# 3       2024-08  HG01261_pat_hprc_r2_v1.0.1   hprc   GCA_041900235.1
# 4       2024-08  HG02015_pat_hprc_r2_v1.0.1   hprc   GCA_041900165.1
#
#                                         assembly_md5  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                         assembly_fai  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                         assembly_gzi  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                             assembly
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...

# %%
# make two assembly tables one for hap1 and one for hap2
assembly_pre_release_hap1 = assembly_pre_release[assembly_pre_release['haplotype'] == 1]
assembly_pre_release_hap2 = assembly_pre_release[assembly_pre_release['haplotype'] == 2]

# Merging the DataFrames on 'sample_id'
assembly_pre_release_diploid = pd.merge(assembly_pre_release_hap1,
                                        assembly_pre_release_hap2,
                                        on='sample_id',
                                        suffixes=('_hap1', '_hap2'))

# keep only neccessary columns
assembly_pre_release_diploid = assembly_pre_release_diploid[["sample_id", 
                                                             "assembly_hap1",
                                                             "assembly_hap2"]]
assembly_pre_release_diploid.head()
# Out:
#   sample_id                                      assembly_hap1  \
# 0   HG00408  s3://human-pangenomics/submissions/DC27718F-5F...
# 1   HG00597  s3://human-pangenomics/submissions/DC27718F-5F...
# 2   HG01192  s3://human-pangenomics/submissions/DC27718F-5F...
# 3   HG01261  s3://human-pangenomics/submissions/DC27718F-5F...
# 4   HG02015  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                        assembly_hap2
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...

# %% [markdown]
# ## Make a table for diploid censat bed files

# %%
censat_pre_release.head()
# Out:
#   sample_id haplotype           assembly_name  \
# 0   HG00408      hap1  HG00408_pat_hprc_r2_v1
# 1   HG00408      hap2  HG00408_mat_hprc_r2_v1
# 2   HG00597      hap1  HG00597_pat_hprc_r2_v1
# 3   HG00597      hap2  HG00597_mat_hprc_r2_v1
# 4   HG01192      hap1  HG01192_pat_hprc_r2_v1
#
#                                             location  Unnamed: 4  Unnamed: 5  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...         NaN         NaN
# 1  s3://human-pangenomics/submissions/DC27718F-5F...         NaN         NaN
# 2  s3://human-pangenomics/submissions/DC27718F-5F...         NaN         NaN
# 3  s3://human-pangenomics/submissions/DC27718F-5F...         NaN         NaN
# 4  s3://human-pangenomics/submissions/DC27718F-5F...         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14                        Unnamed: 15
# 0          NaN          NaN          NaN  HG00408_pat_hprc_r2_v1.cenSat.bed
# 1          NaN          NaN          NaN  HG00408_mat_hprc_r2_v1.cenSat.bed
# 2          NaN          NaN          NaN  HG00597_pat_hprc_r2_v1.cenSat.bed
# 3          NaN          NaN          NaN  HG00597_mat_hprc_r2_v1.cenSat.bed
# 4          NaN          NaN          NaN  HG01192_pat_hprc_r2_v1.cenSat.bed

# %%
# rename the name of the column with censat link
censat_pre_release = censat_pre_release.rename(columns={"location": "cenSatAnnotations"})

# replace s3 link with https
censat_pre_release['cenSatAnnotations'] = censat_pre_release['cenSatAnnotations'].str.replace('s3://','https://s3-us-west-2.amazonaws.com/')

# make two tables one for hap1 and one for hap2
censat_pre_release_hap1 = censat_pre_release[censat_pre_release['haplotype'] == 'hap1']
censat_pre_release_hap2 = censat_pre_release[censat_pre_release['haplotype'] == 'hap2']

# Merging the DataFrames on 'sample_id'
censat_pre_release_merged = pd.merge(censat_pre_release_hap1,
                                     censat_pre_release_hap2,
                                     on='sample_id',
                                     suffixes=('_hap1', '_hap2'))
censat_pre_release_merged = censat_pre_release_merged[["sample_id",
                                                       "cenSatAnnotations_hap1",
                                                       "cenSatAnnotations_hap2"]]
censat_pre_release_merged.head()
# Out:
#   sample_id                             cenSatAnnotations_hap1  \
# 0   HG00408  https://s3-us-west-2.amazonaws.com/human-pange...
# 1   HG00597  https://s3-us-west-2.amazonaws.com/human-pange...
# 2   HG01192  https://s3-us-west-2.amazonaws.com/human-pange...
# 3   HG01261  https://s3-us-west-2.amazonaws.com/human-pange...
# 4   HG02015  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                               cenSatAnnotations_hap2
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...

# %%
# merge new samples for hifi and ont
new_samples_union = list(set(new_samples_hifi).union(set(new_samples_ont)))
censat_table_batch3 = censat_pre_release_merged[censat_pre_release_merged['sample_id'].isin(new_samples_union)]
print(f"We have {len(new_samples_union)} new samples in total")
print(f"Number of censat rows: {len(censat_table_batch3)}")
# Out:
# We have 36 new samples in total
# Number of censat rows: 36

# %%
# fixed index
censat_table_batch3.index = np.arange(len(censat_table_batch3))

# %%
def addDiploidCenSatAnnotation(censat_table_diploid, diploid_censat_dir, create_files):
    # add a column for saving diploid censat bed files
    censat_table_diploid["censat_diploid_bed"] = ""

    # make a directory for saving diploid censat bed files
    # !mkdir -p {diploid_censat_dir}

    censat_diploid_list = []
    additional_annotations_array_list = []
    # iterate over rows
    for i in range(len(censat_table_diploid)):
        sample = censat_table_diploid["sample_id"][i]
        censat_bed_hap1 = censat_table_diploid["cenSatAnnotations_hap1"][i]
        censat_bed_hap2 = censat_table_diploid["cenSatAnnotations_hap2"][i]
        censat_bed_hap1_name = os.path.basename(censat_bed_hap1)
        censat_bed_hap2_name = os.path.basename(censat_bed_hap2)

        if create_files:
            # download censat files
            # !cd {diploid_censat_dir} && wget {censat_bed_hap1}
            # !cd {diploid_censat_dir} && wget {censat_bed_hap2}
        
            # concat hap1 and hap2 censat bed files into a single bed file
            # !cat {diploid_censat_dir}/{censat_bed_hap1_name} {diploid_censat_dir}/{censat_bed_hap2_name} | bedtools sort -i - > {diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.bed
            # !cat {diploid_censat_dir}/{censat_bed_hap1_name} {diploid_censat_dir}/{censat_bed_hap2_name} | bedtools sort -i - | grep -i "rDNA" | awk '{{print $$1"\t"$$2"\t"$$3}}' > {diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.rDNA.bed

        # add new bed to the table
        censat_diploid_list.append(f'{diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.bed')
        # just adding rDNA annotation as an additional annotation
        additional_annotations_array_list.append([f'{diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.rDNA.bed'])

    censat_table_diploid["censat_diploid_bed"] = censat_diploid_list
    censat_table_diploid["additional_annotations_array"] = additional_annotations_array_list
    #censat_table_diploid.head()
    return censat_table_diploid

# %%
diploid_censat_dir_batch3 = f'{BASE_DIR}/batch3/hmm_flagger/diploid_censat_beds'
censat_table_diploid_batch3 = addDiploidCenSatAnnotation(censat_table_diploid = censat_table_batch3,
                                                         diploid_censat_dir = diploid_censat_dir_batch3,
                                                         create_files = True)
# Out:
# --2025-03-10 11:29:23--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG01109/assemblies/freeze_2/annotation/censat/HG01109_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.129.136, 52.92.194.104, 52.92.227.176, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.129.136|:443...
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253950 (248K) [binary/octet-stream]
# Saving to: ‘HG01109_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG01109_pat_hprc_r2 100%[===================>] 248.00K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:23 (3.93 MB/s) - ‘HG01109_pat_hprc_r2_v1.cenSat.bed.1’ saved [253950/253950]
#
# --2025-03-10 11:29:23--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG01109/assemblies/freeze_2/annotation/censat/HG01109_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.227.176, 52.92.129.136, 52.218.252.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.227.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252606 (247K) [binary/octet-stream]
# Saving to: ‘HG01109_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG01109_mat_hprc_r2 100%[===================>] 246.69K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:29:23 (2.30 MB/s) - ‘HG01109_mat_hprc_r2_v1.cenSat.bed.1’ saved [252606/252606]
#
# --2025-03-10 11:29:24--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02055/assemblies/freeze_2/annotation/censat/HG02055_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.182.48, 52.92.129.136, 52.218.252.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.182.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278702 (272K) [binary/octet-stream]
# Saving to: ‘HG02055_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG02055_pat_hprc_r2 100%[===================>] 272.17K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:24 (3.23 MB/s) - ‘HG02055_pat_hprc_r2_v1.cenSat.bed.1’ saved [278702/278702]
#
# --2025-03-10 11:29:24--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02055/assemblies/freeze_2/annotation/censat/HG02055_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.194.104, 52.92.129.136, 52.92.241.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.194.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 258843 (253K) [binary/octet-stream]
# Saving to: ‘HG02055_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG02055_mat_hprc_r2 100%[===================>] 252.78K  --.-KB/s    in 0.09s
#
# 2025-03-10 11:29:25 (2.88 MB/s) - ‘HG02055_mat_hprc_r2_v1.cenSat.bed.1’ saved [258843/258843]
#
# --2025-03-10 11:29:25--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02080/assemblies/freeze_2/annotation/censat/HG02080_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.149.88, 52.218.182.48, 52.92.129.136, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.149.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242987 (237K) [binary/octet-stream]
# Saving to: ‘HG02080_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG02080_pat_hprc_r2 100%[===================>] 237.29K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:26 (2.73 MB/s) - ‘HG02080_pat_hprc_r2_v1.cenSat.bed.1’ saved [242987/242987]
#
# --2025-03-10 11:29:26--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02080/assemblies/freeze_2/annotation/censat/HG02080_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.182.48, 52.92.241.88, 52.218.252.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.182.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 239569 (234K) [binary/octet-stream]
# Saving to: ‘HG02080_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG02080_mat_hprc_r2 100%[===================>] 233.95K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:26 (2.78 MB/s) - ‘HG02080_mat_hprc_r2_v1.cenSat.bed.1’ saved [239569/239569]
#
# --2025-03-10 11:29:27--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02109/assemblies/freeze_2/annotation/censat/HG02109_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.227.176, 52.92.149.88, 52.218.182.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.227.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240472 (235K) [binary/octet-stream]
# Saving to: ‘HG02109_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG02109_pat_hprc_r2 100%[===================>] 234.84K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:27 (3.66 MB/s) - ‘HG02109_pat_hprc_r2_v1.cenSat.bed.1’ saved [240472/240472]
#
# --2025-03-10 11:29:27--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02109/assemblies/freeze_2/annotation/censat/HG02109_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.182.48, 52.92.194.104, 52.92.241.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.182.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246276 (241K) [binary/octet-stream]
# Saving to: ‘HG02109_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG02109_mat_hprc_r2 100%[===================>] 240.50K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:28 (2.85 MB/s) - ‘HG02109_mat_hprc_r2_v1.cenSat.bed.1’ saved [246276/246276]
#
# --2025-03-10 11:29:28--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02723/assemblies/freeze_2/annotation/censat/HG02723_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.212.216, 52.92.210.184, 52.92.132.16, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.212.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246975 (241K) [binary/octet-stream]
# Saving to: ‘HG02723_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG02723_pat_hprc_r2 100%[===================>] 241.19K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:29:29 (2.27 MB/s) - ‘HG02723_pat_hprc_r2_v1.cenSat.bed.1’ saved [246975/246975]
#
# --2025-03-10 11:29:29--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02723/assemblies/freeze_2/annotation/censat/HG02723_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.183.72, 52.92.212.216, 52.92.212.0, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.183.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 241260 (236K) [binary/octet-stream]
# Saving to: ‘HG02723_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG02723_mat_hprc_r2 100%[===================>] 235.61K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:29 (3.65 MB/s) - ‘HG02723_mat_hprc_r2_v1.cenSat.bed.1’ saved [241260/241260]
#
# --2025-03-10 11:29:30--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02818/assemblies/freeze_2/annotation/censat/HG02818_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.212.216, 52.218.183.72, 52.92.132.16, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.212.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247858 (242K) [binary/octet-stream]
# Saving to: ‘HG02818_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG02818_pat_hprc_r2 100%[===================>] 242.05K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:30 (3.83 MB/s) - ‘HG02818_pat_hprc_r2_v1.cenSat.bed.1’ saved [247858/247858]
#
# --2025-03-10 11:29:30--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02818/assemblies/freeze_2/annotation/censat/HG02818_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.16, 52.92.186.24, 52.92.213.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256064 (250K) [binary/octet-stream]
# Saving to: ‘HG02818_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG02818_mat_hprc_r2 100%[===================>] 250.06K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:31 (2.97 MB/s) - ‘HG02818_mat_hprc_r2_v1.cenSat.bed.1’ saved [256064/256064]
#
# --2025-03-10 11:29:31--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG03098/assemblies/freeze_2/annotation/censat/HG03098_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.186.24, 52.92.237.104, 52.92.213.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.186.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 272014 (266K) [binary/octet-stream]
# Saving to: ‘HG03098_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG03098_pat_hprc_r2 100%[===================>] 265.64K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:32 (3.20 MB/s) - ‘HG03098_pat_hprc_r2_v1.cenSat.bed.1’ saved [272014/272014]
#
# --2025-03-10 11:29:32--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG03098/assemblies/freeze_2/annotation/censat/HG03098_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.183.72, 52.92.210.184, 52.92.212.0, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.183.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246881 (241K) [binary/octet-stream]
# Saving to: ‘HG03098_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG03098_mat_hprc_r2 100%[===================>] 241.09K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:32 (2.85 MB/s) - ‘HG03098_mat_hprc_r2_v1.cenSat.bed.1’ saved [246881/246881]
#
# --2025-03-10 11:29:33--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG03486/assemblies/freeze_2/annotation/censat/HG03486_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.16, 52.92.212.216, 52.92.213.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 257147 (251K) [binary/octet-stream]
# Saving to: ‘HG03486_pat_hprc_r2_v1.cenSat.bed.1’
#
# HG03486_pat_hprc_r2 100%[===================>] 251.12K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:33 (3.96 MB/s) - ‘HG03486_pat_hprc_r2_v1.cenSat.bed.1’ saved [257147/257147]
#
# --2025-03-10 11:29:33--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG03486/assemblies/freeze_2/annotation/censat/HG03486_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.181.32, 52.92.132.8, 52.218.176.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.181.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262088 (256K) [binary/octet-stream]
# Saving to: ‘HG03486_mat_hprc_r2_v1.cenSat.bed.1’
#
# HG03486_mat_hprc_r2 100%[===================>] 255.95K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:34 (2.96 MB/s) - ‘HG03486_mat_hprc_r2_v1.cenSat.bed.1’ saved [262088/262088]
#
# --2025-03-10 11:29:34--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18906/assemblies/freeze_2/annotation/censat/NA18906_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.181.32, 52.92.193.128, 52.218.176.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.181.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238992 (233K) [binary/octet-stream]
# Saving to: ‘NA18906_pat_hprc_r2_v1.cenSat.bed.1’
#
# NA18906_pat_hprc_r2 100%[===================>] 233.39K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:35 (3.65 MB/s) - ‘NA18906_pat_hprc_r2_v1.cenSat.bed.1’ saved [238992/238992]
#
# --2025-03-10 11:29:35--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18906/assemblies/freeze_2/annotation/censat/NA18906_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.234.184, 52.92.181.32, 52.218.176.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.234.184|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247960 (242K) [binary/octet-stream]
# Saving to: ‘NA18906_mat_hprc_r2_v1.cenSat.bed.1’
#
# NA18906_mat_hprc_r2 100%[===================>] 242.15K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:35 (3.75 MB/s) - ‘NA18906_mat_hprc_r2_v1.cenSat.bed.1’ saved [247960/247960]
#
# --2025-03-10 11:29:36--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20129/assemblies/freeze_2/annotation/censat/NA20129_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.205.224, 52.218.234.184, 52.92.181.32, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.205.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250949 (245K) [binary/octet-stream]
# Saving to: ‘NA20129_pat_hprc_r2_v1.cenSat.bed.1’
#
# NA20129_pat_hprc_r2 100%[===================>] 245.07K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:36 (3.84 MB/s) - ‘NA20129_pat_hprc_r2_v1.cenSat.bed.1’ saved [250949/250949]
#
# --2025-03-10 11:29:36--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20129/assemblies/freeze_2/annotation/censat/NA20129_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.8, 52.92.207.120, 52.92.228.64, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255962 (250K) [binary/octet-stream]
# Saving to: ‘NA20129_mat_hprc_r2_v1.cenSat.bed.1’
#
# NA20129_mat_hprc_r2 100%[===================>] 249.96K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:37 (2.96 MB/s) - ‘NA20129_mat_hprc_r2_v1.cenSat.bed.1’ saved [255962/255962]
#
# --2025-03-10 11:29:37--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA21309/assemblies/freeze_2/annotation/censat/NA21309_pat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.8, 52.218.234.184, 52.92.181.32, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 235434 (230K) [binary/octet-stream]
# Saving to: ‘NA21309_pat_hprc_r2_v1.cenSat.bed.1’
#
# NA21309_pat_hprc_r2 100%[===================>] 229.92K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:38 (3.61 MB/s) - ‘NA21309_pat_hprc_r2_v1.cenSat.bed.1’ saved [235434/235434]
#
# --2025-03-10 11:29:38--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA21309/assemblies/freeze_2/annotation/censat/NA21309_mat_hprc_r2_v1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.181.32, 52.92.228.64, 52.92.205.224, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.181.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 239226 (234K) [binary/octet-stream]
# Saving to: ‘NA21309_mat_hprc_r2_v1.cenSat.bed.1’
#
# NA21309_mat_hprc_r2 100%[===================>] 233.62K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:38 (3.63 MB/s) - ‘NA21309_mat_hprc_r2_v1.cenSat.bed.1’ saved [239226/239226]
#
# --2025-03-10 11:29:39--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20752/assemblies/freeze_2/annotation/censat/NA20752_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.228.72, 52.92.178.184, 52.92.130.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.228.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 251235 (245K) [binary/octet-stream]
# Saving to: ‘NA20752_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20752_hap1_hprc_r 100%[===================>] 245.35K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:39 (3.85 MB/s) - ‘NA20752_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [251235/251235]
#
# --2025-03-10 11:29:39--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20752/assemblies/freeze_2/annotation/censat/NA20752_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.190.232, 52.218.133.48, 52.92.211.64, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.190.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256739 (251K) [binary/octet-stream]
# Saving to: ‘NA20752_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20752_hap2_hprc_r 100%[===================>] 250.72K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:40 (2.97 MB/s) - ‘NA20752_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [256739/256739]
#
# --2025-03-10 11:29:40--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02145/assemblies/freeze_2/annotation/censat/HG02145_pat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.180.136, 52.218.133.48, 52.92.228.72, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.180.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 258907 (253K) [binary/octet-stream]
# Saving to: ‘HG02145_pat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG02145_pat_hprc_r2 100%[===================>] 252.84K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:40 (3.03 MB/s) - ‘HG02145_pat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [258907/258907]
#
# --2025-03-10 11:29:41--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02145/assemblies/freeze_2/annotation/censat/HG02145_mat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.190.232, 52.92.130.48, 52.218.180.136, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.190.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 243156 (237K) [binary/octet-stream]
# Saving to: ‘HG02145_mat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG02145_mat_hprc_r2 100%[===================>] 237.46K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:41 (2.81 MB/s) - ‘HG02145_mat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [243156/243156]
#
# --2025-03-10 11:29:42--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA19159/assemblies/freeze_2/annotation/censat/NA19159_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.211.64, 52.218.133.48, 52.92.178.184, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.211.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 258257 (252K) [binary/octet-stream]
# Saving to: ‘NA19159_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA19159_hap1_hprc_r 100%[===================>] 252.20K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:42 (3.99 MB/s) - ‘NA19159_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [258257/258257]
#
# --2025-03-10 11:29:42--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA19159/assemblies/freeze_2/annotation/censat/NA19159_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.178.184, 52.92.130.48, 52.218.133.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.178.184|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 235015 (230K) [binary/octet-stream]
# Saving to: ‘NA19159_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA19159_hap2_hprc_r 100%[===================>] 229.51K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:43 (2.67 MB/s) - ‘NA19159_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [235015/235015]
#
# --2025-03-10 11:29:43--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG01786/assemblies/freeze_2/annotation/censat/HG01786_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.211.64, 52.92.228.72, 52.92.130.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.211.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240196 (235K) [binary/octet-stream]
# Saving to: ‘HG01786_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG01786_hap1_hprc_r 100%[===================>] 234.57K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:43 (2.79 MB/s) - ‘HG01786_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [240196/240196]
#
# --2025-03-10 11:29:44--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG01786/assemblies/freeze_2/annotation/censat/HG01786_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.211.64, 52.218.133.48, 52.92.130.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.211.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 251161 (245K) [binary/octet-stream]
# Saving to: ‘HG01786_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG01786_hap2_hprc_r 100%[===================>] 245.27K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:44 (2.89 MB/s) - ‘HG01786_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [251161/251161]
#
# --2025-03-10 11:29:45--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20799/assemblies/freeze_2/annotation/censat/NA20799_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.132.136, 52.92.190.136, 52.218.218.144, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.132.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 251742 (246K) [binary/octet-stream]
# Saving to: ‘NA20799_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20799_hap1_hprc_r 100%[===================>] 245.84K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:29:45 (2.34 MB/s) - ‘NA20799_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [251742/251742]
#
# --2025-03-10 11:29:45--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20799/assemblies/freeze_2/annotation/censat/NA20799_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.132.16, 52.218.132.136, 52.92.144.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.132.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 227561 (222K) [binary/octet-stream]
# Saving to: ‘NA20799_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20799_hap2_hprc_r 100%[===================>] 222.23K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:46 (2.65 MB/s) - ‘NA20799_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [227561/227561]
#
# --2025-03-10 11:29:46--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG00733/assemblies/freeze_2/annotation/censat/HG00733_pat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.190.136, 52.92.144.240, 52.92.144.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.190.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248764 (243K) [binary/octet-stream]
# Saving to: ‘HG00733_pat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG00733_pat_hprc_r2 100%[===================>] 242.93K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:46 (3.83 MB/s) - ‘HG00733_pat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [248764/248764]
#
# --2025-03-10 11:29:47--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG00733/assemblies/freeze_2/annotation/censat/HG00733_mat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.132.16, 52.92.190.136, 52.218.132.136, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.132.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248686 (243K) [binary/octet-stream]
# Saving to: ‘HG00733_mat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG00733_mat_hprc_r2 100%[===================>] 242.86K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:47 (2.85 MB/s) - ‘HG00733_mat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [248686/248686]
#
# --2025-03-10 11:29:48--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG01243/assemblies/freeze_2/annotation/censat/HG01243_pat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.144.48, 52.92.227.32, 52.218.237.16, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.144.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256984 (251K) [binary/octet-stream]
# Saving to: ‘HG01243_pat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG01243_pat_hprc_r2 100%[===================>] 250.96K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:29:48 (2.33 MB/s) - ‘HG01243_pat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [256984/256984]
#
# --2025-03-10 11:29:48--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG01243/assemblies/freeze_2/annotation/censat/HG01243_mat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.144.240, 52.218.132.136, 52.92.144.48, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.144.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247584 (242K) [binary/octet-stream]
# Saving to: ‘HG01243_mat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG01243_mat_hprc_r2 100%[===================>] 241.78K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:49 (2.78 MB/s) - ‘HG01243_mat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [247584/247584]
#
# --2025-03-10 11:29:49--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA19240/assemblies/freeze_2/annotation/censat/NA19240_pat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.218.144, 52.92.144.240, 52.92.227.32, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.218.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246862 (241K) [binary/octet-stream]
# Saving to: ‘NA19240_pat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA19240_pat_hprc_r2 100%[===================>] 241.08K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:50 (2.78 MB/s) - ‘NA19240_pat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [246862/246862]
#
# --2025-03-10 11:29:50--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA19240/assemblies/freeze_2/annotation/censat/NA19240_mat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.181.72, 3.5.79.232, 52.92.209.248, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.181.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245720 (240K) [binary/octet-stream]
# Saving to: ‘NA19240_mat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA19240_mat_hprc_r2 100%[===================>] 239.96K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:50 (2.85 MB/s) - ‘NA19240_mat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [245720/245720]
#
# --2025-03-10 11:29:51--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG005/assemblies/freeze_2/annotation/censat/HG005_pat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.181.72, 3.5.79.232, 52.92.163.96, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.181.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252986 (247K) [binary/octet-stream]
# Saving to: ‘HG005_pat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG005_pat_hprc_r2_v 100%[===================>] 247.06K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:29:51 (2.37 MB/s) - ‘HG005_pat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [252986/252986]
#
# --2025-03-10 11:29:51--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG005/assemblies/freeze_2/annotation/censat/HG005_mat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 3.5.79.232, 52.92.184.48, 52.92.207.8, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|3.5.79.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 230590 (225K) [binary/octet-stream]
# Saving to: ‘HG005_mat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG005_mat_hprc_r2_v 100%[===================>] 225.19K  --.-KB/s    in 0.07s
#
# 2025-03-10 11:29:52 (3.34 MB/s) - ‘HG005_mat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [230590/230590]
#
# --2025-03-10 11:29:52--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02027/assemblies/freeze_2/annotation/censat/HG02027_pat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 3.5.79.232, 52.92.209.248, 52.92.131.128, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|3.5.79.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 272652 (266K) [binary/octet-stream]
# Saving to: ‘HG02027_pat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG02027_pat_hprc_r2 100%[===================>] 266.26K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:29:52 (2.05 MB/s) - ‘HG02027_pat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [272652/272652]
#
# --2025-03-10 11:29:53--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG02027/assemblies/freeze_2/annotation/censat/HG02027_mat_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.163.96, 52.218.229.104, 52.92.207.8, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.163.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242604 (237K) [binary/octet-stream]
# Saving to: ‘HG02027_mat_hprc_r2_v1.0.1.cenSat.bed.1’
#
# HG02027_mat_hprc_r2 100%[===================>] 236.92K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:53 (2.77 MB/s) - ‘HG02027_mat_hprc_r2_v1.0.1.cenSat.bed.1’ saved [242604/242604]
#
# --2025-03-10 11:29:54--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18940/assemblies/freeze_2/annotation/censat/NA18940_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.229.104, 52.92.131.128, 52.218.181.72, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.229.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 234894 (229K) [binary/octet-stream]
# Saving to: ‘NA18940_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18940_hap1_hprc_r 100%[===================>] 229.39K  --.-KB/s    in 0.09s
#
# 2025-03-10 11:29:54 (2.63 MB/s) - ‘NA18940_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [234894/234894]
#
# --2025-03-10 11:29:54--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18940/assemblies/freeze_2/annotation/censat/NA18940_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.209.248, 52.92.163.96, 52.218.181.72, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.209.248|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 207870 (203K) [binary/octet-stream]
# Saving to: ‘NA18940_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18940_hap2_hprc_r 100%[===================>] 203.00K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:55 (3.19 MB/s) - ‘NA18940_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [207870/207870]
#
# --2025-03-10 11:29:55--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18943/assemblies/freeze_2/annotation/censat/NA18943_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.202.120, 52.92.132.8, 52.92.147.0, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.202.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 270728 (264K) [binary/octet-stream]
# Saving to: ‘NA18943_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18943_hap1_hprc_r 100%[===================>] 264.38K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:29:55 (4.05 MB/s) - ‘NA18943_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [270728/270728]
#
# --2025-03-10 11:29:56--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18943/assemblies/freeze_2/annotation/censat/NA18943_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.179.144, 52.92.186.248, 52.92.147.0, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.179.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247443 (242K) [binary/octet-stream]
# Saving to: ‘NA18943_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18943_hap2_hprc_r 100%[===================>] 241.64K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:56 (2.86 MB/s) - ‘NA18943_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [247443/247443]
#
# --2025-03-10 11:29:57--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18944/assemblies/freeze_2/annotation/censat/NA18944_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.186.248, 52.218.179.88, 52.92.147.0, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.186.248|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267797 (262K) [binary/octet-stream]
# Saving to: ‘NA18944_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18944_hap1_hprc_r 100%[===================>] 261.52K  --.-KB/s    in 0.07s
#
# 2025-03-10 11:29:57 (3.52 MB/s) - ‘NA18944_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [267797/267797]
#
# --2025-03-10 11:29:57--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18944/assemblies/freeze_2/annotation/censat/NA18944_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.202.120, 52.92.186.248, 52.92.147.0, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.202.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 249075 (243K) [binary/octet-stream]
# Saving to: ‘NA18944_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18944_hap2_hprc_r 100%[===================>] 243.24K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:58 (2.83 MB/s) - ‘NA18944_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [249075/249075]
#
# --2025-03-10 11:29:58--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18945/assemblies/freeze_2/annotation/censat/NA18945_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.179.88, 52.92.147.0, 52.92.202.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.179.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267905 (262K) [binary/octet-stream]
# Saving to: ‘NA18945_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18945_hap1_hprc_r 100%[===================>] 261.63K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:58 (3.13 MB/s) - ‘NA18945_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [267905/267905]
#
# --2025-03-10 11:29:59--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18945/assemblies/freeze_2/annotation/censat/NA18945_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.8, 52.92.186.248, 52.218.179.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250190 (244K) [binary/octet-stream]
# Saving to: ‘NA18945_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18945_hap2_hprc_r 100%[===================>] 244.33K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:29:59 (2.89 MB/s) - ‘NA18945_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [250190/250190]
#
# --2025-03-10 11:30:00--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18948/assemblies/freeze_2/annotation/censat/NA18948_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.179.88, 52.92.202.120, 52.92.152.64, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.179.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262529 (256K) [binary/octet-stream]
# Saving to: ‘NA18948_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18948_hap1_hprc_r 100%[===================>] 256.38K  --.-KB/s    in 0.09s
#
# 2025-03-10 11:30:00 (2.87 MB/s) - ‘NA18948_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [262529/262529]
#
# --2025-03-10 11:30:00--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18948/assemblies/freeze_2/annotation/censat/NA18948_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.152.64, 52.92.132.8, 52.92.202.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.152.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 272021 (266K) [binary/octet-stream]
# Saving to: ‘NA18948_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18948_hap2_hprc_r 100%[===================>] 265.65K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:01 (3.07 MB/s) - ‘NA18948_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [272021/272021]
#
# --2025-03-10 11:30:01--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18959/assemblies/freeze_2/annotation/censat/NA18959_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.228.16, 52.92.242.176, 52.92.165.128, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.228.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253088 (247K) [binary/octet-stream]
# Saving to: ‘NA18959_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18959_hap1_hprc_r 100%[===================>] 247.16K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:30:01 (2.30 MB/s) - ‘NA18959_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [253088/253088]
#
# --2025-03-10 11:30:01--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18959/assemblies/freeze_2/annotation/censat/NA18959_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.165.128, 52.92.226.24, 52.92.206.152, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.165.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 290983 (284K) [binary/octet-stream]
# Saving to: ‘NA18959_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18959_hap2_hprc_r 100%[===================>] 284.16K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:02 (3.38 MB/s) - ‘NA18959_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [290983/290983]
#
# --2025-03-10 11:30:02--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18960/assemblies/freeze_2/annotation/censat/NA18960_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.228.16, 52.92.165.128, 52.92.224.128, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.228.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278730 (272K) [binary/octet-stream]
# Saving to: ‘NA18960_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18960_hap1_hprc_r 100%[===================>] 272.20K  --.-KB/s    in 0.07s
#
# 2025-03-10 11:30:03 (4.08 MB/s) - ‘NA18960_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [278730/278730]
#
# --2025-03-10 11:30:03--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18960/assemblies/freeze_2/annotation/censat/NA18960_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.165.128, 52.92.228.16, 52.92.242.176, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.165.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244450 (239K) [binary/octet-stream]
# Saving to: ‘NA18960_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18960_hap2_hprc_r 100%[===================>] 238.72K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:04 (2.84 MB/s) - ‘NA18960_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [244450/244450]
#
# --2025-03-10 11:30:04--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18967/assemblies/freeze_2/annotation/censat/NA18967_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.228.16, 52.92.224.128, 52.92.128.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.228.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282518 (276K) [binary/octet-stream]
# Saving to: ‘NA18967_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18967_hap1_hprc_r 100%[===================>] 275.90K  --.-KB/s    in 0.07s
#
# 2025-03-10 11:30:04 (3.71 MB/s) - ‘NA18967_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [282518/282518]
#
# --2025-03-10 11:30:05--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18967/assemblies/freeze_2/annotation/censat/NA18967_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.128.120, 52.92.226.24, 52.92.240.24, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.128.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 235359 (230K) [binary/octet-stream]
# Saving to: ‘NA18967_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18967_hap2_hprc_r 100%[===================>] 229.84K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:05 (2.73 MB/s) - ‘NA18967_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [235359/235359]
#
# --2025-03-10 11:30:06--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18970/assemblies/freeze_2/annotation/censat/NA18970_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.240.24, 52.92.242.176, 52.92.224.128, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.240.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253651 (248K) [binary/octet-stream]
# Saving to: ‘NA18970_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18970_hap1_hprc_r 100%[===================>] 247.71K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:30:06 (3.80 MB/s) - ‘NA18970_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [253651/253651]
#
# --2025-03-10 11:30:06--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18970/assemblies/freeze_2/annotation/censat/NA18970_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.240.24, 52.92.206.152, 52.92.128.120, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.240.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 277087 (271K) [binary/octet-stream]
# Saving to: ‘NA18970_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18970_hap2_hprc_r 100%[===================>] 270.59K  --.-KB/s    in 0.09s
#
# 2025-03-10 11:30:07 (3.11 MB/s) - ‘NA18970_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [277087/277087]
#
# --2025-03-10 11:30:07--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18982/assemblies/freeze_2/annotation/censat/NA18982_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.56, 52.92.234.88, 52.92.234.232, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 285660 (279K) [binary/octet-stream]
# Saving to: ‘NA18982_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18982_hap1_hprc_r 100%[===================>] 278.96K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:07 (3.60 MB/s) - ‘NA18982_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [285660/285660]
#
# --2025-03-10 11:30:07--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA18982/assemblies/freeze_2/annotation/censat/NA18982_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.179.88, 52.92.132.56, 52.92.209.168, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.179.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 232886 (227K) [binary/octet-stream]
# Saving to: ‘NA18982_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA18982_hap2_hprc_r 100%[===================>] 227.43K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:08 (2.65 MB/s) - ‘NA18982_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [232886/232886]
#
# --2025-03-10 11:30:08--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20503/assemblies/freeze_2/annotation/censat/NA20503_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.209.168, 52.92.132.56, 52.92.179.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.209.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 241460 (236K) [binary/octet-stream]
# Saving to: ‘NA20503_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20503_hap1_hprc_r 100%[===================>] 235.80K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:30:09 (3.73 MB/s) - ‘NA20503_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [241460/241460]
#
# --2025-03-10 11:30:09--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20503/assemblies/freeze_2/annotation/censat/NA20503_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.132.80, 52.92.132.56, 52.92.179.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.132.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238899 (233K) [binary/octet-stream]
# Saving to: ‘NA20503_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20503_hap2_hprc_r 100%[===================>] 233.30K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:09 (2.77 MB/s) - ‘NA20503_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [238899/238899]
#
# --2025-03-10 11:30:10--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20762/assemblies/freeze_2/annotation/censat/NA20762_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.234.88, 52.92.209.168, 52.92.179.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.234.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 266051 (260K) [binary/octet-stream]
# Saving to: ‘NA20762_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20762_hap1_hprc_r 100%[===================>] 259.82K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:10 (3.02 MB/s) - ‘NA20762_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [266051/266051]
#
# --2025-03-10 11:30:10--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20762/assemblies/freeze_2/annotation/censat/NA20762_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.144.200, 52.92.132.56, 52.92.132.80, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.144.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238625 (233K) [binary/octet-stream]
# Saving to: ‘NA20762_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20762_hap2_hprc_r 100%[===================>] 233.03K  --.-KB/s    in 0.07s
#
# 2025-03-10 11:30:11 (3.09 MB/s) - ‘NA20762_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [238625/238625]
#
# --2025-03-10 11:30:11--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20806/assemblies/freeze_2/annotation/censat/NA20806_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.209.168, 52.92.234.88, 52.92.144.200, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.209.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267828 (262K) [binary/octet-stream]
# Saving to: ‘NA20806_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20806_hap1_hprc_r 100%[===================>] 261.55K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:30:12 (4.07 MB/s) - ‘NA20806_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [267828/267828]
#
# --2025-03-10 11:30:12--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20806/assemblies/freeze_2/annotation/censat/NA20806_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.234.232, 52.92.132.80, 52.92.179.88, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.234.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247181 (241K) [binary/octet-stream]
# Saving to: ‘NA20806_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20806_hap2_hprc_r 100%[===================>] 241.39K  --.-KB/s    in 0.08s
#
# 2025-03-10 11:30:12 (2.83 MB/s) - ‘NA20806_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [247181/247181]
#
# --2025-03-10 11:30:13--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20827/assemblies/freeze_2/annotation/censat/NA20827_hap1_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.232.96, 52.92.207.192, 52.92.241.208, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.232.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247874 (242K) [binary/octet-stream]
# Saving to: ‘NA20827_hap1_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20827_hap1_hprc_r 100%[===================>] 242.06K  --.-KB/s    in 0.07s
#
# 2025-03-10 11:30:13 (3.48 MB/s) - ‘NA20827_hap1_hprc_r2_v1.0.1.cenSat.bed.1’ saved [247874/247874]
#
# --2025-03-10 11:30:13--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/NA20827/assemblies/freeze_2/annotation/censat/NA20827_hap2_hprc_r2_v1.0.1.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.207.192, 52.92.201.8, 52.92.241.208, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.207.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248055 (242K) [binary/octet-stream]
# Saving to: ‘NA20827_hap2_hprc_r2_v1.0.1.cenSat.bed.1’
#
# NA20827_hap2_hprc_r 100%[===================>] 242.24K  --.-KB/s    in 0.09s
#
# 2025-03-10 11:30:14 (2.78 MB/s) - ‘NA20827_hap2_hprc_r2_v1.0.1.cenSat.bed.1’ saved [248055/248055]
#
# --2025-03-10 11:30:14--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG06807/assemblies/freeze_2/annotation/censat/HG06807_pat_v1.0.genbank.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.209.160, 52.92.241.208, 52.92.207.192, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.209.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246725 (241K) [binary/octet-stream]
# Saving to: ‘HG06807_pat_v1.0.genbank.cenSat.bed.1’
#
# HG06807_pat_v1.0.ge 100%[===================>] 240.94K  --.-KB/s    in 0.1s
#
# 2025-03-10 11:30:15 (2.29 MB/s) - ‘HG06807_pat_v1.0.genbank.cenSat.bed.1’ saved [246725/246725]
#
# --2025-03-10 11:30:15--  https://s3-us-west-2.amazonaws.com/human-pangenomics/submissions/DC27718F-5F38-43B0-9A78-270F395F13E8--INT_ASM_PRODUCTION/HG06807/assemblies/freeze_2/annotation/censat/HG06807_mat_v1.0.genbank.cenSat.bed
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.209.160, 52.218.232.96, 52.92.201.8, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.209.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250116 (244K) [binary/octet-stream]
# Saving to: ‘HG06807_mat_v1.0.genbank.cenSat.bed.1’
#
# HG06807_mat_v1.0.ge 100%[===================>] 244.25K  --.-KB/s    in 0.06s
#
# 2025-03-10 11:30:15 (3.85 MB/s) - ‘HG06807_mat_v1.0.genbank.cenSat.bed.1’ saved [250116/250116]
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
censat_table_diploid_batch3.head()
# Out:
#   sample_id                             cenSatAnnotations_hap1  \
# 0   HG01109  https://s3-us-west-2.amazonaws.com/human-pange...
# 1   HG02055  https://s3-us-west-2.amazonaws.com/human-pange...
# 2   HG02080  https://s3-us-west-2.amazonaws.com/human-pange...
# 3   HG02109  https://s3-us-west-2.amazonaws.com/human-pange...
# 4   HG02723  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                               cenSatAnnotations_hap2  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                         additional_annotations_array
# 0  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...

# %% [markdown]
# ## Merge censat and assembly tables

# %%
assembly_and_censat_table_batch3 = pd.merge(assembly_pre_release_diploid, 
                                            censat_table_diploid_batch3, 
                                            on='sample_id',  
                                            how='inner')

# %%
assembly_and_censat_table_batch3.head()
# Out:
#   sample_id                                      assembly_hap1  \
# 0   NA20752  s3://human-pangenomics/submissions/DC27718F-5F...
# 1   HG02145  s3://human-pangenomics/submissions/DC27718F-5F...
# 2   HG02027  s3://human-pangenomics/submissions/DC27718F-5F...
# 3   NA19159  s3://human-pangenomics/submissions/DC27718F-5F...
# 4   HG01786  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                        assembly_hap2  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                               cenSatAnnotations_hap1  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                               cenSatAnnotations_hap2  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                         additional_annotations_array
# 0  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...

# %% [markdown]
# ## Make a HiFi data table

# %%
print("Assembly+Censat Table {} out of {} exist for HiFi".format(len(set(assembly_and_censat_table_batch3['sample_id']).intersection(new_samples_hifi)),
                                                                  len(new_samples_hifi)))
# Out:
# Assembly+Censat Table 19 out of 19 exist for HiFi

# %%
print("These samples are missing for HiFi")
missing_samples = set(new_samples_hifi).difference(set(merged_hifi_full_table['sample_id']))
missing_samples
# Out:
# These samples are missing for HiFi
# {'HG005', 'NA20503', 'NA20762', 'NA20806', 'NA20827'}

# %%
hifi_data_table_batch3 = pd.merge(assembly_and_censat_table_batch3, 
                                  merged_hifi_full_table, 
                                  on='sample_id',  
                                  how='inner')
hifi_data_table_batch3 = hifi_data_table_batch3[hifi_data_table_batch3['sample_id'].isin(new_samples_hifi)]

# %%
hifi_data_table_batch3.index = np.arange(len(hifi_data_table_batch3))

# %%
print("Number of rows in the final data table for HiFi : ", len(hifi_data_table_batch3))
# Out:
# Number of rows in the final data table for HiFi :  14

# %%
columns_to_keep = ['sample_id',
                   'assembly_hap1', 
                   'assembly_hap2',
                   'cenSatAnnotations_hap1',
                   'cenSatAnnotations_hap2',
                   'censat_diploid_bed',
                   'additional_annotations_array', 'read_files',
                   'coverage','platform', 'total_coverage', 'number_of_read_files',
                   'number_of_cores_per_task', 'mapper_preset', 'kmer_size',
                   'hmm_flagger_preset', 'read_files_downsampled',
                   'total_coverage_downsampled', 'number_of_read_files_downsampled',
                   'number_of_cores_per_task_downsampled']

# %%
hifi_data_table_batch3 = hifi_data_table_batch3[columns_to_keep]

# %% [markdown]
# ## Make a HiFi (DeepConsensus) data table

# %% [markdown]
# Those 5 missing samples should exist in the DeepConsensus table.

# %%
hifi_dc_data_table_batch3 = pd.merge(assembly_and_censat_table_batch3, 
                                     merged_hifi_dc_full_table, 
                                     on='sample_id',  
                                     how='inner')
hifi_dc_data_table_batch3 = hifi_dc_data_table_batch3[hifi_dc_data_table_batch3['sample_id'].isin(missing_samples)]

# %%
hifi_dc_data_table_batch3 = hifi_dc_data_table_batch3[columns_to_keep]
hifi_dc_data_table_batch3.index = np.arange(len(hifi_dc_data_table_batch3))

# %%
hifi_dc_data_table_batch3
# Out:
#   sample_id                                      assembly_hap1  \
# 0     HG005  s3://human-pangenomics/submissions/DC27718F-5F...
# 1   NA20503  s3://human-pangenomics/submissions/DC27718F-5F...
# 2   NA20762  s3://human-pangenomics/submissions/DC27718F-5F...
# 3   NA20806  s3://human-pangenomics/submissions/DC27718F-5F...
# 4   NA20827  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                        assembly_hap2  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                               cenSatAnnotations_hap1  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                               cenSatAnnotations_hap2  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                         additional_annotations_array  \
# 0  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                           read_files  \
# 0  [s3://human-pangenomics/submissions/FFC78D9F-2...
# 1  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 2  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 3  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 4  [s3://human-pangenomics/submissions/82BE5FDF-1...
#
#                                coverage                             platform  \
# 0  [8.4, 7.7, 6.6, 5.0, 10.2, 9.6, 9.4]  [nan, nan, nan, nan, nan, nan, nan]
# 1                                [41.7]                                [nan]
# 2                                [45.7]                                [nan]
# 3                                [47.0]                                [nan]
# 4                                [48.9]                                [nan]
#
#    total_coverage  number_of_read_files  number_of_cores_per_task  \
# 0            56.9                     7                         9
# 1            41.7                     1                        64
# 2            45.7                     1                        64
# 3            47.0                     1                        64
# 4            48.9                     1                        64
#
#   mapper_preset  kmer_size hmm_flagger_preset  \
# 0       lr:hqae         25               hifi
# 1       lr:hqae         25               hifi
# 2       lr:hqae         25               hifi
# 3       lr:hqae         25               hifi
# 4       lr:hqae         25               hifi
#
#                               read_files_downsampled  \
# 0  [s3://human-pangenomics/submissions/FFC78D9F-2...
# 1  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 2  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 3  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 4  [s3://human-pangenomics/submissions/82BE5FDF-1...
#
#    total_coverage_downsampled  number_of_read_files_downsampled  \
# 0                        56.9                                 7
# 1                        41.7                                 1
# 2                        45.7                                 1
# 3                        47.0                                 1
# 4                        48.9                                 1
#
#    number_of_cores_per_task_downsampled
# 0                                     9
# 1                                    64
# 2                                    64
# 3                                    64
# 4                                    64

# %%
# concat deepconsensus-only samples to the hifi table
hifi_data_table_batch3 = pd.concat([hifi_dc_data_table_batch3, hifi_data_table_batch3])
hifi_data_table_batch3.index = np.arange(len(hifi_data_table_batch3))
hifi_data_table_batch3
# Out:
#    sample_id                                      assembly_hap1  \
# 0      HG005  s3://human-pangenomics/submissions/DC27718F-5F...
# 1    NA20503  s3://human-pangenomics/submissions/DC27718F-5F...
# 2    NA20762  s3://human-pangenomics/submissions/DC27718F-5F...
# 3    NA20806  s3://human-pangenomics/submissions/DC27718F-5F...
# 4    NA20827  s3://human-pangenomics/submissions/DC27718F-5F...
# 5    HG02027  s3://human-pangenomics/submissions/DC27718F-5F...
# 6    HG01786  s3://human-pangenomics/submissions/DC27718F-5F...
# 7    HG00733  s3://human-pangenomics/submissions/DC27718F-5F...
# 8    NA18940  s3://human-pangenomics/submissions/DC27718F-5F...
# 9    NA18943  s3://human-pangenomics/submissions/DC27718F-5F...
# 10   NA18944  s3://human-pangenomics/submissions/DC27718F-5F...
# 11   NA18945  s3://human-pangenomics/submissions/DC27718F-5F...
# 12   NA18948  s3://human-pangenomics/submissions/DC27718F-5F...
# 13   NA18959  s3://human-pangenomics/submissions/DC27718F-5F...
# 14   NA18960  s3://human-pangenomics/submissions/DC27718F-5F...
# 15   NA18967  s3://human-pangenomics/submissions/DC27718F-5F...
# 16   NA18970  s3://human-pangenomics/submissions/DC27718F-5F...
# 17   NA18982  s3://human-pangenomics/submissions/DC27718F-5F...
# 18   HG06807  s3://human-pangenomics/working/HPRC_PLUS/HG068...
#
#                                         assembly_hap2  \
# 0   s3://human-pangenomics/submissions/DC27718F-5F...
# 1   s3://human-pangenomics/submissions/DC27718F-5F...
# 2   s3://human-pangenomics/submissions/DC27718F-5F...
# 3   s3://human-pangenomics/submissions/DC27718F-5F...
# 4   s3://human-pangenomics/submissions/DC27718F-5F...
# 5   s3://human-pangenomics/submissions/DC27718F-5F...
# 6   s3://human-pangenomics/submissions/DC27718F-5F...
# 7   s3://human-pangenomics/submissions/DC27718F-5F...
# 8   s3://human-pangenomics/submissions/DC27718F-5F...
# 9   s3://human-pangenomics/submissions/DC27718F-5F...
# 10  s3://human-pangenomics/submissions/DC27718F-5F...
# 11  s3://human-pangenomics/submissions/DC27718F-5F...
# 12  s3://human-pangenomics/submissions/DC27718F-5F...
# 13  s3://human-pangenomics/submissions/DC27718F-5F...
# 14  s3://human-pangenomics/submissions/DC27718F-5F...
# 15  s3://human-pangenomics/submissions/DC27718F-5F...
# 16  s3://human-pangenomics/submissions/DC27718F-5F...
# 17  s3://human-pangenomics/submissions/DC27718F-5F...
# 18  s3://human-pangenomics/working/HPRC_PLUS/HG068...
#
#                                cenSatAnnotations_hap1  \
# 0   https://s3-us-west-2.amazonaws.com/human-pange...
# 1   https://s3-us-west-2.amazonaws.com/human-pange...
# 2   https://s3-us-west-2.amazonaws.com/human-pange...
# 3   https://s3-us-west-2.amazonaws.com/human-pange...
# 4   https://s3-us-west-2.amazonaws.com/human-pange...
# 5   https://s3-us-west-2.amazonaws.com/human-pange...
# 6   https://s3-us-west-2.amazonaws.com/human-pange...
# 7   https://s3-us-west-2.amazonaws.com/human-pange...
# 8   https://s3-us-west-2.amazonaws.com/human-pange...
# 9   https://s3-us-west-2.amazonaws.com/human-pange...
# 10  https://s3-us-west-2.amazonaws.com/human-pange...
# 11  https://s3-us-west-2.amazonaws.com/human-pange...
# 12  https://s3-us-west-2.amazonaws.com/human-pange...
# 13  https://s3-us-west-2.amazonaws.com/human-pange...
# 14  https://s3-us-west-2.amazonaws.com/human-pange...
# 15  https://s3-us-west-2.amazonaws.com/human-pange...
# 16  https://s3-us-west-2.amazonaws.com/human-pange...
# 17  https://s3-us-west-2.amazonaws.com/human-pange...
# 18  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                cenSatAnnotations_hap2  \
# 0   https://s3-us-west-2.amazonaws.com/human-pange...
# 1   https://s3-us-west-2.amazonaws.com/human-pange...
# 2   https://s3-us-west-2.amazonaws.com/human-pange...
# 3   https://s3-us-west-2.amazonaws.com/human-pange...
# 4   https://s3-us-west-2.amazonaws.com/human-pange...
# 5   https://s3-us-west-2.amazonaws.com/human-pange...
# 6   https://s3-us-west-2.amazonaws.com/human-pange...
# 7   https://s3-us-west-2.amazonaws.com/human-pange...
# 8   https://s3-us-west-2.amazonaws.com/human-pange...
# 9   https://s3-us-west-2.amazonaws.com/human-pange...
# 10  https://s3-us-west-2.amazonaws.com/human-pange...
# 11  https://s3-us-west-2.amazonaws.com/human-pange...
# 12  https://s3-us-west-2.amazonaws.com/human-pange...
# 13  https://s3-us-west-2.amazonaws.com/human-pange...
# 14  https://s3-us-west-2.amazonaws.com/human-pange...
# 15  https://s3-us-west-2.amazonaws.com/human-pange...
# 16  https://s3-us-west-2.amazonaws.com/human-pange...
# 17  https://s3-us-west-2.amazonaws.com/human-pange...
# 18  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                    censat_diploid_bed  \
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                          additional_annotations_array  \
# 0   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 5   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 6   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 7   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 8   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 9   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 10  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 11  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 12  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 13  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 14  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 15  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 16  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 17  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 18  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                            read_files  \
# 0   [s3://human-pangenomics/submissions/FFC78D9F-2...
# 1   [s3://human-pangenomics/submissions/82BE5FDF-1...
# 2   [s3://human-pangenomics/submissions/82BE5FDF-1...
# 3   [s3://human-pangenomics/submissions/82BE5FDF-1...
# 4   [s3://human-pangenomics/submissions/82BE5FDF-1...
# 5   [s3://human-pangenomics/working/HPRC/HG02027/r...
# 6   [s3://human-pangenomics/working/HPRC/HG01786/r...
# 7   [s3://human-pangenomics/working/HPRC_PLUS/HG00...
# 8   [s3://human-pangenomics/submissions/B25289BC-5...
# 9   [s3://human-pangenomics/submissions/B25289BC-5...
# 10  [s3://human-pangenomics/submissions/B25289BC-5...
# 11  [s3://human-pangenomics/submissions/B25289BC-5...
# 12  [s3://human-pangenomics/submissions/B25289BC-5...
# 13  [s3://human-pangenomics/submissions/B25289BC-5...
# 14  [s3://human-pangenomics/submissions/B25289BC-5...
# 15  [s3://human-pangenomics/submissions/B25289BC-5...
# 16  [s3://human-pangenomics/submissions/B25289BC-5...
# 17  [s3://human-pangenomics/submissions/B25289BC-5...
# 18  [s3://human-pangenomics/working/HPRC_PLUS/HG06...
#
#                                 coverage  \
# 0   [8.4, 7.7, 6.6, 5.0, 10.2, 9.6, 9.4]
# 1                                 [41.7]
# 2                                 [45.7]
# 3                                 [47.0]
# 4                                 [48.9]
# 5     [9.2, 8.9, 11.1, 10.3, 10.8, 10.6]
# 6                           [36.5, 37.1]
# 7         [13.4, 12.7, 13.9, 12.9, 13.2]
# 8                 [9.2, 11.1, 9.5, 10.2]
# 9                [9.5, 11.0, 10.1, 10.1]
# 10                  [9.7, 9.9, 7.5, 8.2]
# 11                [11.0, 11.7, 9.1, 7.9]
# 12                 [8.9, 9.7, 9.5, 10.3]
# 13                 [6.4, 10.2, 9.5, 9.7]
# 14              [11.8, 12.4, 12.7, 12.8]
# 15               [11.5, 13.1, 13.2, 9.7]
# 16              [13.8, 14.1, 13.4, 13.6]
# 17              [11.1, 12.0, 12.0, 12.3]
# 18                          [10.6, 12.2]
#
#                                              platform  total_coverage  \
# 0                 [nan, nan, nan, nan, nan, nan, nan]            56.9
# 1                                               [nan]            41.7
# 2                                               [nan]            45.7
# 3                                               [nan]            47.0
# 4                                               [nan]            48.9
# 5   [PACBIO_SMRT, PACBIO_SMRT, PACBIO_SMRT, PACBIO...            60.9
# 6                          [PACBIO_SMRT, PACBIO_SMRT]            73.6
# 7                           [nan, nan, nan, nan, nan]            66.1
# 8                                [nan, nan, nan, nan]            40.0
# 9                                [nan, nan, nan, nan]            40.7
# 10                               [nan, nan, nan, nan]            35.3
# 11                               [nan, nan, nan, nan]            39.7
# 12                               [nan, nan, nan, nan]            38.4
# 13                               [nan, nan, nan, nan]            35.8
# 14                               [nan, nan, nan, nan]            49.7
# 15                               [nan, nan, nan, nan]            47.5
# 16                               [nan, nan, nan, nan]            54.9
# 17                               [nan, nan, nan, nan]            47.4
# 18                         [PACBIO_SMRT, PACBIO_SMRT]            22.8
#
#     number_of_read_files  number_of_cores_per_task mapper_preset  kmer_size  \
# 0                      7                         9       lr:hqae         25
# 1                      1                        64       lr:hqae         25
# 2                      1                        64       lr:hqae         25
# 3                      1                        64       lr:hqae         25
# 4                      1                        64       lr:hqae         25
# 5                      6                        10       lr:hqae         25
# 6                      2                        32       lr:hqae         25
# 7                      5                        12       lr:hqae         25
# 8                      4                        16       lr:hqae         25
# 9                      4                        16       lr:hqae         25
# 10                     4                        16       lr:hqae         25
# 11                     4                        16       lr:hqae         25
# 12                     4                        16       lr:hqae         25
# 13                     4                        16       lr:hqae         25
# 14                     4                        16       lr:hqae         25
# 15                     4                        16       lr:hqae         25
# 16                     4                        16       lr:hqae         25
# 17                     4                        16       lr:hqae         25
# 18                     2                        32       lr:hqae         25
#
#    hmm_flagger_preset                             read_files_downsampled  \
# 0                hifi  [s3://human-pangenomics/submissions/FFC78D9F-2...
# 1                hifi  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 2                hifi  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 3                hifi  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 4                hifi  [s3://human-pangenomics/submissions/82BE5FDF-1...
# 5                hifi  [s3://human-pangenomics/working/HPRC/HG02027/r...
# 6                hifi  [s3://human-pangenomics/working/HPRC/HG01786/r...
# 7                hifi  [s3://human-pangenomics/working/HPRC_PLUS/HG00...
# 8                hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 9                hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 10               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 11               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 12               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 13               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 14               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 15               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 16               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 17               hifi  [s3://human-pangenomics/submissions/B25289BC-5...
# 18               hifi  [s3://human-pangenomics/working/HPRC_PLUS/HG06...
#
#     total_coverage_downsampled  number_of_read_files_downsampled  \
# 0                         56.9                                 7
# 1                         41.7                                 1
# 2                         45.7                                 1
# 3                         47.0                                 1
# 4                         48.9                                 1
# 5                         60.9                                 6
# 6                         73.6                                 2
# 7                         66.1                                 5
# 8                         40.0                                 4
# 9                         40.7                                 4
# 10                        35.3                                 4
# 11                        39.7                                 4
# 12                        38.4                                 4
# 13                        35.8                                 4
# 14                        49.7                                 4
# 15                        47.5                                 4
# 16                        54.9                                 4
# 17                        47.4                                 4
# 18                        22.8                                 2
#
#     number_of_cores_per_task_downsampled
# 0                                      9
# 1                                     64
# 2                                     64
# 3                                     64
# 4                                     64
# 5                                     10
# 6                                     32
# 7                                     12
# 8                                     16
# 9                                     16
# 10                                    16
# 11                                    16
# 12                                    16
# 13                                    16
# 14                                    16
# 15                                    16
# 16                                    16
# 17                                    16
# 18                                    32

# %% [markdown]
# ## Make a ONT data table

# %%
print("Assembly+Censat Table {} out of {} exist for ONT".format(len(set(assembly_and_censat_table_batch3['sample_id']).intersection(new_samples_ont)),
                                                                len(new_samples_ont)))
# Out:
# Assembly+Censat Table 36 out of 36 exist for ONT

# %%
print("These samples are missing for ONT")
set(new_samples_ont).difference(set(merged_ont_full_table['sample_id']))
# Out:
# These samples are missing for ONT
# set()

# %%
ont_data_table_batch3 = pd.merge(assembly_and_censat_table_batch3, 
                                 merged_ont_full_table, 
                                 on='sample_id',  
                                 how='inner')
ont_data_table_batch3 = ont_data_table_batch3[ont_data_table_batch3['sample_id'].isin(new_samples_ont)]

# %%
ont_data_table_batch3.index = np.arange(len(ont_data_table_batch3))

# %%
print("Number of rows in the final data table for ONT : ", len(ont_data_table_batch3))
# Out:
# Number of rows in the final data table for ONT :  36

# %%
columns_to_kepp = ['sample_id', 
 'assembly_hap1', 
 'assembly_hap2', 
 'cenSatAnnotations_hap1',
 'cenSatAnnotations_hap2',
 'censat_diploid_bed',
 'additional_annotations_array',
 'read_files','coverage',
 'sequencing_chemistry', 'total_coverage', 'number_of_read_files',
 'number_of_cores_per_task', 'mapper_preset', 'kmer_size',
 'hmm_flagger_preset', 'read_files_downsampled',
 'total_coverage_downsampled', 'number_of_read_files_downsampled',
 'number_of_cores_per_task_downsampled']

# %%
ont_data_table_batch3 = ont_data_table_batch3[columns_to_keep]

# %% [markdown]
# ## Save the final data tables

# %%
os.makedirs("ont", exist_ok=True)
ont_data_table_batch3.to_csv('ont/hmm_flagger_ont_data_table.csv', index=False)

os.makedirs("hifi", exist_ok=True)
hifi_data_table_batch3.to_csv('hifi/hmm_flagger_hifi_data_table.csv', index=False)
