# %%
import numpy as np
import pandas as pd
import sys
import os
import re

# %% [markdown]
# This notebook:
# - Opens ONT and HiFi index files
# - Makes a new table with only one sample per row and the corresponding reads saved in an array
# - ONT_R9, ONT_R10 and HiFi reads have different configs (window size and alpha tsv) for hmm-flagger. Creates columns for saving these attributes
# - It assumes that each mapping will be run in a 64 core machine so the number of tasks for mapping each file will be computed by dividing 64 by number of files
# - Some samples might have very high coverage. It lists ONT files based on coverage and keeps the files untill it reaches 60x and ignores the rest. These file arrays are saved in the column ending with "_downsampled"
# - kmer size and mapping preset will be set based on sequencing platform (HiFi and ONT_R10: minimap2 (lr:hqae,k=25), ONT_R9 minimap2 (map-ont,k=15) )
#
# Comment Jan 12 2025
# - Initially I used `HPRC_DeepConsensus.file.index.csv`. Some samples are missed in that csv file so I will pull `HPRC_PacBio_HiFi.file.index.csv` from https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/main/data/hprc-data-explorer-tables/HPRC_PacBio_HiFi.file.index.csv
# and updates `hifi_reads_table.csv` with new samples that were missed in the previous version.

# %%
os.getcwd()
# Out:
# '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables'

# %%
alpha_tsv_ont_r9 = "https://raw.githubusercontent.com/mobinasri/flagger/refs/heads/main/misc/alpha_tsv/ONT_R941_Guppy6.3.7/alpha_optimum_trunc_exp_gaussian_w_16000_n_50.ONT_R941_Guppy6.3.7_DEC_2024.v1.1.0.tsv"
alpha_tsv_ont_r10 = "https://raw.githubusercontent.com/mobinasri/flagger/refs/heads/main/misc/alpha_tsv/ONT_R1041_Dorado/alpha_optimum_trunc_exp_gaussian_w_8000_n_50.ONT_R1041_Dorado_DEC_2024.v1.1.0.tsv"
alpha_tsv_hifi = "https://raw.githubusercontent.com/mobinasri/flagger/refs/heads/main/misc/alpha_tsv/HiFi_DC_1.2/alpha_optimum_trunc_exp_gaussian_w_16000_n_50.HiFi_DC_1.2_DEC_2024.v1.1.0.tsv"
window_size_ont_r9 = 16000
window_size_ont_r10 = 8000
window_size_hifi = 16000

# %%
# download csv files
#!wget https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/v2-release/data/hprc-data-explorer-tables/HPRC_DeepConsensus.file.index.csv
#!wget https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/v2-release/data/hprc-data-explorer-tables/HPRC_ONT.file.index.csv    
#!wget https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/main/data/hprc-data-explorer-tables/HPRC_PacBio_HiFi.file.index.csv

# %%
ont_table = pd.read_csv('HPRC_ONT.file.index.csv')
hifi_dc_table = pd.read_csv('HPRC_DeepConsensus.file.index.csv')

# %%
len(hifi_dc_table)
# Out:
# 642

# %%
totalCores = 64
# merge ont table
merged_ont_table = ont_table.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_ont_table.rename(columns={"sample_ID": "sample_id"} ,inplace=True)
merged_ont_table.rename(columns={"path": "read_files"}, inplace=True)
merged_ont_table["total_coverage"] = merged_ont_table["coverage"].apply(sum).apply(lambda x: round(x,2))
merged_ont_table["sequencing_chemistry"] = merged_ont_table["sequencing_chemistry"].apply(lambda x : x[0 ]if len(set(x)) == 1 else ",".join(set(x)))
merged_ont_table["number_of_read_files"] = merged_ont_table["read_files"].apply(len)
merged_ont_table["number_of_cores_per_task"] = (totalCores / merged_ont_table["number_of_read_files"]).astype(int)
merged_ont_table['number_of_cores_per_task'] = merged_ont_table['number_of_cores_per_task'].apply(lambda x: max(4,x))

# preset for R1041 is lr:hqae
# preset for R941 is map-ont
merged_ont_table["mapper_preset"] = ""
merged_ont_table["mapper_preset"][merged_ont_table["sequencing_chemistry"] == "R1041"] = "lr:hqae"
merged_ont_table["mapper_preset"][merged_ont_table["sequencing_chemistry"] == "R941"] = "map-ont"
merged_ont_table["kmer_size"] = 0
merged_ont_table["kmer_size"][merged_ont_table["sequencing_chemistry"] == "R1041"] = 25
merged_ont_table["kmer_size"][merged_ont_table["sequencing_chemistry"] == "R941"] = 15

merged_ont_table["hmm_flagger_window_size"] = 0
merged_ont_table["hmm_flagger_window_size"][merged_ont_table["sequencing_chemistry"] == "R1041"] = 8000
merged_ont_table["hmm_flagger_window_size"][merged_ont_table["sequencing_chemistry"] == "R941"] = 16000

merged_ont_table["hmm_flagger_alpha_tsv"] = ""
merged_ont_table["hmm_flagger_alpha_tsv"][merged_ont_table["sequencing_chemistry"] == "R1041"] = alpha_tsv_ont_r10
merged_ont_table["hmm_flagger_alpha_tsv"][merged_ont_table["sequencing_chemistry"] == "R941"] = alpha_tsv_ont_r9


# merge hifi dc table
merged_hifi_dc_table = hifi_dc_table.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_hifi_dc_table.rename(columns={"sample_ID": "sample_id"}, inplace=True)
merged_hifi_dc_table.rename(columns={"path": "read_files"}, inplace=True)
merged_hifi_dc_table["total_coverage"] = merged_hifi_dc_table["coverage"].apply(sum)
merged_hifi_dc_table["number_of_read_files"] = merged_hifi_dc_table["read_files"].apply(len)
merged_hifi_dc_table["number_of_cores_per_task"] = (totalCores / merged_hifi_dc_table["number_of_read_files"]).astype(int)
merged_hifi_dc_table['number_of_cores_per_task'] = merged_hifi_dc_table['number_of_cores_per_task'].apply(lambda x: max(4,x))
merged_hifi_dc_table["mapper_preset"] = "lr:hqae"
merged_hifi_dc_table["kmer_size"] = 25

merged_hifi_dc_table["hmm_flagger_window_size"] = window_size_hifi
merged_hifi_dc_table["hmm_flagger_alpha_tsv"] = alpha_tsv_hifi
# Out:
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(merged_ont_table)
# Out:
# 258

# %%
len(merged_hifi_dc_table)
# Out:
# 166

# %% [markdown]
# Since total ONT coverage for some samples are very high and we don't need coverage higher than 60x, here I sort the read files by coverage from high to low and keep the file untill the total coverage goes above 60x and ignore the rest of the files.

# %%
merged_ont_table["read_files_downsampled"] = [[] for _ in range(len(merged_ont_table))]
merged_ont_table["total_coverage_downsampled"] = 0

for i in range(merged_ont_table.shape[0]):
    coverages = merged_ont_table["coverage"][i]
    paths = merged_ont_table["read_files"][i]
    coverage_path_tuples = [(c, p) for c, p in zip(coverages, paths)]
    coverage_path_tuples.sort(key=lambda x: x[0], reverse=True)
    summed_coverage = 0
    downsampled_paths = []
    for j in range(len(coverage_path_tuples)):
        summed_coverage += coverage_path_tuples[j][0]
        merged_ont_table.loc[i, "read_files_downsampled"].append(coverage_path_tuples[j][1])
        if summed_coverage >= 60:
            break
    merged_ont_table.loc[i, "total_coverage_downsampled"] = round(summed_coverage,2)

merged_ont_table["number_of_read_files_downsampled"] = merged_ont_table["read_files_downsampled"].apply(len)
merged_ont_table["number_of_cores_per_task_downsampled"] = (totalCores / merged_ont_table["number_of_read_files_downsampled"]).astype(int)
merged_ont_table['number_of_cores_per_task_downsampled'] = merged_ont_table['number_of_cores_per_task_downsampled'].apply(lambda x: max(4,x))

# %%
merged_ont_table = merged_ont_table[["sample_id",  
                                     "read_files_downsampled", 
                                     "number_of_read_files_downsampled", 
                                     "total_coverage_downsampled", 
                                     "number_of_cores_per_task_downsampled", 
                                     "mapper_preset", 
                                     "kmer_size", 
                                     "read_files", 
                                     "number_of_read_files", 
                                     "total_coverage", 
                                     "coverage", 
                                     "number_of_cores_per_task", 
                                     "sequencing_chemistry",
                                     "hmm_flagger_window_size",
                                     "hmm_flagger_alpha_tsv"]]
merged_ont_table
# Out:
#     sample_id                             read_files_downsampled  \
# 0     GM18522  [s3://human-pangenomics/working/HPRC/NA18522/r...
# 1     GM18570  [s3://human-pangenomics/working/HPRC/NA18570/r...
# 2     GM18612  [s3://human-pangenomics/working/HPRC/NA18612/r...
# 3     GM18747  [s3://human-pangenomics/working/HPRC/NA18747/r...
# 4     GM18971  [s3://human-pangenomics/working/HPRC/NA18971/r...
# 5     GM18983  [s3://human-pangenomics/working/HPRC/NA18983/r...
# 6     GM19043  [s3://human-pangenomics/working/HPRC/NA19043/r...
# 7     GM19087  [s3://human-pangenomics/working/HPRC/NA19087/r...
# 8     GM19120  [s3://human-pangenomics/working/HPRC/NA19120/r...
# 9     GM19159  [s3://human-pangenomics/working/HPRC/NA19159/r...
# 10    GM19185  [s3://human-pangenomics/working/HPRC/NA19185/r...
# 11    GM19338  [s3://human-pangenomics/working/HPRC/NA19338/r...
# 12    GM19391  [s3://human-pangenomics/working/HPRC/NA19391/r...
# 13    GM19468  [s3://human-pangenomics/working/HPRC/NA19468/r...
# 14    GM20752  [s3://human-pangenomics/working/HPRC/NA20752/r...
# 15    GM20799  [s3://human-pangenomics/working/HPRC/NA20799/r...
# 16    GM20805  [s3://human-pangenomics/working/HPRC/NA20805/r...
# 17    GM20858  [s3://human-pangenomics/working/HPRC/NA20858/r...
# 18    GM20905  [s3://human-pangenomics/working/HPRC/NA20905/r...
# 19    HG00097  [s3://human-pangenomics/working/HPRC/HG00097/r...
# 20    HG00099  [s3://human-pangenomics/working/HPRC/HG00099/r...
# 21    HG00106  [s3://human-pangenomics/working/HPRC/HG00106/r...
# 22    HG00117  [s3://human-pangenomics/working/HPRC/HG00117/r...
# 23    HG00126  [s3://human-pangenomics/working/HPRC/HG00126/r...
# 24    HG00128  [s3://human-pangenomics/working/HPRC/HG00128/r...
# 25    HG00133  [s3://human-pangenomics/working/HPRC/HG00133/r...
# 26    HG00140  [s3://human-pangenomics/working/HPRC/HG00140/r...
# 27    HG00146  [s3://human-pangenomics/working/HPRC/HG00146/r...
# 28    HG00232  [s3://human-pangenomics/working/HPRC/HG00232/r...
# 29    HG00235  [s3://human-pangenomics/working/HPRC/HG00235/r...
# ..        ...                                                ...
# 228   NA19175  [s3://human-pangenomics/working/HPRC/NA19175/r...
# 229   NA19190  [s3://human-pangenomics/working/HPRC/NA19190/r...
# 230   NA19315  [s3://human-pangenomics/working/HPRC/NA19315/r...
# 231   NA19377  [s3://human-pangenomics/working/HPRC/NA19377/r...
# 232   NA19390  [s3://human-pangenomics/working/HPRC/NA19390/r...
# 233   NA19443  [s3://human-pangenomics/working/HPRC/NA19443/r...
# 234   NA19682  [s3://human-pangenomics/working/HPRC/NA19682/r...
# 235   NA19700  [s3://human-pangenomics/working/HPRC/NA19700/r...
# 236   NA19703  [s3://human-pangenomics/working/HPRC/NA19703/r...
# 237   NA19776  [s3://human-pangenomics/working/HPRC/NA19776/r...
# 238   NA19834  [s3://human-pangenomics/working/HPRC/NA19834/r...
# 239   NA19835  [s3://human-pangenomics/working/HPRC/NA19835/r...
# 240   NA19909  [s3://human-pangenomics/working/HPRC/NA19909/r...
# 241   NA20282  [s3://human-pangenomics/working/HPRC/NA20282/r...
# 242   NA20287  [s3://human-pangenomics/working/HPRC/NA20287/r...
# 243   NA20346  [s3://human-pangenomics/working/HPRC/NA20346/r...
# 244   NA20503  [s3://human-pangenomics/working/HPRC/NA20503/r...
# 245   NA20762  [s3://human-pangenomics/working/HPRC/NA20762/r...
# 246   NA20806  [s3://human-pangenomics/working/HPRC/NA20806/r...
# 247   NA20809  [s3://human-pangenomics/working/HPRC/NA20809/r...
# 248   NA20818  [s3://human-pangenomics/working/HPRC/NA20818/r...
# 249   NA20827  [s3://human-pangenomics/working/HPRC/NA20827/r...
# 250   NA20850  [s3://human-pangenomics/working/HPRC/NA20850/r...
# 251   NA20870  [s3://human-pangenomics/working/HPRC/NA20870/r...
# 252   NA21093  [s3://human-pangenomics/working/HPRC/NA21093/r...
# 253   NA21101  [s3://human-pangenomics/working/HPRC/NA21101/r...
# 254   NA21102  [s3://human-pangenomics/working/HPRC/NA21102/r...
# 255   NA21106  [s3://human-pangenomics/working/HPRC/NA21106/r...
# 256   NA21110  [s3://human-pangenomics/working/HPRC/NA21110/r...
# 257   NA21144  [s3://human-pangenomics/working/HPRC/NA21144/r...
#
#      number_of_read_files_downsampled  total_coverage_downsampled  \
# 0                                   3                       69.01
# 1                                   3                       66.22
# 2                                   3                       72.34
# 3                                   3                       75.12
# 4                                   3                       79.88
# 5                                   3                       68.10
# 6                                   3                       60.08
# 7                                   3                       72.01
# 8                                   3                       57.42
# 9                                   3                       56.33
# 10                                  3                       54.52
# 11                                  3                       65.32
# 12                                  3                       81.87
# 13                                  3                       78.16
# 14                                  3                       78.93
# 15                                  3                       58.34
# 16                                  4                       49.43
# 17                                  3                       47.06
# 18                                  3                       60.55
# 19                                  3                       57.09
# 20                                  3                       58.78
# 21                                  3                       62.87
# 22                                  3                       69.07
# 23                                  3                       70.94
# 24                                  3                       59.52
# 25                                  3                       65.96
# 26                                  3                       72.87
# 27                                  5                       65.41
# 28                                  4                       69.59
# 29                                  3                       62.86
# ..                                ...                         ...
# 228                                 2                       60.23
# 229                                 3                       83.04
# 230                                 3                       63.79
# 231                                 3                       58.97
# 232                                 3                       65.79
# 233                                 4                       61.12
# 234                                 3                       77.48
# 235                                 6                       61.70
# 236                                 3                       75.09
# 237                                 2                       61.90
# 238                                 3                       58.34
# 239                                 3                       82.96
# 240                                 3                       79.87
# 241                                 3                       68.40
# 242                                 3                       54.36
# 243                                 2                       60.02
# 244                                 3                       63.22
# 245                                 4                       67.89
# 246                                 3                       80.22
# 247                                 3                       69.93
# 248                                 3                       84.25
# 249                                 4                       75.76
# 250                                 3                       63.95
# 251                                 3                       79.27
# 252                                 3                       79.52
# 253                                 3                       65.89
# 254                                 5                       59.78
# 255                                 3                       72.34
# 256                                 3                       80.92
# 257                                 4                       68.91
#
#      number_of_cores_per_task_downsampled mapper_preset  kmer_size  \
# 0                                      21       map-ont         15
# 1                                      21       map-ont         15
# 2                                      21       map-ont         15
# 3                                      21       map-ont         15
# 4                                      21       map-ont         15
# 5                                      21       map-ont         15
# 6                                      21       map-ont         15
# 7                                      21       map-ont         15
# 8                                      21       map-ont         15
# 9                                      21       map-ont         15
# 10                                     21       map-ont         15
# 11                                     21       map-ont         15
# 12                                     21       map-ont         15
# 13                                     21       map-ont         15
# 14                                     21       map-ont         15
# 15                                     21       map-ont         15
# 16                                     16       map-ont         15
# 17                                     21       map-ont         15
# 18                                     21       map-ont         15
# 19                                     21       lr:hqae         25
# 20                                     21       map-ont         15
# 21                                     21       lr:hqae         25
# 22                                     21       lr:hqae         25
# 23                                     21       lr:hqae         25
# 24                                     21       lr:hqae         25
# 25                                     21       lr:hqae         25
# 26                                     21       map-ont         15
# 27                                     12       lr:hqae         25
# 28                                     16       lr:hqae         25
# 29                                     21       lr:hqae         25
# ..                                    ...           ...        ...
# 228                                    32       lr:hqae         25
# 229                                    21       lr:hqae         25
# 230                                    21       lr:hqae         25
# 231                                    21       lr:hqae         25
# 232                                    21       lr:hqae         25
# 233                                    16       lr:hqae         25
# 234                                    21       lr:hqae         25
# 235                                    10       lr:hqae         25
# 236                                    21       lr:hqae         25
# 237                                    32       lr:hqae         25
# 238                                    21       lr:hqae         25
# 239                                    21       lr:hqae         25
# 240                                    21       lr:hqae         25
# 241                                    21       lr:hqae         25
# 242                                    21       lr:hqae         25
# 243                                    32       lr:hqae         25
# 244                                    21       lr:hqae         25
# 245                                    16       lr:hqae         25
# 246                                    21       lr:hqae         25
# 247                                    21       lr:hqae         25
# 248                                    21       lr:hqae         25
# 249                                    16       lr:hqae         25
# 250                                    21       lr:hqae         25
# 251                                    21       lr:hqae         25
# 252                                    21       lr:hqae         25
# 253                                    21       lr:hqae         25
# 254                                    12       lr:hqae         25
# 255                                    21       lr:hqae         25
# 256                                    21       lr:hqae         25
# 257                                    16       lr:hqae         25
#
#                                             read_files  number_of_read_files  \
# 0    [s3://human-pangenomics/working/HPRC/NA18522/r...                     3
# 1    [s3://human-pangenomics/working/HPRC/NA18570/r...                     3
# 2    [s3://human-pangenomics/working/HPRC/NA18612/r...                     3
# 3    [s3://human-pangenomics/working/HPRC/NA18747/r...                     3
# 4    [s3://human-pangenomics/working/HPRC/NA18971/r...                     3
# 5    [s3://human-pangenomics/working/HPRC/NA18983/r...                     3
# 6    [s3://human-pangenomics/working/HPRC/NA19043/r...                     4
# 7    [s3://human-pangenomics/working/HPRC/NA19087/r...                     3
# 8    [s3://human-pangenomics/working/HPRC/NA19120/r...                     3
# 9    [s3://human-pangenomics/working/HPRC/NA19159/r...                     3
# 10   [s3://human-pangenomics/working/HPRC/NA19185/r...                     3
# 11   [s3://human-pangenomics/working/HPRC/NA19338/r...                     3
# 12   [s3://human-pangenomics/working/HPRC/NA19391/r...                     3
# 13   [s3://human-pangenomics/working/HPRC/NA19468/r...                     3
# 14   [s3://human-pangenomics/working/HPRC/NA20752/r...                     3
# 15   [s3://human-pangenomics/working/HPRC/NA20799/r...                     3
# 16   [s3://human-pangenomics/working/HPRC/NA20805/r...                     4
# 17   [s3://human-pangenomics/working/HPRC/NA20858/r...                     3
# 18   [s3://human-pangenomics/working/HPRC/NA20905/r...                     3
# 19   [s3://human-pangenomics/working/HPRC/HG00097/r...                     3
# 20   [s3://human-pangenomics/working/HPRC/HG00099/r...                     3
# 21   [s3://human-pangenomics/working/HPRC/HG00106/r...                     3
# 22   [s3://human-pangenomics/working/HPRC/HG00117/r...                     3
# 23   [s3://human-pangenomics/working/HPRC/HG00126/r...                     3
# 24   [s3://human-pangenomics/working/HPRC/HG00128/r...                     3
# 25   [s3://human-pangenomics/working/HPRC/HG00133/r...                     3
# 26   [s3://human-pangenomics/working/HPRC/HG00140/r...                     3
# 27   [s3://human-pangenomics/working/HPRC/HG00146/r...                     6
# 28   [s3://human-pangenomics/working/HPRC/HG00232/r...                     8
# 29   [s3://human-pangenomics/working/HPRC/HG00235/r...                     7
# ..                                                 ...                   ...
# 228  [s3://human-pangenomics/working/HPRC/NA19175/r...                     6
# 229  [s3://human-pangenomics/working/HPRC/NA19190/r...                     4
# 230  [s3://human-pangenomics/working/HPRC/NA19315/r...                     3
# 231  [s3://human-pangenomics/working/HPRC/NA19377/r...                     3
# 232  [s3://human-pangenomics/working/HPRC/NA19390/r...                     3
# 233  [s3://human-pangenomics/working/HPRC/NA19443/r...                     5
# 234  [s3://human-pangenomics/working/HPRC/NA19682/r...                     4
# 235  [s3://human-pangenomics/working/HPRC/NA19700/r...                     6
# 236  [s3://human-pangenomics/working/HPRC/NA19703/r...                     3
# 237  [s3://human-pangenomics/working/HPRC/NA19776/r...                     3
# 238  [s3://human-pangenomics/working/HPRC/NA19834/r...                     3
# 239  [s3://human-pangenomics/working/HPRC/NA19835/r...                     3
# 240  [s3://human-pangenomics/working/HPRC/NA19909/r...                     3
# 241  [s3://human-pangenomics/working/HPRC/NA20282/r...                     3
# 242  [s3://human-pangenomics/working/HPRC/NA20287/r...                     3
# 243  [s3://human-pangenomics/working/HPRC/NA20346/r...                     4
# 244  [s3://human-pangenomics/working/HPRC/NA20503/r...                     3
# 245  [s3://human-pangenomics/working/HPRC/NA20762/r...                     5
# 246  [s3://human-pangenomics/working/HPRC/NA20806/r...                     4
# 247  [s3://human-pangenomics/working/HPRC/NA20809/r...                     3
# 248  [s3://human-pangenomics/working/HPRC/NA20818/r...                     3
# 249  [s3://human-pangenomics/working/HPRC/NA20827/r...                     5
# 250  [s3://human-pangenomics/working/HPRC/NA20850/r...                     3
# 251  [s3://human-pangenomics/working/HPRC/NA20870/r...                     3
# 252  [s3://human-pangenomics/working/HPRC/NA21093/r...                     4
# 253  [s3://human-pangenomics/working/HPRC/NA21101/r...                     3
# 254  [s3://human-pangenomics/working/HPRC/NA21102/r...                     5
# 255  [s3://human-pangenomics/working/HPRC/NA21106/r...                     4
# 256  [s3://human-pangenomics/working/HPRC/NA21110/r...                     3
# 257  [s3://human-pangenomics/working/HPRC/NA21144/r...                     5
#
#      total_coverage                                           coverage  \
# 0             69.01                              [23.22, 29.67, 16.12]
# 1             66.22                               [23.54, 23.88, 18.8]
# 2             72.34                              [24.45, 19.88, 28.01]
# 3             75.12                              [24.51, 26.08, 24.53]
# 4             79.88                               [24.8, 28.49, 26.59]
# 5             68.10                               [18.63, 24.7, 24.77]
# 6             62.45                        [2.37, 21.36, 20.83, 17.89]
# 7             72.01                              [23.91, 22.89, 25.21]
# 8             57.42                              [15.45, 17.61, 24.36]
# 9             56.33                              [21.16, 18.43, 16.74]
# 10            54.52                              [18.49, 16.96, 19.07]
# 11            65.32                              [20.21, 25.57, 19.54]
# 12            81.87                              [27.12, 29.12, 25.63]
# 13            78.16                              [26.98, 25.61, 25.57]
# 14            78.93                                [27.2, 27.2, 24.53]
# 15            58.34                              [23.77, 12.85, 21.72]
# 16            49.43                        [5.16, 18.88, 15.28, 10.11]
# 17            47.06                              [17.19, 15.36, 14.51]
# 18            60.55                               [21.22, 19.23, 20.1]
# 19            57.09                              [21.08, 18.14, 17.87]
# 20            58.78                               [19.41, 19.1, 20.27]
# 21            62.87                              [20.02, 23.24, 19.61]
# 22            69.07                              [23.99, 24.55, 20.53]
# 23            70.94                              [24.61, 23.61, 22.72]
# 24            59.52                              [19.34, 22.03, 18.15]
# 25            65.96                               [22.09, 21.87, 22.0]
# 26            72.87                              [24.21, 26.01, 22.65]
# 27            75.99         [13.63, 11.42, 10.58, 15.05, 13.39, 11.92]
# 28            92.00  [19.87, 16.29, 4.31, 12.39, 19.26, 14.17, 4.11...
# 29            91.04     [23.78, 13.87, 5.26, 23.41, 4.73, 15.67, 4.32]
# ..              ...                                                ...
# 228           93.57            [1.85, 26.22, 25.67, 3.51, 34.01, 2.31]
# 229           89.60                        [28.02, 26.98, 6.56, 28.04]
# 230           63.79                               [25.0, 19.85, 18.94]
# 231           58.97                              [15.57, 22.15, 21.25]
# 232           65.79                               [21.32, 22.6, 21.87]
# 233           69.85                  [8.73, 21.44, 10.32, 18.0, 11.36]
# 234           86.82                        [18.46, 31.36, 27.66, 9.34]
# 235           61.70            [7.87, 8.02, 16.09, 10.59, 3.27, 15.86]
# 236           75.09                               [27.88, 22.81, 24.4]
# 237           90.67                              [31.98, 29.92, 28.77]
# 238           58.34                              [19.63, 19.28, 19.43]
# 239           82.96                              [25.09, 25.75, 32.12]
# 240           79.87                               [24.66, 28.6, 26.61]
# 241           68.40                              [22.21, 19.57, 26.62]
# 242           54.36                               [17.44, 19.32, 17.6]
# 243           87.35                       [29.86, 30.16, 10.88, 16.45]
# 244           63.22                                [21.8, 19.42, 22.0]
# 245           75.05                   [25.39, 7.16, 7.94, 26.01, 8.55]
# 246           95.54                       [29.73, 22.78, 15.32, 27.71]
# 247           69.93                              [20.29, 25.89, 23.75]
# 248           84.25                               [27.4, 30.54, 26.31]
# 249           84.63                 [18.95, 15.83, 8.87, 21.56, 19.42]
# 250           63.95                               [20.76, 20.89, 22.3]
# 251           79.27                              [28.34, 28.15, 22.78]
# 252           96.55                       [17.03, 28.97, 24.21, 26.34]
# 253           65.89                              [21.92, 21.22, 22.75]
# 254           59.78                   [17.81, 7.47, 18.45, 9.12, 6.93]
# 255           77.66                        [20.94, 5.32, 24.08, 27.32]
# 256           80.92                              [26.17, 24.74, 30.01]
# 257           79.03                  [10.12, 21.7, 13.14, 21.67, 12.4]
#
#      number_of_cores_per_task sequencing_chemistry  hmm_flagger_window_size  \
# 0                          21                 R941                    16000
# 1                          21                 R941                    16000
# 2                          21                 R941                    16000
# 3                          21                 R941                    16000
# 4                          21                 R941                    16000
# 5                          21                 R941                    16000
# 6                          16                 R941                    16000
# 7                          21                 R941                    16000
# 8                          21                 R941                    16000
# 9                          21                 R941                    16000
# 10                         21                 R941                    16000
# 11                         21                 R941                    16000
# 12                         21                 R941                    16000
# 13                         21                 R941                    16000
# 14                         21                 R941                    16000
# 15                         21                 R941                    16000
# 16                         16                 R941                    16000
# 17                         21                 R941                    16000
# 18                         21                 R941                    16000
# 19                         21                R1041                     8000
# 20                         21                 R941                    16000
# 21                         21                R1041                     8000
# 22                         21                R1041                     8000
# 23                         21                R1041                     8000
# 24                         21                R1041                     8000
# 25                         21                R1041                     8000
# 26                         21                 R941                    16000
# 27                         10                R1041                     8000
# 28                          8                R1041                     8000
# 29                          9                R1041                     8000
# ..                        ...                  ...                      ...
# 228                        10                R1041                     8000
# 229                        16                R1041                     8000
# 230                        21                R1041                     8000
# 231                        21                R1041                     8000
# 232                        21                R1041                     8000
# 233                        12                R1041                     8000
# 234                        16                R1041                     8000
# 235                        10                R1041                     8000
# 236                        21                R1041                     8000
# 237                        21                R1041                     8000
# 238                        21                R1041                     8000
# 239                        21                R1041                     8000
# 240                        21                R1041                     8000
# 241                        21                R1041                     8000
# 242                        21                R1041                     8000
# 243                        16                R1041                     8000
# 244                        21                R1041                     8000
# 245                        12                R1041                     8000
# 246                        16                R1041                     8000
# 247                        21                R1041                     8000
# 248                        21                R1041                     8000
# 249                        12                R1041                     8000
# 250                        21                R1041                     8000
# 251                        21                R1041                     8000
# 252                        16                R1041                     8000
# 253                        21                R1041                     8000
# 254                        12                R1041                     8000
# 255                        16                R1041                     8000
# 256                        21                R1041                     8000
# 257                        12                R1041                     8000
#
#                                  hmm_flagger_alpha_tsv
# 0    https://raw.githubusercontent.com/mobinasri/fl...
# 1    https://raw.githubusercontent.com/mobinasri/fl...
# 2    https://raw.githubusercontent.com/mobinasri/fl...
# 3    https://raw.githubusercontent.com/mobinasri/fl...
# 4    https://raw.githubusercontent.com/mobinasri/fl...
# 5    https://raw.githubusercontent.com/mobinasri/fl...
# 6    https://raw.githubusercontent.com/mobinasri/fl...
# 7    https://raw.githubusercontent.com/mobinasri/fl...
# 8    https://raw.githubusercontent.com/mobinasri/fl...
# 9    https://raw.githubusercontent.com/mobinasri/fl...
# 10   https://raw.githubusercontent.com/mobinasri/fl...
# 11   https://raw.githubusercontent.com/mobinasri/fl...
# 12   https://raw.githubusercontent.com/mobinasri/fl...
# 13   https://raw.githubusercontent.com/mobinasri/fl...
# 14   https://raw.githubusercontent.com/mobinasri/fl...
# 15   https://raw.githubusercontent.com/mobinasri/fl...
# 16   https://raw.githubusercontent.com/mobinasri/fl...
# 17   https://raw.githubusercontent.com/mobinasri/fl...
# 18   https://raw.githubusercontent.com/mobinasri/fl...
# 19   https://raw.githubusercontent.com/mobinasri/fl...
# 20   https://raw.githubusercontent.com/mobinasri/fl...
# 21   https://raw.githubusercontent.com/mobinasri/fl...
# 22   https://raw.githubusercontent.com/mobinasri/fl...
# 23   https://raw.githubusercontent.com/mobinasri/fl...
# 24   https://raw.githubusercontent.com/mobinasri/fl...
# 25   https://raw.githubusercontent.com/mobinasri/fl...
# 26   https://raw.githubusercontent.com/mobinasri/fl...
# 27   https://raw.githubusercontent.com/mobinasri/fl...
# 28   https://raw.githubusercontent.com/mobinasri/fl...
# 29   https://raw.githubusercontent.com/mobinasri/fl...
# ..                                                 ...
# 228  https://raw.githubusercontent.com/mobinasri/fl...
# 229  https://raw.githubusercontent.com/mobinasri/fl...
# 230  https://raw.githubusercontent.com/mobinasri/fl...
# 231  https://raw.githubusercontent.com/mobinasri/fl...
# 232  https://raw.githubusercontent.com/mobinasri/fl...
# 233  https://raw.githubusercontent.com/mobinasri/fl...
# 234  https://raw.githubusercontent.com/mobinasri/fl...
# 235  https://raw.githubusercontent.com/mobinasri/fl...
# 236  https://raw.githubusercontent.com/mobinasri/fl...
# 237  https://raw.githubusercontent.com/mobinasri/fl...
# 238  https://raw.githubusercontent.com/mobinasri/fl...
# 239  https://raw.githubusercontent.com/mobinasri/fl...
# 240  https://raw.githubusercontent.com/mobinasri/fl...
# 241  https://raw.githubusercontent.com/mobinasri/fl...
# 242  https://raw.githubusercontent.com/mobinasri/fl...
# 243  https://raw.githubusercontent.com/mobinasri/fl...
# 244  https://raw.githubusercontent.com/mobinasri/fl...
# 245  https://raw.githubusercontent.com/mobinasri/fl...
# 246  https://raw.githubusercontent.com/mobinasri/fl...
# 247  https://raw.githubusercontent.com/mobinasri/fl...
# 248  https://raw.githubusercontent.com/mobinasri/fl...
# 249  https://raw.githubusercontent.com/mobinasri/fl...
# 250  https://raw.githubusercontent.com/mobinasri/fl...
# 251  https://raw.githubusercontent.com/mobinasri/fl...
# 252  https://raw.githubusercontent.com/mobinasri/fl...
# 253  https://raw.githubusercontent.com/mobinasri/fl...
# 254  https://raw.githubusercontent.com/mobinasri/fl...
# 255  https://raw.githubusercontent.com/mobinasri/fl...
# 256  https://raw.githubusercontent.com/mobinasri/fl...
# 257  https://raw.githubusercontent.com/mobinasri/fl...
#
# [258 rows x 15 columns]

# %%
merged_hifi_dc_table = merged_hifi_dc_table[["sample_id", 
                                             "read_files", 
                                             "number_of_read_files", 
                                             "total_coverage", 
                                             "coverage", 
                                             "mapper_preset", 
                                             "kmer_size", 
                                             "number_of_cores_per_task",
                                             "hmm_flagger_window_size",
                                             "hmm_flagger_alpha_tsv"]]
merged_hifi_dc_table
# Out:
#          sample_id                                         read_files  \
# 0          HG00099  [s3://human-pangenomics/submissions/42AFCE59-2...
# 1          HG00140  [s3://human-pangenomics/submissions/42AFCE59-2...
# 2          HG00280  [s3://human-pangenomics/submissions/42AFCE59-2...
# 3          HG00323  [s3://human-pangenomics/submissions/42AFCE59-2...
# 4          HG00408  [s3://human-pangenomics/submissions/42AFCE59-2...
# 5          HG00423  [s3://human-pangenomics/working/HPRC/HG00423/r...
# 6          HG00438  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 7          HG00544  [s3://human-pangenomics/working/HPRC/HG00544/r...
# 8          HG00558  [s3://human-pangenomics/submissions/42AFCE59-2...
# 9          HG00597  [s3://human-pangenomics/submissions/42AFCE59-2...
# 10         HG00609  [s3://human-pangenomics/working/HPRC/HG00609/r...
# 11         HG00621  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 12         HG00639  [s3://human-pangenomics/submissions/42AFCE59-2...
# 13         HG00642  [s3://human-pangenomics/working/HPRC/HG00642/r...
# 14         HG00658  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 15         HG00673  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 16         HG00735  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 17         HG00738  [s3://human-pangenomics/working/HPRC/HG00738/r...
# 18         HG00741  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 19         HG01071  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 20         HG01074  [s3://human-pangenomics/submissions/42AFCE59-2...
# 21         HG01081  [s3://human-pangenomics/submissions/42AFCE59-2...
# 22         HG01099  [s3://human-pangenomics/working/HPRC/HG01099/r...
# 23         HG01106  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 24         HG01109  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 25         HG01123  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 26         HG01150  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 27         HG01175  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 28         HG01192  [s3://human-pangenomics/submissions/42AFCE59-2...
# 29         HG01243  [s3://human-pangenomics/submissions/3A25CF8A-1...
# ..             ...                                                ...
# 136        HG04184  [s3://human-pangenomics/working/HPRC/HG04184/r...
# 137        HG04187  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 138        HG04199  [s3://human-pangenomics/working/HPRC/HG04199/r...
# 139        HG04204  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 140        HG04228  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 141        HG06807  [s3://human-pangenomics/submissions/42AFCE59-2...
# 142  MGISTL-PAN027  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 143        NA18522  [s3://human-pangenomics/submissions/42AFCE59-2...
# 144        NA18570  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 145        NA18612  [s3://human-pangenomics/submissions/42AFCE59-2...
# 146        NA18747  [s3://human-pangenomics/submissions/42AFCE59-2...
# 147        NA18906  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 148        NA18971  [s3://human-pangenomics/submissions/42AFCE59-2...
# 149        NA18983  [s3://human-pangenomics/submissions/42AFCE59-2...
# 150        NA19030  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 151        NA19043  [s3://human-pangenomics/submissions/42AFCE59-2...
# 152        NA19087  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 153        NA19159  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 154        NA19185  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 155        NA19240  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 156        NA19338  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 157        NA19391  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 158        NA19468  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 159        NA20129  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 160        NA20300  [s3://human-pangenomics/submissions/3A25CF8A-1...
# 161        NA20752  [s3://human-pangenomics/submissions/42AFCE59-2...
# 162        NA20799  [s3://human-pangenomics/submissions/B4B0B5DC-5...
# 163        NA20805  [s3://human-pangenomics/submissions/42AFCE59-2...
# 164        NA20905  [s3://human-pangenomics/submissions/42AFCE59-2...
# 165        NA21309  [s3://human-pangenomics/submissions/3A25CF8A-1...
#
#      number_of_read_files  total_coverage  \
# 0                       3           53.73
# 1                       4           40.84
# 2                       3           48.90
# 3                       4           38.72
# 4                       3           43.37
# 5                       4           53.33
# 6                       6           77.69
# 7                       5           45.45
# 8                       4           40.48
# 9                       4           43.93
# 10                      3           38.26
# 11                      4           47.91
# 12                      4           41.87
# 13                      4           47.70
# 14                      6           40.84
# 15                      4           48.60
# 16                      4           52.77
# 17                      4           38.06
# 18                      4           47.85
# 19                      6           74.09
# 20                      4           46.36
# 21                      3           42.29
# 22                      3           38.28
# 23                      4           56.29
# 24                      3           41.38
# 25                      4           45.64
# 26                      5           41.10
# 27                      4           45.91
# 28                      3           44.37
# 29                      3           42.18
# ..                    ...             ...
# 136                     4           42.86
# 137                     6           38.80
# 138                     4           37.48
# 139                     4           35.51
# 140                     5           50.53
# 141                     4           40.85
# 142                     6           67.63
# 143                     3           47.92
# 144                     3           50.24
# 145                     3           40.69
# 146                     4           44.49
# 147                     4           51.45
# 148                     4           41.34
# 149                     3           48.69
# 150                     3           41.21
# 151                     3           48.43
# 152                     3           48.26
# 153                     2           34.69
# 154                     3           51.77
# 155                     3           35.24
# 156                     3           42.74
# 157                     3           42.91
# 158                     4           49.80
# 159                     5           42.33
# 160                     6           56.98
# 161                     3           52.43
# 162                     3           39.91
# 163                     3           43.60
# 164                     3           49.01
# 165                     4           45.34
#
#                                        coverage mapper_preset  kmer_size  \
# 0                          [18.1, 17.07, 18.56]       lr:hqae         25
# 1                   [3.66, 11.91, 12.64, 12.63]       lr:hqae         25
# 2                         [17.78, 13.65, 17.47]       lr:hqae         25
# 3                    [2.43, 11.82, 12.17, 12.3]       lr:hqae         25
# 4                          [14.46, 14.31, 14.6]       lr:hqae         25
# 5                  [12.91, 12.53, 14.11, 13.78]       lr:hqae         25
# 6    [13.81, 11.36, 12.69, 13.34, 14.44, 12.05]       lr:hqae         25
# 7              [10.26, 13.74, 7.29, 6.79, 7.37]       lr:hqae         25
# 8                   [12.77, 13.38, 13.46, 0.87]       lr:hqae         25
# 9                    [13.15, 13.0, 12.94, 4.84]       lr:hqae         25
# 10                         [12.6, 12.74, 12.92]       lr:hqae         25
# 11                 [12.56, 11.73, 11.66, 11.96]       lr:hqae         25
# 12                  [12.43, 12.88, 14.37, 2.19]       lr:hqae         25
# 13                 [13.52, 11.28, 11.51, 11.39]       lr:hqae         25
# 14         [6.91, 7.37, 6.77, 5.82, 8.58, 5.39]       lr:hqae         25
# 15                 [11.26, 12.62, 13.05, 11.67]       lr:hqae         25
# 16                 [14.19, 13.15, 13.45, 11.98]       lr:hqae         25
# 17                    [9.74, 10.0, 10.04, 8.28]       lr:hqae         25
# 18                 [12.21, 11.52, 12.37, 11.75]       lr:hqae         25
# 19   [11.63, 10.41, 10.92, 10.97, 17.15, 13.01]       lr:hqae         25
# 20                  [6.28, 12.97, 13.56, 13.55]       lr:hqae         25
# 21                         [13.63, 14.7, 13.96]       lr:hqae         25
# 22                        [13.52, 13.79, 10.97]       lr:hqae         25
# 23                 [14.76, 13.11, 14.04, 14.38]       lr:hqae         25
# 24                        [15.59, 13.55, 12.24]       lr:hqae         25
# 25                   [13.0, 10.57, 9.53, 12.54]       lr:hqae         25
# 26            [11.98, 11.64, 11.36, 3.47, 2.65]       lr:hqae         25
# 27                 [11.48, 12.92, 10.59, 10.92]       lr:hqae         25
# 28                        [14.79, 15.02, 14.56]       lr:hqae         25
# 29                         [15.29, 13.1, 13.79]       lr:hqae         25
# ..                                          ...           ...        ...
# 136                 [9.53, 11.07, 10.67, 11.59]       lr:hqae         25
# 137         [9.83, 9.68, 5.12, 4.4, 4.71, 5.06]       lr:hqae         25
# 138                   [8.07, 9.81, 7.69, 11.91]       lr:hqae         25
# 139                  [12.02, 10.51, 11.4, 1.58]       lr:hqae         25
# 140          [11.51, 11.25, 13.75, 12.56, 1.46]       lr:hqae         25
# 141                 [13.06, 13.21, 12.84, 1.74]       lr:hqae         25
# 142    [12.3, 12.25, 10.44, 12.43, 9.44, 10.77]       lr:hqae         25
# 143                       [15.28, 15.61, 17.03]       lr:hqae         25
# 144                       [16.43, 16.69, 17.12]       lr:hqae         25
# 145                       [12.96, 14.17, 13.56]       lr:hqae         25
# 146                 [16.85, 11.74, 12.34, 3.56]       lr:hqae         25
# 147                [12.68, 13.23, 12.52, 13.02]       lr:hqae         25
# 148                   [12.61, 12.1, 12.3, 4.33]       lr:hqae         25
# 149                       [16.51, 15.91, 16.27]       lr:hqae         25
# 150                       [14.11, 14.09, 13.01]       lr:hqae         25
# 151                       [16.43, 15.71, 16.29]       lr:hqae         25
# 152                       [16.55, 16.56, 15.15]       lr:hqae         25
# 153                              [17.56, 17.13]       lr:hqae         25
# 154                        [16.99, 17.98, 16.8]       lr:hqae         25
# 155                         [12.44, 11.3, 11.5]       lr:hqae         25
# 156                       [14.41, 15.01, 13.32]       lr:hqae         25
# 157                       [14.02, 14.35, 14.54]       lr:hqae         25
# 158                 [14.79, 14.28, 14.25, 6.48]       lr:hqae         25
# 159           [10.52, 11.08, 11.16, 3.26, 6.31]       lr:hqae         25
# 160     [13.94, 13.26, 12.39, 5.55, 5.09, 6.75]       lr:hqae         25
# 161                       [18.23, 17.88, 16.32]       lr:hqae         25
# 162                       [13.23, 13.04, 13.64]       lr:hqae         25
# 163                       [14.02, 14.81, 14.77]       lr:hqae         25
# 164                       [16.47, 16.17, 16.37]       lr:hqae         25
# 165                 [11.84, 13.56, 13.32, 6.62]       lr:hqae         25
#
#      number_of_cores_per_task  hmm_flagger_window_size  \
# 0                          21                    16000
# 1                          16                    16000
# 2                          21                    16000
# 3                          16                    16000
# 4                          21                    16000
# 5                          16                    16000
# 6                          10                    16000
# 7                          12                    16000
# 8                          16                    16000
# 9                          16                    16000
# 10                         21                    16000
# 11                         16                    16000
# 12                         16                    16000
# 13                         16                    16000
# 14                         10                    16000
# 15                         16                    16000
# 16                         16                    16000
# 17                         16                    16000
# 18                         16                    16000
# 19                         10                    16000
# 20                         16                    16000
# 21                         21                    16000
# 22                         21                    16000
# 23                         16                    16000
# 24                         21                    16000
# 25                         16                    16000
# 26                         12                    16000
# 27                         16                    16000
# 28                         21                    16000
# 29                         21                    16000
# ..                        ...                      ...
# 136                        16                    16000
# 137                        10                    16000
# 138                        16                    16000
# 139                        16                    16000
# 140                        12                    16000
# 141                        16                    16000
# 142                        10                    16000
# 143                        21                    16000
# 144                        21                    16000
# 145                        21                    16000
# 146                        16                    16000
# 147                        16                    16000
# 148                        16                    16000
# 149                        21                    16000
# 150                        21                    16000
# 151                        21                    16000
# 152                        21                    16000
# 153                        32                    16000
# 154                        21                    16000
# 155                        21                    16000
# 156                        21                    16000
# 157                        21                    16000
# 158                        16                    16000
# 159                        12                    16000
# 160                        10                    16000
# 161                        21                    16000
# 162                        21                    16000
# 163                        21                    16000
# 164                        21                    16000
# 165                        16                    16000
#
#                                  hmm_flagger_alpha_tsv
# 0    https://raw.githubusercontent.com/mobinasri/fl...
# 1    https://raw.githubusercontent.com/mobinasri/fl...
# 2    https://raw.githubusercontent.com/mobinasri/fl...
# 3    https://raw.githubusercontent.com/mobinasri/fl...
# 4    https://raw.githubusercontent.com/mobinasri/fl...
# 5    https://raw.githubusercontent.com/mobinasri/fl...
# 6    https://raw.githubusercontent.com/mobinasri/fl...
# 7    https://raw.githubusercontent.com/mobinasri/fl...
# 8    https://raw.githubusercontent.com/mobinasri/fl...
# 9    https://raw.githubusercontent.com/mobinasri/fl...
# 10   https://raw.githubusercontent.com/mobinasri/fl...
# 11   https://raw.githubusercontent.com/mobinasri/fl...
# 12   https://raw.githubusercontent.com/mobinasri/fl...
# 13   https://raw.githubusercontent.com/mobinasri/fl...
# 14   https://raw.githubusercontent.com/mobinasri/fl...
# 15   https://raw.githubusercontent.com/mobinasri/fl...
# 16   https://raw.githubusercontent.com/mobinasri/fl...
# 17   https://raw.githubusercontent.com/mobinasri/fl...
# 18   https://raw.githubusercontent.com/mobinasri/fl...
# 19   https://raw.githubusercontent.com/mobinasri/fl...
# 20   https://raw.githubusercontent.com/mobinasri/fl...
# 21   https://raw.githubusercontent.com/mobinasri/fl...
# 22   https://raw.githubusercontent.com/mobinasri/fl...
# 23   https://raw.githubusercontent.com/mobinasri/fl...
# 24   https://raw.githubusercontent.com/mobinasri/fl...
# 25   https://raw.githubusercontent.com/mobinasri/fl...
# 26   https://raw.githubusercontent.com/mobinasri/fl...
# 27   https://raw.githubusercontent.com/mobinasri/fl...
# 28   https://raw.githubusercontent.com/mobinasri/fl...
# 29   https://raw.githubusercontent.com/mobinasri/fl...
# ..                                                 ...
# 136  https://raw.githubusercontent.com/mobinasri/fl...
# 137  https://raw.githubusercontent.com/mobinasri/fl...
# 138  https://raw.githubusercontent.com/mobinasri/fl...
# 139  https://raw.githubusercontent.com/mobinasri/fl...
# 140  https://raw.githubusercontent.com/mobinasri/fl...
# 141  https://raw.githubusercontent.com/mobinasri/fl...
# 142  https://raw.githubusercontent.com/mobinasri/fl...
# 143  https://raw.githubusercontent.com/mobinasri/fl...
# 144  https://raw.githubusercontent.com/mobinasri/fl...
# 145  https://raw.githubusercontent.com/mobinasri/fl...
# 146  https://raw.githubusercontent.com/mobinasri/fl...
# 147  https://raw.githubusercontent.com/mobinasri/fl...
# 148  https://raw.githubusercontent.com/mobinasri/fl...
# 149  https://raw.githubusercontent.com/mobinasri/fl...
# 150  https://raw.githubusercontent.com/mobinasri/fl...
# 151  https://raw.githubusercontent.com/mobinasri/fl...
# 152  https://raw.githubusercontent.com/mobinasri/fl...
# 153  https://raw.githubusercontent.com/mobinasri/fl...
# 154  https://raw.githubusercontent.com/mobinasri/fl...
# 155  https://raw.githubusercontent.com/mobinasri/fl...
# 156  https://raw.githubusercontent.com/mobinasri/fl...
# 157  https://raw.githubusercontent.com/mobinasri/fl...
# 158  https://raw.githubusercontent.com/mobinasri/fl...
# 159  https://raw.githubusercontent.com/mobinasri/fl...
# 160  https://raw.githubusercontent.com/mobinasri/fl...
# 161  https://raw.githubusercontent.com/mobinasri/fl...
# 162  https://raw.githubusercontent.com/mobinasri/fl...
# 163  https://raw.githubusercontent.com/mobinasri/fl...
# 164  https://raw.githubusercontent.com/mobinasri/fl...
# 165  https://raw.githubusercontent.com/mobinasri/fl...
#
# [166 rows x 10 columns]

# %%
merged_hifi_dc_table.to_csv('hifi_reads_table.csv', index=False)
merged_ont_table.to_csv('ont_reads_table.csv', index=False)

# %%
# !find ${PWD}
# Out:
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/make_ont_hifi_tables.ipynb
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/HPRC_ONT.file.index.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/HPRC_DeepConsensus.file.index.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/ont_reads_table.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/.ipynb_checkpoints
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/.ipynb_checkpoints/make_ont_hifi_tables-checkpoint.ipynb
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/hifi_reads_table.csv

# %% [markdown]
# ## Make a table for additional HiFi data

# %%
hifi_full_table = pd.read_csv('HPRC_PacBio_HiFi.file.index.csv')

# %% [markdown]
# In creating `merged_hifi_new_table.csv` first I tried to keep only `Revio` data but 6 samples had less than 40x coverage so I will sort all files per sample and keep them until the total coverage is greater than `80x`.

# %%
# merge hifi full table
merged_hifi_full_table = hifi_full_table.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_hifi_full_table.rename(columns={"sample_ID": "sample_id"}, inplace=True)
merged_hifi_full_table.rename(columns={"path": "read_files"}, inplace=True)
merged_hifi_full_table["total_coverage"] = merged_hifi_full_table["coverage"].apply(sum)
merged_hifi_full_table["number_of_read_files"] = merged_hifi_full_table["read_files"].apply(len)
merged_hifi_full_table["number_of_cores_per_task"] = (totalCores / merged_hifi_full_table["number_of_read_files"]).astype(int)
merged_hifi_full_table['number_of_cores_per_task'] = merged_hifi_full_table['number_of_cores_per_task'].apply(lambda x: max(4,x))
merged_hifi_full_table["mapper_preset"] = "lr:hqae"
merged_hifi_full_table["kmer_size"] = 25

merged_hifi_full_table["hmm_flagger_window_size"] = window_size_hifi
merged_hifi_full_table["hmm_flagger_alpha_tsv"] = alpha_tsv_hifi

# %% [markdown]
# ### Keep only the samples with higher coverage (>40x) or the ones absent from the old HiFi table

# %%
# here I will take only the samples with less than 40x HiFi_DC coverage
# so if in the new table we have higher coverage we will rerun it with greater than 40x coverage
all_samples_dc_cov_lt_40 = set(merged_hifi_dc_table["sample_id"][merged_hifi_dc_table["total_coverage"] < 40])
all_samples_full_cov_gt_40 = set(merged_hifi_full_table["sample_id"][merged_hifi_full_table["total_coverage"] > 40])

samples_to_be_rerun_higher_cov = all_samples_full_cov_gt_40.intersection(all_samples_dc_cov_lt_40)

print('There are',
      len(samples_to_be_rerun_higher_cov),
      'samples with coverage > 40x in the new table but not in the old table')
# Out:
# There are 40 samples with coverage > 40x in the new table but not in the old table

# %%
# here I will take the new samples that were absent from HiFi_DC table
all_samples_dc = set(merged_hifi_dc_table["sample_id"])
all_samples_full = set(merged_hifi_full_table["sample_id"])

samples_to_be_run = all_samples_full.difference(all_samples_dc)

print('There are',
      len(samples_to_be_run),
      'samples existing in the new table but not in the old table')
# Out:
# There are 107 samples existing in the new table but not in the old table

# %%
all_samples_for_new_table = samples_to_be_run.union(samples_to_be_rerun_higher_cov)
# make a new table with only samples that need to be run (or rerun with higher coverage)
merged_hifi_full_table_new_only = merged_hifi_full_table[merged_hifi_full_table['sample_id'].isin(all_samples_for_new_table)]

# %% [markdown]
# Since total HiFi coverage for some new samples are very high and we don't need coverage higher than 60x, here I sort the read files by coverage from high to low and keep the file untill the total coverage goes above 60x and ignore the rest of the files.

# %%
merged_hifi_full_table_new_only.index = np.arange(len(merged_hifi_full_table_new_only))
merged_hifi_full_table_new_only["read_files_downsampled"] = [[] for _ in range(len(merged_hifi_full_table_new_only))]
merged_hifi_full_table_new_only["total_coverage_downsampled"] = 0

for i in range(merged_hifi_full_table_new_only.shape[0]):
    coverages = merged_hifi_full_table_new_only["coverage"][i]
    paths = merged_hifi_full_table_new_only["read_files"][i]
    coverage_path_tuples = [(c, p) for c, p in zip(coverages, paths)]
    coverage_path_tuples.sort(key=lambda x: x[0], reverse=True)
    summed_coverage = 0
    downsampled_paths = []
    for j in range(len(coverage_path_tuples)):
        summed_coverage += coverage_path_tuples[j][0]
        merged_hifi_full_table_new_only.loc[i, "read_files_downsampled"].append(coverage_path_tuples[j][1])
        if summed_coverage >= 60:
            break
    merged_hifi_full_table_new_only.loc[i, "total_coverage_downsampled"] = round(summed_coverage,2)

merged_hifi_full_table_new_only["number_of_read_files_downsampled"] = merged_hifi_full_table_new_only["read_files_downsampled"].apply(len)
merged_hifi_full_table_new_only["number_of_cores_per_task_downsampled"] = (totalCores / merged_hifi_full_table_new_only["number_of_read_files_downsampled"]).astype(int)
merged_hifi_full_table_new_only["number_of_cores_per_task_downsampled"] = merged_hifi_full_table_new_only["number_of_cores_per_task_downsampled"].apply(lambda x: max(4,x))
# Out:
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /private/home/masri/apps/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(merged_hifi_full_table_new_only)
# Out:
# 147

# %%
merged_hifi_full_table_new_only = merged_hifi_full_table_new_only[["sample_id",  
                                     "read_files_downsampled", 
                                     "number_of_read_files_downsampled", 
                                     "total_coverage_downsampled", 
                                     "number_of_cores_per_task_downsampled", 
                                     "mapper_preset", 
                                     "kmer_size", 
                                     "read_files", 
                                     "number_of_read_files", 
                                     "total_coverage", 
                                     "coverage", 
                                     "number_of_cores_per_task", 
                                     "instrument_model",
                                     "hmm_flagger_window_size",
                                     "hmm_flagger_alpha_tsv"]]
merged_hifi_full_table_new_only
# Out:
#     sample_id                             read_files_downsampled  \
# 0     HG00097  [s3://human-pangenomics/working/HPRC/HG00097/r...
# 1     HG00106  [s3://human-pangenomics/working/HPRC/HG00106/r...
# 2     HG00117  [s3://human-pangenomics/working/HPRC/HG00117/r...
# 3     HG00126  [s3://human-pangenomics/working/HPRC/HG00126/r...
# 4     HG00128  [s3://human-pangenomics/working/HPRC/HG00128/r...
# 5     HG00133  [s3://human-pangenomics/working/HPRC/HG00133/r...
# 6     HG00146  [s3://human-pangenomics/working/HPRC/HG00146/r...
# 7     HG00232  [s3://human-pangenomics/working/HPRC/HG00232/r...
# 8     HG00235  [s3://human-pangenomics/working/HPRC/HG00235/r...
# 9     HG00243  [s3://human-pangenomics/working/HPRC/HG00243/r...
# 10    HG00253  [s3://human-pangenomics/working/HPRC/HG00253/r...
# 11    HG00258  [s3://human-pangenomics/working/HPRC/HG00258/r...
# 12    HG00272  [s3://human-pangenomics/working/HPRC/HG00272/r...
# 13    HG00290  [s3://human-pangenomics/working/HPRC/HG00290/r...
# 14    HG00320  [s3://human-pangenomics/working/HPRC/HG00320/r...
# 15    HG00321  [s3://human-pangenomics/working/HPRC/HG00321/r...
# 16    HG00323  [s3://human-pangenomics/working/HPRC/HG00323/r...
# 17    HG00329  [s3://human-pangenomics/working/HPRC/HG00329/r...
# 18    HG00344  [s3://human-pangenomics/working/HPRC/HG00344/r...
# 19    HG00350  [s3://human-pangenomics/working/HPRC/HG00350/r...
# 20    HG00384  [s3://human-pangenomics/working/HPRC/HG00384/r...
# 21    HG00609  [s3://human-pangenomics/working/HPRC/HG00609/r...
# 22    HG00662  [s3://human-pangenomics/working/HPRC/HG00662/r...
# 23    HG00701  [s3://human-pangenomics/working/HPRC/HG00701/r...
# 24    HG00706  [s3://human-pangenomics/working/HPRC/HG00706/r...
# 25    HG00738  [s3://human-pangenomics/working/HPRC/HG00738/r...
# 26    HG00867  [s3://human-pangenomics/working/HPRC/HG00867/r...
# 27    HG01028  [s3://human-pangenomics/working/HPRC/HG01028/r...
# 28    HG01048  [s3://human-pangenomics/working/HPRC/HG01048/r...
# 29    HG01099  [s3://human-pangenomics/working/HPRC/HG01099/r...
# ..        ...                                                ...
# 117   NA19099  [s3://human-pangenomics/working/HPRC/NA19099/r...
# 118   NA19120  [s3://human-pangenomics/working/HPRC/NA19120/r...
# 119   NA19131  [s3://human-pangenomics/working/HPRC/NA19131/r...
# 120   NA19159  [s3://human-pangenomics/working/HPRC/NA19159/r...
# 121   NA19175  [s3://human-pangenomics/working/HPRC/NA19175/r...
# 122   NA19190  [s3://human-pangenomics/working/HPRC/NA19190/r...
# 123   NA19377  [s3://human-pangenomics/working/HPRC/NA19377/r...
# 124   NA19390  [s3://human-pangenomics/working/HPRC/NA19390/r...
# 125   NA19443  [s3://human-pangenomics/working/HPRC/NA19443/r...
# 126   NA19682  [s3://human-pangenomics/working/HPRC/NA19682/r...
# 127   NA19700  [s3://human-pangenomics/working/HPRC/NA19700/r...
# 128   NA19703  [s3://human-pangenomics/working/HPRC/NA19703/r...
# 129   NA19776  [s3://human-pangenomics/working/HPRC/NA19776/r...
# 130   NA19834  [s3://human-pangenomics/working/HPRC/NA19834/r...
# 131   NA19835  [s3://human-pangenomics/working/HPRC/NA19835/r...
# 132   NA19909  [s3://human-pangenomics/working/HPRC/NA19909/r...
# 133   NA20282  [s3://human-pangenomics/working/HPRC/NA20282/r...
# 134   NA20287  [s3://human-pangenomics/working/HPRC/NA20287/r...
# 135   NA20346  [s3://human-pangenomics/working/HPRC/NA20346/r...
# 136   NA20799  [s3://human-pangenomics/working/HPRC/NA20799/r...
# 137   NA20809  [s3://human-pangenomics/working/HPRC/NA20809/r...
# 138   NA20818  [s3://human-pangenomics/working/HPRC/NA20818/r...
# 139   NA20850  [s3://human-pangenomics/working/HPRC/NA20850/r...
# 140   NA20858  [s3://human-pangenomics/working/HPRC/NA20858/r...
# 141   NA20870  [s3://human-pangenomics/working/HPRC/NA20870/r...
# 142   NA21093  [s3://human-pangenomics/working/HPRC/NA21093/r...
# 143   NA21102  [s3://human-pangenomics/working/HPRC/NA21102/r...
# 144   NA21106  [s3://human-pangenomics/working/HPRC/NA21106/r...
# 145   NA21110  [s3://human-pangenomics/working/HPRC/NA21110/r...
# 146   NA21144  [s3://human-pangenomics/working/HPRC/NA21144/r...
#
#      number_of_read_files_downsampled  total_coverage_downsampled  \
# 0                                   3                       63.70
# 1                                   3                       61.40
# 2                                   2                       63.50
# 3                                   5                       63.80
# 4                                   4                       66.30
# 5                                   6                       66.00
# 6                                   2                       72.60
# 7                                   5                       60.30
# 8                                   2                       61.60
# 9                                   2                       59.90
# 10                                  2                       64.90
# 11                                  4                       66.50
# 12                                  4                       67.80
# 13                                  5                       63.30
# 14                                  2                       68.30
# 15                                  4                       61.20
# 16                                 10                       56.70
# 17                                  2                       62.10
# 18                                  3                       65.30
# 19                                  3                       65.80
# 20                                  4                       61.30
# 21                                  6                       65.20
# 22                                  3                       61.50
# 23                                  3                       66.20
# 24                                  5                       61.10
# 25                                  5                       64.50
# 26                                  3                       62.40
# 27                                  4                       66.20
# 28                                  4                       69.00
# 29                                  6                       58.70
# ..                                ...                         ...
# 117                                 4                       65.00
# 118                                 2                       70.50
# 119                                 3                       64.30
# 120                                 4                       52.54
# 121                                 2                       66.20
# 122                                 2                       71.30
# 123                                 3                       61.10
# 124                                 4                       63.50
# 125                                 5                       62.80
# 126                                 4                       62.60
# 127                                 4                       60.60
# 128                                 3                       62.20
# 129                                 3                       62.40
# 130                                 2                       83.50
# 131                                 3                       62.40
# 132                                 2                       71.00
# 133                                 2                       69.80
# 134                                 2                       60.00
# 135                                 2                       60.10
# 136                                 6                       60.93
# 137                                 3                       59.10
# 138                                 2                       72.30
# 139                                 3                       60.60
# 140                                 2                       60.80
# 141                                 2                       70.30
# 142                                 4                       62.50
# 143                                 3                       62.30
# 144                                 4                       63.00
# 145                                 3                       61.90
# 146                                 2                       77.40
#
#      number_of_cores_per_task_downsampled mapper_preset  kmer_size  \
# 0                                      21       lr:hqae         25
# 1                                      21       lr:hqae         25
# 2                                      32       lr:hqae         25
# 3                                      12       lr:hqae         25
# 4                                      16       lr:hqae         25
# 5                                      10       lr:hqae         25
# 6                                      32       lr:hqae         25
# 7                                      12       lr:hqae         25
# 8                                      32       lr:hqae         25
# 9                                      32       lr:hqae         25
# 10                                     32       lr:hqae         25
# 11                                     16       lr:hqae         25
# 12                                     16       lr:hqae         25
# 13                                     12       lr:hqae         25
# 14                                     32       lr:hqae         25
# 15                                     16       lr:hqae         25
# 16                                      6       lr:hqae         25
# 17                                     32       lr:hqae         25
# 18                                     21       lr:hqae         25
# 19                                     21       lr:hqae         25
# 20                                     16       lr:hqae         25
# 21                                     10       lr:hqae         25
# 22                                     21       lr:hqae         25
# 23                                     21       lr:hqae         25
# 24                                     12       lr:hqae         25
# 25                                     12       lr:hqae         25
# 26                                     21       lr:hqae         25
# 27                                     16       lr:hqae         25
# 28                                     16       lr:hqae         25
# 29                                     10       lr:hqae         25
# ..                                    ...           ...        ...
# 117                                    16       lr:hqae         25
# 118                                    32       lr:hqae         25
# 119                                    21       lr:hqae         25
# 120                                    16       lr:hqae         25
# 121                                    32       lr:hqae         25
# 122                                    32       lr:hqae         25
# 123                                    21       lr:hqae         25
# 124                                    16       lr:hqae         25
# 125                                    12       lr:hqae         25
# 126                                    16       lr:hqae         25
# 127                                    16       lr:hqae         25
# 128                                    21       lr:hqae         25
# 129                                    21       lr:hqae         25
# 130                                    32       lr:hqae         25
# 131                                    21       lr:hqae         25
# 132                                    32       lr:hqae         25
# 133                                    32       lr:hqae         25
# 134                                    32       lr:hqae         25
# 135                                    32       lr:hqae         25
# 136                                    10       lr:hqae         25
# 137                                    21       lr:hqae         25
# 138                                    32       lr:hqae         25
# 139                                    21       lr:hqae         25
# 140                                    32       lr:hqae         25
# 141                                    32       lr:hqae         25
# 142                                    16       lr:hqae         25
# 143                                    21       lr:hqae         25
# 144                                    16       lr:hqae         25
# 145                                    21       lr:hqae         25
# 146                                    32       lr:hqae         25
#
#                                             read_files  number_of_read_files  \
# 0    [s3://human-pangenomics/working/HPRC/HG00097/r...                     3
# 1    [s3://human-pangenomics/working/HPRC/HG00106/r...                     3
# 2    [s3://human-pangenomics/working/HPRC/HG00117/r...                     2
# 3    [s3://human-pangenomics/working/HPRC/HG00126/r...                     5
# 4    [s3://human-pangenomics/working/HPRC/HG00128/r...                     4
# 5    [s3://human-pangenomics/working/HPRC/HG00133/r...                     6
# 6    [s3://human-pangenomics/working/HPRC/HG00146/r...                     2
# 7    [s3://human-pangenomics/working/HPRC/HG00232/r...                     6
# 8    [s3://human-pangenomics/working/HPRC/HG00235/r...                     2
# 9    [s3://human-pangenomics/working/HPRC/HG00243/r...                     2
# 10   [s3://human-pangenomics/working/HPRC/HG00253/r...                     2
# 11   [s3://human-pangenomics/working/HPRC/HG00258/r...                     4
# 12   [s3://human-pangenomics/working/HPRC/HG00272/r...                     4
# 13   [s3://human-pangenomics/working/HPRC/HG00290/r...                     5
# 14   [s3://human-pangenomics/working/HPRC/HG00320/r...                     2
# 15   [s3://human-pangenomics/working/HPRC/HG00321/r...                     4
# 16   [s3://human-pangenomics/working/HPRC/HG00323/r...                    10
# 17   [s3://human-pangenomics/working/HPRC/HG00329/r...                     2
# 18   [s3://human-pangenomics/working/HPRC/HG00344/r...                     3
# 19   [s3://human-pangenomics/working/HPRC/HG00350/r...                     3
# 20   [s3://human-pangenomics/working/HPRC/HG00384/r...                     4
# 21   [s3://human-pangenomics/working/HPRC/HG00609/r...                     6
# 22   [s3://human-pangenomics/working/HPRC/HG00662/r...                     3
# 23   [s3://human-pangenomics/working/HPRC/HG00701/r...                     3
# 24   [s3://human-pangenomics/working/HPRC/HG00706/r...                     5
# 25   [s3://human-pangenomics/working/HPRC/HG00738/r...                     5
# 26   [s3://human-pangenomics/working/HPRC/HG00867/r...                     3
# 27   [s3://human-pangenomics/working/HPRC/HG01028/r...                     4
# 28   [s3://human-pangenomics/working/HPRC/HG01048/r...                     4
# 29   [s3://human-pangenomics/working/HPRC/HG01099/r...                     6
# ..                                                 ...                   ...
# 117  [s3://human-pangenomics/working/HPRC/NA19099/r...                     4
# 118  [s3://human-pangenomics/working/HPRC/NA19120/r...                     2
# 119  [s3://human-pangenomics/working/HPRC/NA19131/r...                     3
# 120  [s3://human-pangenomics/working/HPRC/NA19159/r...                     4
# 121  [s3://human-pangenomics/working/HPRC/NA19175/r...                     2
# 122  [s3://human-pangenomics/working/HPRC/NA19190/r...                     2
# 123  [s3://human-pangenomics/working/HPRC/NA19377/r...                     3
# 124  [s3://human-pangenomics/working/HPRC/NA19390/r...                     4
# 125  [s3://human-pangenomics/working/HPRC/NA19443/r...                     5
# 126  [s3://human-pangenomics/working/HPRC/NA19682/r...                     4
# 127  [s3://human-pangenomics/working/HPRC/NA19700/r...                     4
# 128  [s3://human-pangenomics/working/HPRC/NA19703/r...                     3
# 129  [s3://human-pangenomics/working/HPRC/NA19776/r...                     3
# 130  [s3://human-pangenomics/working/HPRC/NA19834/r...                     2
# 131  [s3://human-pangenomics/working/HPRC/NA19835/r...                     3
# 132  [s3://human-pangenomics/working/HPRC/NA19909/r...                     6
# 133  [s3://human-pangenomics/working/HPRC/NA20282/r...                     2
# 134  [s3://human-pangenomics/working/HPRC/NA20287/r...                     2
# 135  [s3://human-pangenomics/working/HPRC/NA20346/r...                     2
# 136  [s3://human-pangenomics/working/HPRC/NA20799/r...                     6
# 137  [s3://human-pangenomics/working/HPRC/NA20809/r...                     3
# 138  [s3://human-pangenomics/working/HPRC/NA20818/r...                     2
# 139  [s3://human-pangenomics/working/HPRC/NA20850/r...                     3
# 140  [s3://human-pangenomics/working/HPRC/NA20858/r...                     2
# 141  [s3://human-pangenomics/working/HPRC/NA20870/r...                     2
# 142  [s3://human-pangenomics/working/HPRC/NA21093/r...                     4
# 143  [s3://human-pangenomics/working/HPRC/NA21102/r...                     3
# 144  [s3://human-pangenomics/working/HPRC/NA21106/r...                     4
# 145  [s3://human-pangenomics/working/HPRC/NA21110/r...                     3
# 146  [s3://human-pangenomics/working/HPRC/NA21144/r...                     2
#
#      total_coverage                                           coverage  \
# 0             63.70                                 [26.4, 19.2, 18.1]
# 1             61.40                                  [27.9, 27.9, 5.6]
# 2             63.50                                       [29.9, 33.6]
# 3             63.80                       [17.9, 8.7, 10.1, 19.2, 7.9]
# 4             66.30                           [13.9, 10.7, 15.2, 26.5]
# 5             66.00                  [14.3, 8.6, 9.7, 7.6, 10.2, 15.6]
# 6             72.60                                       [36.5, 36.1]
# 7             62.30                   [26.2, 26.7, 2.0, 2.3, 2.5, 2.6]
# 8             61.60                                       [29.2, 32.4]
# 9             59.90                                       [30.4, 29.5]
# 10            64.90                                       [36.0, 28.9]
# 11            66.50                           [16.3, 16.6, 17.4, 16.2]
# 12            67.80                            [21.5, 18.0, 19.1, 9.2]
# 13            63.30                       [19.1, 15.8, 16.8, 8.0, 3.6]
# 14            68.30                                       [28.8, 39.5]
# 15            61.20                             [28.3, 28.1, 2.2, 2.6]
# 16            56.70  [10.8, 11.2, 2.2, 10.9, 3.2, 3.2, 3.0, 3.2, 4....
# 17            62.10                                       [34.2, 27.9]
# 18            65.30                                 [20.6, 19.6, 25.1]
# 19            65.80                                  [6.7, 37.8, 21.3]
# 20            61.30                             [28.1, 29.5, 1.8, 1.9]
# 21            65.20                [11.8, 11.0, 11.6, 11.0, 9.4, 10.4]
# 22            61.50                                  [34.3, 25.2, 2.0]
# 23            66.20                                 [21.3, 24.1, 20.8]
# 24            61.10                         [8.9, 7.8, 9.5, 9.5, 25.4]
# 25            64.50                         [8.7, 9.0, 9.2, 7.1, 30.5]
# 26            62.40                                  [27.4, 29.2, 5.8]
# 27            66.20                            [18.8, 9.3, 18.5, 19.6]
# 28            69.00                           [19.9, 18.1, 18.2, 12.8]
# 29            58.70                   [12.1, 12.3, 8.3, 9.2, 8.0, 8.8]
# ..              ...                                                ...
# 117           65.00                            [23.0, 21.8, 9.6, 10.6]
# 118           70.50                                       [34.9, 35.6]
# 119           64.30                                  [34.8, 23.7, 5.8]
# 120           52.54                           [14.9, 14.9, 15.1, 7.64]
# 121           66.20                                       [34.0, 32.2]
# 122           71.30                                       [35.1, 36.2]
# 123           61.10                                  [27.5, 28.7, 4.9]
# 124           63.50                           [17.3, 17.9, 10.6, 17.7]
# 125           62.80                       [4.5, 18.3, 16.8, 14.7, 8.5]
# 126           62.60                           [17.1, 15.5, 17.4, 12.6]
# 127           60.60                           [13.9, 14.6, 16.1, 16.0]
# 128           62.20                                 [19.3, 25.6, 17.3]
# 129           62.40                                 [20.8, 20.8, 20.8]
# 130           83.50                                       [40.8, 42.7]
# 131           62.40                                  [29.1, 30.8, 2.5]
# 132          189.80               [31.1, 32.9, 24.2, 31.4, 32.1, 38.1]
# 133           69.80                                       [35.8, 34.0]
# 134           60.00                                       [28.4, 31.6]
# 135           60.10                                       [28.2, 31.9]
# 136           60.93               [11.6, 11.5, 10.8, 5.8, 12.09, 9.14]
# 137           59.10                                  [28.1, 27.5, 3.5]
# 138           72.30                                       [37.0, 35.3]
# 139           60.60                                 [20.4, 18.8, 21.4]
# 140           60.80                                       [33.4, 27.4]
# 141           70.30                                       [35.7, 34.6]
# 142           62.50                            [19.4, 17.5, 8.5, 17.1]
# 143           62.30                                  [28.6, 29.1, 4.6]
# 144           63.00                            [4.6, 19.1, 20.3, 19.0]
# 145           61.90                                  [28.8, 28.5, 4.6]
# 146           77.40                                       [36.1, 41.3]
#
#      number_of_cores_per_task  \
# 0                          21
# 1                          21
# 2                          32
# 3                          12
# 4                          16
# 5                          10
# 6                          32
# 7                          10
# 8                          32
# 9                          32
# 10                         32
# 11                         16
# 12                         16
# 13                         12
# 14                         32
# 15                         16
# 16                          6
# 17                         32
# 18                         21
# 19                         21
# 20                         16
# 21                         10
# 22                         21
# 23                         21
# 24                         12
# 25                         12
# 26                         21
# 27                         16
# 28                         16
# 29                         10
# ..                        ...
# 117                        16
# 118                        32
# 119                        21
# 120                        16
# 121                        32
# 122                        32
# 123                        21
# 124                        16
# 125                        12
# 126                        16
# 127                        16
# 128                        21
# 129                        21
# 130                        32
# 131                        21
# 132                        10
# 133                        32
# 134                        32
# 135                        32
# 136                        10
# 137                        21
# 138                        32
# 139                        21
# 140                        32
# 141                        32
# 142                        16
# 143                        21
# 144                        16
# 145                        21
# 146                        32
#
#                                       instrument_model  \
# 0                                [Revio, Revio, Revio]
# 1                                [Revio, Revio, Revio]
# 2                                       [Revio, Revio]
# 3                  [Revio, Revio, Revio, Revio, Revio]
# 4                         [Revio, Revio, Revio, Revio]
# 5           [Revio, Revio, Revio, Revio, Revio, Revio]
# 6                                       [Revio, Revio]
# 7           [Revio, Revio, Revio, Revio, Revio, Revio]
# 8                                       [Revio, Revio]
# 9                                       [Revio, Revio]
# 10                                      [Revio, Revio]
# 11                        [Revio, Revio, Revio, Revio]
# 12                        [Revio, Revio, Revio, Revio]
# 13                 [Revio, Revio, Revio, Revio, Revio]
# 14                                      [Revio, Revio]
# 15                        [Revio, Revio, Revio, Revio]
# 16   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 17                                      [Revio, Revio]
# 18                               [Revio, Revio, Revio]
# 19                               [Revio, Revio, Revio]
# 20                        [Revio, Revio, Revio, Revio]
# 21   [Sequel II, Sequel II, Sequel II, Revio, Revio...
# 22                               [Revio, Revio, Revio]
# 23                               [Revio, Revio, Revio]
# 24   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 25   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 26                               [Revio, Revio, Revio]
# 27                        [Revio, Revio, Revio, Revio]
# 28                        [Revio, Revio, Revio, Revio]
# 29   [Sequel II, Sequel II, Sequel II, Revio, Revio...
# ..                                                 ...
# 117                       [Revio, Revio, Revio, Revio]
# 118                                     [Revio, Revio]
# 119                              [Revio, Revio, Revio]
# 120           [Sequel II, Sequel II, Sequel II, Revio]
# 121                                     [Revio, Revio]
# 122                                     [Revio, Revio]
# 123                              [Revio, Revio, Revio]
# 124                       [Revio, Revio, Revio, Revio]
# 125                [Revio, Revio, Revio, Revio, Revio]
# 126                       [Revio, Revio, Revio, Revio]
# 127                       [Revio, Revio, Revio, Revio]
# 128                              [Revio, Revio, Revio]
# 129                              [Revio, Revio, Revio]
# 130                                     [Revio, Revio]
# 131                              [Revio, Revio, Revio]
# 132         [Revio, Revio, Revio, Revio, Revio, Revio]
# 133                                     [Revio, Revio]
# 134                                     [Revio, Revio]
# 135                                     [Revio, Revio]
# 136  [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 137                              [Revio, Revio, Revio]
# 138                                     [Revio, Revio]
# 139                              [Revio, Revio, Revio]
# 140                                     [Revio, Revio]
# 141                                     [Revio, Revio]
# 142                       [Revio, Revio, Revio, Revio]
# 143                              [Revio, Revio, Revio]
# 144                       [Revio, Revio, Revio, Revio]
# 145                              [Revio, Revio, Revio]
# 146                                     [Revio, Revio]
#
#      hmm_flagger_window_size  \
# 0                      16000
# 1                      16000
# 2                      16000
# 3                      16000
# 4                      16000
# 5                      16000
# 6                      16000
# 7                      16000
# 8                      16000
# 9                      16000
# 10                     16000
# 11                     16000
# 12                     16000
# 13                     16000
# 14                     16000
# 15                     16000
# 16                     16000
# 17                     16000
# 18                     16000
# 19                     16000
# 20                     16000
# 21                     16000
# 22                     16000
# 23                     16000
# 24                     16000
# 25                     16000
# 26                     16000
# 27                     16000
# 28                     16000
# 29                     16000
# ..                       ...
# 117                    16000
# 118                    16000
# 119                    16000
# 120                    16000
# 121                    16000
# 122                    16000
# 123                    16000
# 124                    16000
# 125                    16000
# 126                    16000
# 127                    16000
# 128                    16000
# 129                    16000
# 130                    16000
# 131                    16000
# 132                    16000
# 133                    16000
# 134                    16000
# 135                    16000
# 136                    16000
# 137                    16000
# 138                    16000
# 139                    16000
# 140                    16000
# 141                    16000
# 142                    16000
# 143                    16000
# 144                    16000
# 145                    16000
# 146                    16000
#
#                                  hmm_flagger_alpha_tsv
# 0    https://raw.githubusercontent.com/mobinasri/fl...
# 1    https://raw.githubusercontent.com/mobinasri/fl...
# 2    https://raw.githubusercontent.com/mobinasri/fl...
# 3    https://raw.githubusercontent.com/mobinasri/fl...
# 4    https://raw.githubusercontent.com/mobinasri/fl...
# 5    https://raw.githubusercontent.com/mobinasri/fl...
# 6    https://raw.githubusercontent.com/mobinasri/fl...
# 7    https://raw.githubusercontent.com/mobinasri/fl...
# 8    https://raw.githubusercontent.com/mobinasri/fl...
# 9    https://raw.githubusercontent.com/mobinasri/fl...
# 10   https://raw.githubusercontent.com/mobinasri/fl...
# 11   https://raw.githubusercontent.com/mobinasri/fl...
# 12   https://raw.githubusercontent.com/mobinasri/fl...
# 13   https://raw.githubusercontent.com/mobinasri/fl...
# 14   https://raw.githubusercontent.com/mobinasri/fl...
# 15   https://raw.githubusercontent.com/mobinasri/fl...
# 16   https://raw.githubusercontent.com/mobinasri/fl...
# 17   https://raw.githubusercontent.com/mobinasri/fl...
# 18   https://raw.githubusercontent.com/mobinasri/fl...
# 19   https://raw.githubusercontent.com/mobinasri/fl...
# 20   https://raw.githubusercontent.com/mobinasri/fl...
# 21   https://raw.githubusercontent.com/mobinasri/fl...
# 22   https://raw.githubusercontent.com/mobinasri/fl...
# 23   https://raw.githubusercontent.com/mobinasri/fl...
# 24   https://raw.githubusercontent.com/mobinasri/fl...
# 25   https://raw.githubusercontent.com/mobinasri/fl...
# 26   https://raw.githubusercontent.com/mobinasri/fl...
# 27   https://raw.githubusercontent.com/mobinasri/fl...
# 28   https://raw.githubusercontent.com/mobinasri/fl...
# 29   https://raw.githubusercontent.com/mobinasri/fl...
# ..                                                 ...
# 117  https://raw.githubusercontent.com/mobinasri/fl...
# 118  https://raw.githubusercontent.com/mobinasri/fl...
# 119  https://raw.githubusercontent.com/mobinasri/fl...
# 120  https://raw.githubusercontent.com/mobinasri/fl...
# 121  https://raw.githubusercontent.com/mobinasri/fl...
# 122  https://raw.githubusercontent.com/mobinasri/fl...
# 123  https://raw.githubusercontent.com/mobinasri/fl...
# 124  https://raw.githubusercontent.com/mobinasri/fl...
# 125  https://raw.githubusercontent.com/mobinasri/fl...
# 126  https://raw.githubusercontent.com/mobinasri/fl...
# 127  https://raw.githubusercontent.com/mobinasri/fl...
# 128  https://raw.githubusercontent.com/mobinasri/fl...
# 129  https://raw.githubusercontent.com/mobinasri/fl...
# 130  https://raw.githubusercontent.com/mobinasri/fl...
# 131  https://raw.githubusercontent.com/mobinasri/fl...
# 132  https://raw.githubusercontent.com/mobinasri/fl...
# 133  https://raw.githubusercontent.com/mobinasri/fl...
# 134  https://raw.githubusercontent.com/mobinasri/fl...
# 135  https://raw.githubusercontent.com/mobinasri/fl...
# 136  https://raw.githubusercontent.com/mobinasri/fl...
# 137  https://raw.githubusercontent.com/mobinasri/fl...
# 138  https://raw.githubusercontent.com/mobinasri/fl...
# 139  https://raw.githubusercontent.com/mobinasri/fl...
# 140  https://raw.githubusercontent.com/mobinasri/fl...
# 141  https://raw.githubusercontent.com/mobinasri/fl...
# 142  https://raw.githubusercontent.com/mobinasri/fl...
# 143  https://raw.githubusercontent.com/mobinasri/fl...
# 144  https://raw.githubusercontent.com/mobinasri/fl...
# 145  https://raw.githubusercontent.com/mobinasri/fl...
# 146  https://raw.githubusercontent.com/mobinasri/fl...
#
# [147 rows x 15 columns]

# %%
merged_hifi_full_table_new_only.to_csv('hifi_additional_reads_table.csv', index=False)

# %%
# !find ${PWD}
# Out:
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/hifi_additional_reads_table.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/make_ont_hifi_tables.ipynb
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/HPRC_ONT.file.index.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/HPRC_DeepConsensus.file.index.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/ont_reads_table.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/HPRC_PacBio_HiFi.file.index.csv
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/.ipynb_checkpoints
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/.ipynb_checkpoints/make_ont_hifi_tables-checkpoint.ipynb
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/hifi_reads_table.csv
