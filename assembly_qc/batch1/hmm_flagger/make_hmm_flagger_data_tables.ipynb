# %%
import numpy as np
import pandas as pd
import sys
import os
import re

# %% [markdown]
# ### This notebook:
# - Opens `batch1_censat_outputs_done.csv` and `hprc_year1_sample_metadata.txt`
# - Makes diploid censat bed files and add links to the final tables
# - Adds a column to the final tables which keeps if the sample is Year1 or not
# - Puts Year1 samples on top of the table so that they will be run first
# - Takes read paths from tables `/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/ont_reads_table.csv` and `/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/hifi_reads_table.csv`
# - Makes separate data tables for HiFi and ONT runs (both will contain diploid censat bed files)
# - Saves the final data tables in `hifi/` and `ont/` subdirectories and they will be used for creating input json files

# %%
# !ls
# Out:
# batch1_censat_outputs_done.csv	hprc_year1_sample_metadata.txt	    read_tables
# diploid_censat_beds		make_hmm_flagger_data_tables.ipynb
# hifi				ont

# %%
censat_table = pd.read_csv('batch1_censat_outputs_done.csv')
print("Number of rows:", len(censat_table))
censat_table.head()
# Out:
# Number of rows: 388
#       sample_id                                                asm  \
# 0  HG00408_hap1  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  HG00408_hap2  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  HG00597_hap1  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  HG00597_hap2  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  HG01192_hap1  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                      sequence_id_key  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                            as_sf_bed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                           as_hor_bed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                        as_strand_bed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                        as_hor_sf_bed  rmRmskAlignBigBed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...                NaN
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...                NaN
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...                NaN
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...                NaN
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...                NaN
#
#    rmRmskBigBed                                  repeatMaskerTarGZ  \
# 0           NaN  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1           NaN  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2           NaN  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3           NaN  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4           NaN  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                            rmOutFile  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                   rmFinalMaskedFasta  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                       rmRmskAlignBed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                            rmRmskBed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                                rmBed  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                          centromeres  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                         cenSatStrand  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...
#
#                                    cenSatAnnotations
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 2  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 3  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 4  /private/groups/hprc/qc/batch1/censat/HG01192_...

# %%
# Remove "_hap1" or "_hap2" from 'sample_id' and create a new column 'sample_name'
censat_table["sample_name"] = censat_table["sample_id"].str.replace(r"_hap[12]$", "", regex=True)

# make two tables one for hap1 and one for hap2
censat_table_hap1 = censat_table[censat_table['sample_id'].str.endswith('_hap1', na=False)]
censat_table_hap2 = censat_table[censat_table['sample_id'].str.endswith('_hap2', na=False)]

# Merging the DataFrames on 'sample_name'
censat_table_diploid = pd.merge(censat_table_hap1,
                                censat_table_hap2,
                                on='sample_name',
                                suffixes=('_hap1', '_hap2'))
censat_table_diploid = censat_table_diploid[["sample_name", 
                                             "asm_hap1", 
                                             "asm_hap2",
                                             "cenSatAnnotations_hap1",
                                             "cenSatAnnotations_hap2"]]

censat_table_diploid = censat_table_diploid.rename(columns={"sample_name":"sample_id"})
censat_table_diploid.head()
# Out:
#   sample_id                                           asm_hap1  \
# 0   HG00408  s3://human-pangenomics/submissions/DC27718F-5F...
# 1   HG00597  s3://human-pangenomics/submissions/DC27718F-5F...
# 2   HG01192  s3://human-pangenomics/submissions/DC27718F-5F...
# 3   HG01261  s3://human-pangenomics/submissions/DC27718F-5F...
# 4   HG02015  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                             asm_hap2  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                               cenSatAnnotations_hap1  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 2  /private/groups/hprc/qc/batch1/censat/HG01192_...
# 3  /private/groups/hprc/qc/batch1/censat/HG01261_...
# 4  /private/groups/hprc/qc/batch1/censat/HG02015_...
#
#                               cenSatAnnotations_hap2
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 2  /private/groups/hprc/qc/batch1/censat/HG01192_...
# 3  /private/groups/hprc/qc/batch1/censat/HG01261_...
# 4  /private/groups/hprc/qc/batch1/censat/HG02015_...

# %%
# add a column for saving diploid censat bed files
censat_table_diploid["censat_diploid_bed"] = ""

# make a directory for saving diploid censat bed files
diploid_censat_dir = f'{os.getcwd()}/diploid_censat_beds'
# !mkdir -p {diploid_censat_dir}

censat_diploid_list = []
additional_annotations_array_list = []
# iterate over rows
for i in range(len(censat_table_diploid)):
    sample = censat_table_diploid["sample_id"][i]
    censat_bed_hap1 = censat_table_diploid["cenSatAnnotations_hap1"][i]
    censat_bed_hap2 = censat_table_diploid["cenSatAnnotations_hap2"][i]
    
    # concat hap1 and hap2 censat bed files into a single bed file
    #!cat {censat_bed_hap1} {censat_bed_hap2} | bedtools sort -i - > {diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.bed
    #!cat {censat_bed_hap1} {censat_bed_hap2} | bedtools sort -i - | grep -i "rDNA" | awk '{{print $$1"\t"$$2"\t"$$3}}' > {diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.rDNA.bed
    
    print(f'Merged {sample}')
    # add new bed to the table
    censat_diploid_list.append(f'{diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.bed')
    additional_annotations_array_list.append([f'{diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.rDNA.bed'])

censat_table_diploid["censat_diploid_bed"] = censat_diploid_list
censat_table_diploid["additional_annotations_array"] = additional_annotations_array_list
censat_table_diploid.head()
# Out:
# Merged HG00408
# Merged HG00597
# Merged HG01192
# Merged HG01261
# Merged HG02015
# Merged HG02056
# Merged HG02129
# Merged HG02258
# Merged HG03834
# Merged HG00609
# Merged HG00642
# Merged HG00738
# Merged HG01099
# Merged HG01255
# Merged HG01346
# Merged HG01433
# Merged HG01496
# Merged HG01884
# Merged HG01981
# Merged HG01993
# Merged HG02004
# Merged HG02083
# Merged HG02132
# Merged HG02280
# Merged HG02293
# Merged HG02300
# Merged HG02451
# Merged HG02523
# Merged HG02615
# Merged HG02647
# Merged HG02698
# Merged HG03654
# Merged HG03669
# Merged HG03688
# Merged HG03704
# Merged HG03710
# Merged HG03831
# Merged HG03927
# Merged HG04115
# Merged HG04184
# Merged HG04199
# Merged HG00621
# Merged HG00741
# Merged HG01106
# Merged HG01175
# Merged HG01258
# Merged HG01891
# Merged HG01952
# Merged HG02148
# Merged HG02486
# Merged HG02559
# Merged HG02572
# Merged HG02622
# Merged HG02886
# Merged HG03453
# Merged HG03540
# Merged HG00099
# Merged HG00140
# Merged HG00280
# Merged HG00323
# Merged HG02040
# Merged HG02165
# Merged HG02273
# Merged HG02922
# Merged HG02965
# Merged HG02976
# Merged HG03130
# Merged HG03195
# Merged HG03209
# Merged NA18522
# Merged NA18747
# Merged NA18971
# Merged NA18983
# Merged NA19043
# Merged NA20905
# Merged HG01530
# Merged HG01784
# Merged HG02391
# Merged HG03471
# Merged HG03742
# Merged NA18570
# Merged NA19087
# Merged NA19185
# Merged NA19338
# Merged NA19391
# Merged NA19468
# Merged HG00438
# Merged HG00558
# Merged HG00639
# Merged HG00658
# Merged HG00673
# Merged HG01071
# Merged HG01074
# Merged HG01081
# Merged HG01123
# Merged HG01150
# Merged HG01252
# Merged HG01358
# Merged HG01361
# Merged HG01928
# Merged HG01934
# Merged HG01940
# Merged HG01960
# Merged HG01969
# Merged HG01978
# Merged HG02071
# Merged HG02074
# Merged HG02135
# Merged HG02257
# Merged HG02668
# Merged HG02717
# Merged HG02809
# Merged HG03017
# Merged HG03041
# Merged HG03239
# Merged HG03516
# Merged HG03804
# Merged HG03942
# Merged HG04157
# Merged HG04160
# Merged HG04204
# Merged HG04228
# Merged HG00423
# Merged HG00544
# Merged HG01943
# Merged HG02735
# Merged HG03225
# Merged HG00126
# Merged HG00128
# Merged HG00133
# Merged HG00146
# Merged HG00232
# Merged HG00290
# Merged HG00320
# Merged HG00321
# Merged HG02178
# Merged HG02583
# Merged HG03270
# Merged HG03583
# Merged HG03874
# Merged NA18505
# Merged NA18508
# Merged NA18608
# Merged NA18620
# Merged NA18952
# Merged NA18974
# Merged NA18976
# Merged NA19036
# Merged NA19443
# Merged NA19700
# Merged NA20870
# Merged NA21093
# Merged NA21106
# Merged NA21110
# Merged HG00735
# Merged HG02155
# Merged HG02630
# Merged HG03139
# Merged HG03470
# Merged HG03579
# Merged NA20805
# Merged HG01109
# Merged HG02055
# Merged HG02080
# Merged HG02109
# Merged HG02723
# Merged HG02818
# Merged HG03098
# Merged HG03486
# Merged NA18906
# Merged NA20129
# Merged NA21309
# Merged HG00097
# Merged HG00235
# Merged HG00253
# Merged HG00272
# Merged HG00329
# Merged HG00344
# Merged HG00350
# Merged HG01167
# Merged HG03369
# Merged HG03521
# Merged HG03784
# Merged NA18565
# Merged NA19682
# Merged NA19776
# Merged NA19835
# Merged NA19909
# Merged NA20282
# Merged NA20346
# Merged NA20809
# Merged NA20850
# Merged NA21102
# Merged NA21144
#   sample_id                                           asm_hap1  \
# 0   HG00408  s3://human-pangenomics/submissions/DC27718F-5F...
# 1   HG00597  s3://human-pangenomics/submissions/DC27718F-5F...
# 2   HG01192  s3://human-pangenomics/submissions/DC27718F-5F...
# 3   HG01261  s3://human-pangenomics/submissions/DC27718F-5F...
# 4   HG02015  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                             asm_hap2  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                               cenSatAnnotations_hap1  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 2  /private/groups/hprc/qc/batch1/censat/HG01192_...
# 3  /private/groups/hprc/qc/batch1/censat/HG01261_...
# 4  /private/groups/hprc/qc/batch1/censat/HG02015_...
#
#                               cenSatAnnotations_hap2  \
# 0  /private/groups/hprc/qc/batch1/censat/HG00408_...
# 1  /private/groups/hprc/qc/batch1/censat/HG00597_...
# 2  /private/groups/hprc/qc/batch1/censat/HG01192_...
# 3  /private/groups/hprc/qc/batch1/censat/HG01261_...
# 4  /private/groups/hprc/qc/batch1/censat/HG02015_...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                         additional_annotations_array
# 0  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...

# %%
list(censat_table_diploid["censat_diploid_bed"])[:5]
# Out:
# ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG00408_dip_hprc_r2_v1.cenSat.bed',
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG00597_dip_hprc_r2_v1.cenSat.bed',
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG01192_dip_hprc_r2_v1.cenSat.bed',
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG01261_dip_hprc_r2_v1.cenSat.bed',
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG02015_dip_hprc_r2_v1.cenSat.bed']

# %%
list(censat_table_diploid["additional_annotations_array"])[:5]
# Out:
# [['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG00408_dip_hprc_r2_v1.cenSat.rDNA.bed'],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG00597_dip_hprc_r2_v1.cenSat.rDNA.bed'],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG01192_dip_hprc_r2_v1.cenSat.rDNA.bed'],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG01261_dip_hprc_r2_v1.cenSat.rDNA.bed'],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG02015_dip_hprc_r2_v1.cenSat.rDNA.bed']]

# %%
# !cat /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/diploid_censat_beds/HG00408_dip_hprc_r2_v1.cenSat.rDNA.bed | head
# Out:
# HG00408#1#CM085953.1	132949629	132952668
# HG00408#1#CM085961.1	34643331	34646412
# HG00408#1#CM085964.1	29763394	29766442
# HG00408#1#CM085964.1	30693954	30697014
# HG00408#1#JBHDVK010000001.1	19274	112653
# HG00408#1#JBHDVK010000001.1	2651597	2654675
# HG00408#1#JBHDVK010000008.1	6440370	6851003
# HG00408#1#JBHDVK010000008.1	7045506	7660493
# HG00408#1#JBHDVK010000008.1	12266867	12268108
# HG00408#1#JBHDVK010000008.1	13361951	13365007

# %%
os.getcwd()
# Out:
# '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger'

# %%
# read ont and hifi reads table
hifi_reads_table = pd.read_csv('read_tables/hifi_reads_table.csv')
ont_reads_table = pd.read_csv('read_tables/ont_reads_table.csv')

# merge with censat table
ont_data_table = pd.merge(censat_table_diploid, ont_reads_table, on='sample_id',  how='inner')
hifi_data_table = pd.merge(censat_table_diploid, hifi_reads_table, on='sample_id',  how='inner')

# %%
hprc_y1_table = pd.read_csv('hprc_year1_sample_metadata.txt', sep="\t")
print("Number of rows:", len(hprc_y1_table))
y1_samples = list(hprc_y1_table["Sample"])
# Out:
# Number of rows: 47

# %%
y1_samples
# Out:
# ['HG01123',
#  'HG01258',
#  'HG01358',
#  'HG01361',
#  'HG01891',
#  'HG02257',
#  'HG02486',
#  'HG02559',
#  'HG02572',
#  'HG03516',
#  'HG00438',
#  'HG00621',
#  'HG00673',
#  'HG00735',
#  'HG00741',
#  'HG01071',
#  'HG01106',
#  'HG01175',
#  'HG01928',
#  'HG01952',
#  'HG01978',
#  'HG02148',
#  'HG02622',
#  'HG02630',
#  'HG02717',
#  'HG02886',
#  'HG03453',
#  'HG03540',
#  'HG03579',
#  'HG002',
#  'HG005',
#  'HG00733',
#  'HG01109',
#  'HG01243',
#  'HG02080',
#  'HG02109',
#  'HG02145',
#  'HG02723',
#  'HG02818',
#  'HG03486',
#  'HG03492',
#  'NA18906',
#  'NA19240',
#  'NA20129',
#  'NA21309',
#  'HG02055',
#  'HG03098']

# %%
ont_data_table["is_year1"] = ont_data_table["sample_id"].apply(lambda x: "true" if x in y1_samples else "false")
hifi_data_table["is_year1"] = hifi_data_table["sample_id"].apply(lambda x: "true" if x in y1_samples else "false")

# %%
ont_data_table = ont_data_table.sort_values(by=["is_year1", "sample_id"], ascending=False)
hifi_data_table = hifi_data_table.sort_values(by=["is_year1", "sample_id"], ascending=False)

# %%
print(f"Number of rows for final HiFi table: {len(hifi_data_table)}")
print(f"Number of rows for final HiFi table (Year1): {sum(hifi_data_table['is_year1'] == 'true')}")
hifi_data_table.head()
# Out:
# Number of rows for final HiFi table: 141
# Number of rows for final HiFi table (Year1): 40
#     sample_id                                           asm_hap1  \
# 140   NA21309  s3://human-pangenomics/submissions/DC27718F-5F...
# 139   NA20129  s3://human-pangenomics/submissions/DC27718F-5F...
# 138   NA18906  s3://human-pangenomics/submissions/DC27718F-5F...
# 128   HG03579  s3://human-pangenomics/submissions/DC27718F-5F...
# 55    HG03540  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                               asm_hap2  \
# 140  s3://human-pangenomics/submissions/DC27718F-5F...
# 139  s3://human-pangenomics/submissions/DC27718F-5F...
# 138  s3://human-pangenomics/submissions/DC27718F-5F...
# 128  s3://human-pangenomics/submissions/DC27718F-5F...
# 55   s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                 cenSatAnnotations_hap1  \
# 140  /private/groups/hprc/qc/batch1/censat/NA21309_...
# 139  /private/groups/hprc/qc/batch1/censat/NA20129_...
# 138  /private/groups/hprc/qc/batch1/censat/NA18906_...
# 128  /private/groups/hprc/qc/batch1/censat/HG03579_...
# 55   /private/groups/hprc/qc/batch1/censat/HG03540_...
#
#                                 cenSatAnnotations_hap2  \
# 140  /private/groups/hprc/qc/batch1/censat/NA21309_...
# 139  /private/groups/hprc/qc/batch1/censat/NA20129_...
# 138  /private/groups/hprc/qc/batch1/censat/NA18906_...
# 128  /private/groups/hprc/qc/batch1/censat/HG03579_...
# 55   /private/groups/hprc/qc/batch1/censat/HG03540_...
#
#                                     censat_diploid_bed  \
# 140  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 139  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 138  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 128  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 55   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                           additional_annotations_array  \
# 140  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 139  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 138  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 128  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 55   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                             read_files  number_of_read_files  \
# 140  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 139  ['s3://human-pangenomics/submissions/3A25CF8A-...                     5
# 138  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 128  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 55   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
#
#      total_coverage                                    coverage mapper_preset  \
# 140           45.34                 [11.84, 13.56, 13.32, 6.62]       lr:hqae
# 139           42.33           [10.52, 11.08, 11.16, 3.26, 6.31]       lr:hqae
# 138           51.45                [12.68, 13.23, 12.52, 13.02]       lr:hqae
# 128           84.47  [12.94, 14.54, 14.68, 14.19, 16.84, 11.28]       lr:hqae
# 55            58.53                [15.01, 14.59, 14.66, 14.27]       lr:hqae
#
#      kmer_size  number_of_cores_per_task  hmm_flagger_window_size  \
# 140         25                        16                    16000
# 139         25                        12                    16000
# 138         25                        16                    16000
# 128         25                        10                    16000
# 55          25                        16                    16000
#
#                                  hmm_flagger_alpha_tsv is_year1
# 140  https://raw.githubusercontent.com/mobinasri/fl...     true
# 139  https://raw.githubusercontent.com/mobinasri/fl...     true
# 138  https://raw.githubusercontent.com/mobinasri/fl...     true
# 128  https://raw.githubusercontent.com/mobinasri/fl...     true
# 55   https://raw.githubusercontent.com/mobinasri/fl...     true

# %%
print(f"Number of rows for final ONT table: {len(ont_data_table)}")
print(f"Number of rows for final ONT table (Year1): {sum(ont_data_table['is_year1'] == 'true')}")
ont_data_table.head()
# Out:
# Number of rows for final ONT table: 170
# Number of rows for final ONT table (Year1): 29
#     sample_id                                           asm_hap1  \
# 147   HG03579  s3://human-pangenomics/submissions/DC27718F-5F...
# 55    HG03540  s3://human-pangenomics/submissions/DC27718F-5F...
# 103   HG03516  s3://human-pangenomics/submissions/DC27718F-5F...
# 54    HG03453  s3://human-pangenomics/submissions/DC27718F-5F...
# 53    HG02886  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                               asm_hap2  \
# 147  s3://human-pangenomics/submissions/DC27718F-5F...
# 55   s3://human-pangenomics/submissions/DC27718F-5F...
# 103  s3://human-pangenomics/submissions/DC27718F-5F...
# 54   s3://human-pangenomics/submissions/DC27718F-5F...
# 53   s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                 cenSatAnnotations_hap1  \
# 147  /private/groups/hprc/qc/batch1/censat/HG03579_...
# 55   /private/groups/hprc/qc/batch1/censat/HG03540_...
# 103  /private/groups/hprc/qc/batch1/censat/HG03516_...
# 54   /private/groups/hprc/qc/batch1/censat/HG03453_...
# 53   /private/groups/hprc/qc/batch1/censat/HG02886_...
#
#                                 cenSatAnnotations_hap2  \
# 147  /private/groups/hprc/qc/batch1/censat/HG03579_...
# 55   /private/groups/hprc/qc/batch1/censat/HG03540_...
# 103  /private/groups/hprc/qc/batch1/censat/HG03516_...
# 54   /private/groups/hprc/qc/batch1/censat/HG03453_...
# 53   /private/groups/hprc/qc/batch1/censat/HG02886_...
#
#                                     censat_diploid_bed  \
# 147  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 55   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 103  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 54   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 53   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                           additional_annotations_array  \
# 147  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 55   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 103  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 54   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 53   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                 read_files_downsampled  \
# 147  ['s3://human-pangenomics/working/HPRC/HG03579/...
# 55   ['s3://human-pangenomics/working/HPRC/HG03540/...
# 103  ['s3://human-pangenomics/working/HPRC/HG03516/...
# 54   ['s3://human-pangenomics/working/HPRC/HG03453/...
# 53   ['s3://human-pangenomics/working/HPRC/HG02886/...
#
#      number_of_read_files_downsampled  total_coverage_downsampled    ...     \
# 147                                 4                       61.24    ...
# 55                                  4                       66.73    ...
# 103                                 4                       65.43    ...
# 54                                  4                       60.64    ...
# 53                                  5                       64.07    ...
#
#      kmer_size                                         read_files  \
# 147         15  ['s3://human-pangenomics/working/HPRC/HG03579/...
# 55          15  ['s3://human-pangenomics/working/HPRC/HG03540/...
# 103         15  ['s3://human-pangenomics/working/HPRC/HG03516/...
# 54          15  ['s3://human-pangenomics/working/HPRC/HG03453/...
# 53          15  ['s3://human-pangenomics/working/HPRC/HG02886/...
#
#      number_of_read_files total_coverage  \
# 147                     9          95.33
# 55                      5          69.44
# 103                     9         126.17
# 54                      5          61.51
# 53                      5          64.07
#
#                                               coverage  \
# 147  [5.51, 4.3, 2.78, 10.72, 12.87, 10.78, 16.91, ...
# 55                   [19.56, 28.57, 6.77, 11.83, 2.71]
# 103  [10.45, 12.86, 13.36, 12.69, 16.85, 13.58, 17....
# 54                    [30.59, 22.17, 3.24, 4.64, 0.87]
# 53                   [20.24, 16.83, 9.84, 10.72, 6.44]
#
#      number_of_cores_per_task sequencing_chemistry  hmm_flagger_window_size  \
# 147                         7                 R941                    16000
# 55                         12                 R941                    16000
# 103                         7                 R941                    16000
# 54                         12                 R941                    16000
# 53                         12                 R941                    16000
#
#                                  hmm_flagger_alpha_tsv  is_year1
# 147  https://raw.githubusercontent.com/mobinasri/fl...      true
# 55   https://raw.githubusercontent.com/mobinasri/fl...      true
# 103  https://raw.githubusercontent.com/mobinasri/fl...      true
# 54   https://raw.githubusercontent.com/mobinasri/fl...      true
# 53   https://raw.githubusercontent.com/mobinasri/fl...      true
#
# [5 rows x 22 columns]

# %%
os.makedirs("ont", exist_ok=True)
ont_data_table.to_csv('ont/hmm_flagger_ont_data_table.csv', index=False)

os.makedirs("hifi", exist_ok=True)
hifi_data_table.to_csv('hifi/hmm_flagger_hifi_data_table.csv', index=False)
