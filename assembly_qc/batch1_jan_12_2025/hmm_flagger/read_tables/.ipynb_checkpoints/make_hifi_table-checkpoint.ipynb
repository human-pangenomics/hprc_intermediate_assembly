# %%
import numpy as np
import pandas as pd
import sys
import os
import re

# %% [markdown]
# This notebook (Jan 12 2025):
# - Opens HiFi index file (`HPRC_PacBio_HiFi.file.index.csv`)
# - Makes a hifi table with only one sample per row and the corresponding reads saved in an array
# - It assumes that each mapping will be run in a 64 core machine so the number of tasks for mapping each file will be computed by dividing 64 by number of files
# - Some samples might have very high coverage. It sorts HiFi files based on coverage and keeps the files untill it reaches 80x and ignores the rest. These file arrays are saved in the column ending with "_downsampled"
# - kmer size and mapping preset will be set based on sequencing platform (HiFi: minimap2 (lr:hqae,k=25))
# - Note that `HPRC_PacBio_HiFi.file.index.csv` is a more complete version of `HPRC_DeepConsensus.file.index.csv` which was used in `batch1/hmm_flagger/read_tables/`
# - Related link for `HPRC_PacBio_HiFi.file.index.csv` (commit: `4687c2e`)
# https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/main/data/hprc-data-explorer-tables/HPRC_PacBio_HiFi.file.index.csv

# %%
os.getcwd()
# Out:
# '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1_jan_12_2025/hmm_flagger/read_tables'

# %%
alpha_tsv_hifi = "https://raw.githubusercontent.com/mobinasri/flagger/refs/heads/main/misc/alpha_tsv/HiFi_DC_1.2/alpha_optimum_trunc_exp_gaussian_w_16000_n_50.HiFi_DC_1.2_DEC_2024.v1.1.0.tsv"
window_size_hifi = 16000

# %%
# download csv files  
# !wget https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/main/data/hprc-data-explorer-tables/HPRC_PacBio_HiFi.file.index.csv
# Out:
# --2025-01-19 13:35:26--  https://raw.githubusercontent.com/human-pangenomics/HPRC_metadata/refs/heads/main/data/hprc-data-explorer-tables/HPRC_PacBio_HiFi.file.index.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 657103 (642K) [text/plain]
# Saving to: ‘HPRC_PacBio_HiFi.file.index.csv.1’
#
# HPRC_PacBio_HiFi.fi 100%[===================>] 641.70K  --.-KB/s    in 0.01s
#
# 2025-01-19 13:35:27 (46.5 MB/s) - ‘HPRC_PacBio_HiFi.file.index.csv.1’ saved [657103/657103]

# %%
def addDownsampledColumn(merged_reads_table, coverage_threshold):
    merged_reads_table["read_files_downsampled"] = [[] for _ in range(len(merged_reads_table))]
    merged_reads_table["total_coverage_downsampled"] = 0

    for i in range(merged_reads_table.shape[0]):
        coverages = merged_reads_table["coverage"][i]
        paths = merged_reads_table["read_files"][i]
        coverage_path_tuples = [(c, p) for c, p in zip(coverages, paths)]
        coverage_path_tuples.sort(key=lambda x: x[0], reverse=True)
        summed_coverage = 0
        downsampled_paths = []
        for j in range(len(coverage_path_tuples)):
            summed_coverage += coverage_path_tuples[j][0]
            merged_reads_table.loc[i, "read_files_downsampled"].append(coverage_path_tuples[j][1])
            if summed_coverage >= coverage_threshold:
                break
        merged_reads_table.loc[i, "total_coverage_downsampled"] = round(summed_coverage,2)

    merged_reads_table["number_of_read_files_downsampled"] = merged_reads_table["read_files_downsampled"].apply(len)
    merged_reads_table["number_of_cores_per_task_downsampled"] = (totalCores / merged_reads_table["number_of_read_files_downsampled"]).astype(int)
    merged_reads_table['number_of_cores_per_task_downsampled'] = merged_reads_table['number_of_cores_per_task_downsampled'].apply(lambda x: max(4,x))

# %% [markdown]
# ## Make a table for additional HiFi data

# %%
hifi_full_table = pd.read_csv('HPRC_PacBio_HiFi.file.index.csv')

# %%
# merge hifi full table
totalCores = 64
merged_hifi_full_table = hifi_full_table.groupby("sample_ID", as_index=False).agg(lambda x: list(x))
merged_hifi_full_table.rename(columns={"sample_ID": "sample_id"}, inplace=True)
merged_hifi_full_table.rename(columns={"path": "read_files"}, inplace=True)
merged_hifi_full_table["total_coverage"] = merged_hifi_full_table["coverage"].apply(sum)
merged_hifi_full_table["number_of_read_files"] = merged_hifi_full_table["read_files"].apply(len)
merged_hifi_full_table["number_of_cores_per_task"] = (totalCores / merged_hifi_full_table["number_of_read_files"]).astype(int)
merged_hifi_full_table['number_of_cores_per_task'] = merged_hifi_full_table['number_of_cores_per_task'].apply(lambda x: max(4,x))
merged_hifi_full_table["mapper_preset"] = "lr:hqae"
merged_hifi_full_table["kmer_size"] = 25

merged_hifi_full_table["hmm_flagger_window_size"] = window_size_hifi
merged_hifi_full_table["hmm_flagger_alpha_tsv"] = alpha_tsv_hifi

# %% [markdown]
# Since total HiFi coverage for some new samples are very high and we don't need coverage higher than 60x, here I sort the read files by coverage from high to low and keep the file untill the total coverage goes above 60x and ignore the rest of the files.

# %%
addDownsampledColumn(merged_hifi_full_table, coverage_threshold=60)

# %%
len(merged_hifi_full_table)
# Out:
# 253

# %%
merged_hifi_full_table = merged_hifi_full_table[["sample_id",  
                                     "read_files_downsampled", 
                                     "number_of_read_files_downsampled", 
                                     "total_coverage_downsampled", 
                                     "number_of_cores_per_task_downsampled", 
                                     "mapper_preset", 
                                     "kmer_size", 
                                     "read_files", 
                                     "number_of_read_files", 
                                     "total_coverage", 
                                     "coverage", 
                                     "number_of_cores_per_task", 
                                     "instrument_model",
                                     "hmm_flagger_window_size",
                                     "hmm_flagger_alpha_tsv"]]
merged_hifi_full_table
# Out:
#     sample_id                             read_files_downsampled  \
# 0     HG00097  [s3://human-pangenomics/working/HPRC/HG00097/r...
# 1     HG00099  [s3://human-pangenomics/working/HPRC/HG00099/r...
# 2     HG00106  [s3://human-pangenomics/working/HPRC/HG00106/r...
# 3     HG00117  [s3://human-pangenomics/working/HPRC/HG00117/r...
# 4     HG00126  [s3://human-pangenomics/working/HPRC/HG00126/r...
# 5     HG00128  [s3://human-pangenomics/working/HPRC/HG00128/r...
# 6     HG00133  [s3://human-pangenomics/working/HPRC/HG00133/r...
# 7     HG00140  [s3://human-pangenomics/working/HPRC/HG00140/r...
# 8     HG00146  [s3://human-pangenomics/working/HPRC/HG00146/r...
# 9     HG00232  [s3://human-pangenomics/working/HPRC/HG00232/r...
# 10    HG00235  [s3://human-pangenomics/working/HPRC/HG00235/r...
# 11    HG00243  [s3://human-pangenomics/working/HPRC/HG00243/r...
# 12    HG00253  [s3://human-pangenomics/working/HPRC/HG00253/r...
# 13    HG00258  [s3://human-pangenomics/working/HPRC/HG00258/r...
# 14    HG00272  [s3://human-pangenomics/working/HPRC/HG00272/r...
# 15    HG00280  [s3://human-pangenomics/working/HPRC/HG00280/r...
# 16    HG00290  [s3://human-pangenomics/working/HPRC/HG00290/r...
# 17    HG00320  [s3://human-pangenomics/working/HPRC/HG00320/r...
# 18    HG00321  [s3://human-pangenomics/working/HPRC/HG00321/r...
# 19    HG00323  [s3://human-pangenomics/working/HPRC/HG00323/r...
# 20    HG00329  [s3://human-pangenomics/working/HPRC/HG00329/r...
# 21    HG00344  [s3://human-pangenomics/working/HPRC/HG00344/r...
# 22    HG00350  [s3://human-pangenomics/working/HPRC/HG00350/r...
# 23    HG00384  [s3://human-pangenomics/working/HPRC/HG00384/r...
# 24    HG00408  [s3://human-pangenomics/working/HPRC/HG00408/r...
# 25    HG00423  [s3://human-pangenomics/working/HPRC/HG00423/r...
# 26    HG00438  [s3://human-pangenomics/working/HPRC/HG00438/r...
# 27    HG00544  [s3://human-pangenomics/working/HPRC/HG00544/r...
# 28    HG00558  [s3://human-pangenomics/working/HPRC/HG00558/r...
# 29    HG00597  [s3://human-pangenomics/working/HPRC/HG00597/r...
# ..        ...                                                ...
# 223   NA19338  [s3://human-pangenomics/working/HPRC/NA19338/r...
# 224   NA19377  [s3://human-pangenomics/working/HPRC/NA19377/r...
# 225   NA19390  [s3://human-pangenomics/working/HPRC/NA19390/r...
# 226   NA19391  [s3://human-pangenomics/working/HPRC/NA19391/r...
# 227   NA19443  [s3://human-pangenomics/working/HPRC/NA19443/r...
# 228   NA19468  [s3://human-pangenomics/working/HPRC/NA19468/r...
# 229   NA19682  [s3://human-pangenomics/working/HPRC/NA19682/r...
# 230   NA19700  [s3://human-pangenomics/working/HPRC/NA19700/r...
# 231   NA19703  [s3://human-pangenomics/working/HPRC/NA19703/r...
# 232   NA19776  [s3://human-pangenomics/working/HPRC/NA19776/r...
# 233   NA19834  [s3://human-pangenomics/working/HPRC/NA19834/r...
# 234   NA19835  [s3://human-pangenomics/working/HPRC/NA19835/r...
# 235   NA19909  [s3://human-pangenomics/working/HPRC/NA19909/r...
# 236   NA20282  [s3://human-pangenomics/working/HPRC/NA20282/r...
# 237   NA20287  [s3://human-pangenomics/working/HPRC/NA20287/r...
# 238   NA20346  [s3://human-pangenomics/working/HPRC/NA20346/r...
# 239   NA20752  [s3://human-pangenomics/working/HPRC/NA20752/r...
# 240   NA20799  [s3://human-pangenomics/working/HPRC/NA20799/r...
# 241   NA20805  [s3://human-pangenomics/working/HPRC/NA20805/r...
# 242   NA20809  [s3://human-pangenomics/working/HPRC/NA20809/r...
# 243   NA20818  [s3://human-pangenomics/working/HPRC/NA20818/r...
# 244   NA20850  [s3://human-pangenomics/working/HPRC/NA20850/r...
# 245   NA20858  [s3://human-pangenomics/working/HPRC/NA20858/r...
# 246   NA20870  [s3://human-pangenomics/working/HPRC/NA20870/r...
# 247   NA20905  [s3://human-pangenomics/working/HPRC/NA20905/r...
# 248   NA21093  [s3://human-pangenomics/working/HPRC/NA21093/r...
# 249   NA21102  [s3://human-pangenomics/working/HPRC/NA21102/r...
# 250   NA21106  [s3://human-pangenomics/working/HPRC/NA21106/r...
# 251   NA21110  [s3://human-pangenomics/working/HPRC/NA21110/r...
# 252   NA21144  [s3://human-pangenomics/working/HPRC/NA21144/r...
#
#      number_of_read_files_downsampled  total_coverage_downsampled  \
# 0                                   3                       63.70
# 1                                   4                       66.30
# 2                                   3                       61.40
# 3                                   2                       63.50
# 4                                   5                       63.80
# 5                                   4                       66.30
# 6                                   6                       66.00
# 7                                   6                       55.40
# 8                                   2                       72.60
# 9                                   5                       60.30
# 10                                  2                       61.60
# 11                                  2                       59.90
# 12                                  2                       64.90
# 13                                  4                       66.50
# 14                                  4                       67.80
# 15                                  4                       59.30
# 16                                  5                       63.30
# 17                                  2                       68.30
# 18                                  4                       61.20
# 19                                 10                       56.70
# 20                                  2                       62.10
# 21                                  3                       65.30
# 22                                  3                       65.80
# 23                                  4                       61.30
# 24                                  5                       57.40
# 25                                  5                       54.10
# 26                                  4                       41.20
# 27                                  7                       60.90
# 28                                  8                       56.50
# 29                                  6                       59.10
# ..                                ...                         ...
# 223                                 6                       57.60
# 224                                 3                       61.10
# 225                                 4                       63.50
# 226                                 4                       60.37
# 227                                 5                       62.80
# 228                                 6                       59.95
# 229                                 4                       62.60
# 230                                 4                       60.60
# 231                                 3                       62.20
# 232                                 3                       62.40
# 233                                 2                       83.50
# 234                                 3                       62.40
# 235                                 2                       71.00
# 236                                 2                       69.80
# 237                                 2                       60.00
# 238                                 2                       60.10
# 239                                 4                       65.50
# 240                                 6                       60.93
# 241                                 4                       53.40
# 242                                 3                       59.10
# 243                                 2                       72.30
# 244                                 3                       60.60
# 245                                 2                       60.80
# 246                                 2                       70.30
# 247                                 5                       54.00
# 248                                 4                       62.50
# 249                                 3                       62.30
# 250                                 4                       63.00
# 251                                 3                       61.90
# 252                                 2                       77.40
#
#      number_of_cores_per_task_downsampled mapper_preset  kmer_size  \
# 0                                      21       lr:hqae         25
# 1                                      16       lr:hqae         25
# 2                                      21       lr:hqae         25
# 3                                      32       lr:hqae         25
# 4                                      12       lr:hqae         25
# 5                                      16       lr:hqae         25
# 6                                      10       lr:hqae         25
# 7                                      10       lr:hqae         25
# 8                                      32       lr:hqae         25
# 9                                      12       lr:hqae         25
# 10                                     32       lr:hqae         25
# 11                                     32       lr:hqae         25
# 12                                     32       lr:hqae         25
# 13                                     16       lr:hqae         25
# 14                                     16       lr:hqae         25
# 15                                     16       lr:hqae         25
# 16                                     12       lr:hqae         25
# 17                                     32       lr:hqae         25
# 18                                     16       lr:hqae         25
# 19                                      6       lr:hqae         25
# 20                                     32       lr:hqae         25
# 21                                     21       lr:hqae         25
# 22                                     21       lr:hqae         25
# 23                                     16       lr:hqae         25
# 24                                     12       lr:hqae         25
# 25                                     12       lr:hqae         25
# 26                                     16       lr:hqae         25
# 27                                      9       lr:hqae         25
# 28                                      8       lr:hqae         25
# 29                                     10       lr:hqae         25
# ..                                    ...           ...        ...
# 223                                    10       lr:hqae         25
# 224                                    21       lr:hqae         25
# 225                                    16       lr:hqae         25
# 226                                    16       lr:hqae         25
# 227                                    12       lr:hqae         25
# 228                                    10       lr:hqae         25
# 229                                    16       lr:hqae         25
# 230                                    16       lr:hqae         25
# 231                                    21       lr:hqae         25
# 232                                    21       lr:hqae         25
# 233                                    32       lr:hqae         25
# 234                                    21       lr:hqae         25
# 235                                    32       lr:hqae         25
# 236                                    32       lr:hqae         25
# 237                                    32       lr:hqae         25
# 238                                    32       lr:hqae         25
# 239                                    16       lr:hqae         25
# 240                                    10       lr:hqae         25
# 241                                    16       lr:hqae         25
# 242                                    21       lr:hqae         25
# 243                                    32       lr:hqae         25
# 244                                    21       lr:hqae         25
# 245                                    32       lr:hqae         25
# 246                                    32       lr:hqae         25
# 247                                    12       lr:hqae         25
# 248                                    16       lr:hqae         25
# 249                                    21       lr:hqae         25
# 250                                    16       lr:hqae         25
# 251                                    21       lr:hqae         25
# 252                                    32       lr:hqae         25
#
#                                             read_files  number_of_read_files  \
# 0    [s3://human-pangenomics/working/HPRC/HG00097/r...                     3
# 1    [s3://human-pangenomics/working/HPRC/HG00099/r...                     4
# 2    [s3://human-pangenomics/working/HPRC/HG00106/r...                     3
# 3    [s3://human-pangenomics/working/HPRC/HG00117/r...                     2
# 4    [s3://human-pangenomics/working/HPRC/HG00126/r...                     5
# 5    [s3://human-pangenomics/working/HPRC/HG00128/r...                     4
# 6    [s3://human-pangenomics/working/HPRC/HG00133/r...                     6
# 7    [s3://human-pangenomics/working/HPRC/HG00140/r...                     6
# 8    [s3://human-pangenomics/working/HPRC/HG00146/r...                     2
# 9    [s3://human-pangenomics/working/HPRC/HG00232/r...                     6
# 10   [s3://human-pangenomics/working/HPRC/HG00235/r...                     2
# 11   [s3://human-pangenomics/working/HPRC/HG00243/r...                     2
# 12   [s3://human-pangenomics/working/HPRC/HG00253/r...                     2
# 13   [s3://human-pangenomics/working/HPRC/HG00258/r...                     4
# 14   [s3://human-pangenomics/working/HPRC/HG00272/r...                     4
# 15   [s3://human-pangenomics/working/HPRC/HG00280/r...                     4
# 16   [s3://human-pangenomics/working/HPRC/HG00290/r...                     5
# 17   [s3://human-pangenomics/working/HPRC/HG00320/r...                     2
# 18   [s3://human-pangenomics/working/HPRC/HG00321/r...                     4
# 19   [s3://human-pangenomics/working/HPRC/HG00323/r...                    10
# 20   [s3://human-pangenomics/working/HPRC/HG00329/r...                     2
# 21   [s3://human-pangenomics/working/HPRC/HG00344/r...                     3
# 22   [s3://human-pangenomics/working/HPRC/HG00350/r...                     3
# 23   [s3://human-pangenomics/working/HPRC/HG00384/r...                     4
# 24   [s3://human-pangenomics/working/HPRC/HG00408/r...                     5
# 25   [s3://human-pangenomics/working/HPRC/HG00423/r...                     5
# 26   [s3://human-pangenomics/working/HPRC/HG00438/r...                     4
# 27   [s3://human-pangenomics/working/HPRC/HG00544/r...                     7
# 28   [s3://human-pangenomics/working/HPRC/HG00558/r...                     8
# 29   [s3://human-pangenomics/working/HPRC/HG00597/r...                     6
# ..                                                 ...                   ...
# 223  [s3://human-pangenomics/working/HPRC/NA19338/r...                     6
# 224  [s3://human-pangenomics/working/HPRC/NA19377/r...                     3
# 225  [s3://human-pangenomics/working/HPRC/NA19390/r...                     4
# 226  [s3://human-pangenomics/working/HPRC/NA19391/r...                     4
# 227  [s3://human-pangenomics/working/HPRC/NA19443/r...                     5
# 228  [s3://human-pangenomics/working/HPRC/NA19468/r...                     6
# 229  [s3://human-pangenomics/working/HPRC/NA19682/r...                     4
# 230  [s3://human-pangenomics/working/HPRC/NA19700/r...                     4
# 231  [s3://human-pangenomics/working/HPRC/NA19703/r...                     3
# 232  [s3://human-pangenomics/working/HPRC/NA19776/r...                     3
# 233  [s3://human-pangenomics/working/HPRC/NA19834/r...                     2
# 234  [s3://human-pangenomics/working/HPRC/NA19835/r...                     3
# 235  [s3://human-pangenomics/working/HPRC/NA19909/r...                     6
# 236  [s3://human-pangenomics/working/HPRC/NA20282/r...                     2
# 237  [s3://human-pangenomics/working/HPRC/NA20287/r...                     2
# 238  [s3://human-pangenomics/working/HPRC/NA20346/r...                     2
# 239  [s3://human-pangenomics/working/HPRC/NA20752/r...                     4
# 240  [s3://human-pangenomics/working/HPRC/NA20799/r...                     6
# 241  [s3://human-pangenomics/working/HPRC/NA20805/r...                     4
# 242  [s3://human-pangenomics/working/HPRC/NA20809/r...                     3
# 243  [s3://human-pangenomics/working/HPRC/NA20818/r...                     2
# 244  [s3://human-pangenomics/working/HPRC/NA20850/r...                     3
# 245  [s3://human-pangenomics/working/HPRC/NA20858/r...                     2
# 246  [s3://human-pangenomics/working/HPRC/NA20870/r...                     2
# 247  [s3://human-pangenomics/working/HPRC/NA20905/r...                     5
# 248  [s3://human-pangenomics/working/HPRC/NA21093/r...                     4
# 249  [s3://human-pangenomics/working/HPRC/NA21102/r...                     3
# 250  [s3://human-pangenomics/working/HPRC/NA21106/r...                     4
# 251  [s3://human-pangenomics/working/HPRC/NA21110/r...                     3
# 252  [s3://human-pangenomics/working/HPRC/NA21144/r...                     2
#
#      total_coverage                                           coverage  \
# 0             63.70                                 [26.4, 19.2, 18.1]
# 1             66.30                           [15.4, 14.7, 16.4, 19.8]
# 2             61.40                                  [27.9, 27.9, 5.6]
# 3             63.50                                       [29.9, 33.6]
# 4             63.80                       [17.9, 8.7, 10.1, 19.2, 7.9]
# 5             66.30                           [13.9, 10.7, 15.2, 26.5]
# 6             66.00                  [14.3, 8.6, 9.7, 7.6, 10.2, 15.6]
# 7             55.40                 [3.3, 10.9, 11.0, 10.4, 9.6, 10.2]
# 8             72.60                                       [36.5, 36.1]
# 9             62.30                   [26.2, 26.7, 2.0, 2.3, 2.5, 2.6]
# 10            61.60                                       [29.2, 32.4]
# 11            59.90                                       [30.4, 29.5]
# 12            64.90                                       [36.0, 28.9]
# 13            66.50                           [16.3, 16.6, 17.4, 16.2]
# 14            67.80                            [21.5, 18.0, 19.1, 9.2]
# 15            59.30                           [15.2, 11.4, 14.8, 17.9]
# 16            63.30                       [19.1, 15.8, 16.8, 8.0, 3.6]
# 17            68.30                                       [28.8, 39.5]
# 18            61.20                             [28.3, 28.1, 2.2, 2.6]
# 19            56.70  [10.8, 11.2, 2.2, 10.9, 3.2, 3.2, 3.0, 3.2, 4....
# 20            62.10                                       [34.2, 27.9]
# 21            65.30                                 [20.6, 19.6, 25.1]
# 22            65.80                                  [6.7, 37.8, 21.3]
# 23            61.30                             [28.1, 29.5, 1.8, 1.9]
# 24            57.40                      [12.5, 12.4, 12.5, 9.8, 10.2]
# 25            54.10                      [11.5, 10.8, 12.4, 11.9, 7.5]
# 26            41.20                            [11.3, 8.4, 10.6, 10.9]
# 27            60.90             [12.2, 9.5, 6.0, 5.6, 6.4, 10.9, 10.3]
# 28            56.50        [10.9, 11.4, 11.0, 0.7, 4.0, 7.5, 8.2, 2.8]
# 29            59.10                [11.0, 10.6, 4.3, 10.8, 11.0, 11.4]
# ..              ...                                                ...
# 223           57.60                [13.1, 11.3, 12.6, 6.5, 6.35, 7.75]
# 224           61.10                                  [27.5, 28.7, 4.9]
# 225           63.50                           [17.3, 17.9, 10.6, 17.7]
# 226           60.37                          [12.7, 12.7, 12.1, 22.87]
# 227           62.80                       [4.5, 18.3, 16.8, 14.7, 8.5]
# 228           59.95               [11.3, 11.9, 11.6, 5.4, 13.26, 6.49]
# 229           62.60                           [17.1, 15.5, 17.4, 12.6]
# 230           60.60                           [13.9, 14.6, 16.1, 16.0]
# 231           62.20                                 [19.3, 25.6, 17.3]
# 232           62.40                                 [20.8, 20.8, 20.8]
# 233           83.50                                       [40.8, 42.7]
# 234           62.40                                  [29.1, 30.8, 2.5]
# 235          189.80               [31.1, 32.9, 24.2, 31.4, 32.1, 38.1]
# 236           69.80                                       [35.8, 34.0]
# 237           60.00                                       [28.4, 31.6]
# 238           60.10                                       [28.2, 31.9]
# 239           65.50                           [15.5, 15.1, 13.6, 21.3]
# 240           60.93               [11.6, 11.5, 10.8, 5.8, 12.09, 9.14]
# 241           53.40                           [12.2, 13.3, 13.3, 14.6]
# 242           59.10                                  [28.1, 27.5, 3.5]
# 243           72.30                                       [37.0, 35.3]
# 244           60.60                                 [20.4, 18.8, 21.4]
# 245           60.80                                       [33.4, 27.4]
# 246           70.30                                       [35.7, 34.6]
# 247           54.00                       [14.2, 13.5, 14.0, 7.1, 5.2]
# 248           62.50                            [19.4, 17.5, 8.5, 17.1]
# 249           62.30                                  [28.6, 29.1, 4.6]
# 250           63.00                            [4.6, 19.1, 20.3, 19.0]
# 251           61.90                                  [28.8, 28.5, 4.6]
# 252           77.40                                       [36.1, 41.3]
#
#      number_of_cores_per_task  \
# 0                          21
# 1                          16
# 2                          21
# 3                          32
# 4                          12
# 5                          16
# 6                          10
# 7                          10
# 8                          32
# 9                          10
# 10                         32
# 11                         32
# 12                         32
# 13                         16
# 14                         16
# 15                         16
# 16                         12
# 17                         32
# 18                         16
# 19                          6
# 20                         32
# 21                         21
# 22                         21
# 23                         16
# 24                         12
# 25                         12
# 26                         16
# 27                          9
# 28                          8
# 29                         10
# ..                        ...
# 223                        10
# 224                        21
# 225                        16
# 226                        16
# 227                        12
# 228                        10
# 229                        16
# 230                        16
# 231                        21
# 232                        21
# 233                        32
# 234                        21
# 235                        10
# 236                        32
# 237                        32
# 238                        32
# 239                        16
# 240                        10
# 241                        16
# 242                        21
# 243                        32
# 244                        21
# 245                        32
# 246                        32
# 247                        12
# 248                        16
# 249                        21
# 250                        16
# 251                        21
# 252                        32
#
#                                       instrument_model  \
# 0                                [Revio, Revio, Revio]
# 1             [Sequel II, Sequel II, Sequel II, Revio]
# 2                                [Revio, Revio, Revio]
# 3                                       [Revio, Revio]
# 4                  [Revio, Revio, Revio, Revio, Revio]
# 5                         [Revio, Revio, Revio, Revio]
# 6           [Revio, Revio, Revio, Revio, Revio, Revio]
# 7    [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 8                                       [Revio, Revio]
# 9           [Revio, Revio, Revio, Revio, Revio, Revio]
# 10                                      [Revio, Revio]
# 11                                      [Revio, Revio]
# 12                                      [Revio, Revio]
# 13                        [Revio, Revio, Revio, Revio]
# 14                        [Revio, Revio, Revio, Revio]
# 15            [Sequel II, Sequel II, Sequel II, Revio]
# 16                 [Revio, Revio, Revio, Revio, Revio]
# 17                                      [Revio, Revio]
# 18                        [Revio, Revio, Revio, Revio]
# 19   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 20                                      [Revio, Revio]
# 21                               [Revio, Revio, Revio]
# 22                               [Revio, Revio, Revio]
# 23                        [Revio, Revio, Revio, Revio]
# 24     [Sequel II, Sequel II, Sequel II, Revio, Revio]
# 25   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 26        [Sequel II, Sequel II, Sequel II, Sequel II]
# 27   [Sequel II, Sequel II, Sequel II, Sequel II, S...
# 28   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 29   [Sequel II, Sequel II, Sequel II, Sequel II, R...
# ..                                                 ...
# 223  [Sequel II, Sequel II, Sequel II, Revio, Revio...
# 224                              [Revio, Revio, Revio]
# 225                       [Revio, Revio, Revio, Revio]
# 226           [Sequel II, Sequel II, Sequel II, Revio]
# 227                [Revio, Revio, Revio, Revio, Revio]
# 228  [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 229                       [Revio, Revio, Revio, Revio]
# 230                       [Revio, Revio, Revio, Revio]
# 231                              [Revio, Revio, Revio]
# 232                              [Revio, Revio, Revio]
# 233                                     [Revio, Revio]
# 234                              [Revio, Revio, Revio]
# 235         [Revio, Revio, Revio, Revio, Revio, Revio]
# 236                                     [Revio, Revio]
# 237                                     [Revio, Revio]
# 238                                     [Revio, Revio]
# 239           [Sequel II, Sequel II, Sequel II, Revio]
# 240  [Sequel II, Sequel II, Sequel II, Sequel II, R...
# 241           [Sequel II, Sequel II, Sequel II, Revio]
# 242                              [Revio, Revio, Revio]
# 243                                     [Revio, Revio]
# 244                              [Revio, Revio, Revio]
# 245                                     [Revio, Revio]
# 246                                     [Revio, Revio]
# 247    [Sequel II, Sequel II, Sequel II, Revio, Revio]
# 248                       [Revio, Revio, Revio, Revio]
# 249                              [Revio, Revio, Revio]
# 250                       [Revio, Revio, Revio, Revio]
# 251                              [Revio, Revio, Revio]
# 252                                     [Revio, Revio]
#
#      hmm_flagger_window_size  \
# 0                      16000
# 1                      16000
# 2                      16000
# 3                      16000
# 4                      16000
# 5                      16000
# 6                      16000
# 7                      16000
# 8                      16000
# 9                      16000
# 10                     16000
# 11                     16000
# 12                     16000
# 13                     16000
# 14                     16000
# 15                     16000
# 16                     16000
# 17                     16000
# 18                     16000
# 19                     16000
# 20                     16000
# 21                     16000
# 22                     16000
# 23                     16000
# 24                     16000
# 25                     16000
# 26                     16000
# 27                     16000
# 28                     16000
# 29                     16000
# ..                       ...
# 223                    16000
# 224                    16000
# 225                    16000
# 226                    16000
# 227                    16000
# 228                    16000
# 229                    16000
# 230                    16000
# 231                    16000
# 232                    16000
# 233                    16000
# 234                    16000
# 235                    16000
# 236                    16000
# 237                    16000
# 238                    16000
# 239                    16000
# 240                    16000
# 241                    16000
# 242                    16000
# 243                    16000
# 244                    16000
# 245                    16000
# 246                    16000
# 247                    16000
# 248                    16000
# 249                    16000
# 250                    16000
# 251                    16000
# 252                    16000
#
#                                  hmm_flagger_alpha_tsv
# 0    https://raw.githubusercontent.com/mobinasri/fl...
# 1    https://raw.githubusercontent.com/mobinasri/fl...
# 2    https://raw.githubusercontent.com/mobinasri/fl...
# 3    https://raw.githubusercontent.com/mobinasri/fl...
# 4    https://raw.githubusercontent.com/mobinasri/fl...
# 5    https://raw.githubusercontent.com/mobinasri/fl...
# 6    https://raw.githubusercontent.com/mobinasri/fl...
# 7    https://raw.githubusercontent.com/mobinasri/fl...
# 8    https://raw.githubusercontent.com/mobinasri/fl...
# 9    https://raw.githubusercontent.com/mobinasri/fl...
# 10   https://raw.githubusercontent.com/mobinasri/fl...
# 11   https://raw.githubusercontent.com/mobinasri/fl...
# 12   https://raw.githubusercontent.com/mobinasri/fl...
# 13   https://raw.githubusercontent.com/mobinasri/fl...
# 14   https://raw.githubusercontent.com/mobinasri/fl...
# 15   https://raw.githubusercontent.com/mobinasri/fl...
# 16   https://raw.githubusercontent.com/mobinasri/fl...
# 17   https://raw.githubusercontent.com/mobinasri/fl...
# 18   https://raw.githubusercontent.com/mobinasri/fl...
# 19   https://raw.githubusercontent.com/mobinasri/fl...
# 20   https://raw.githubusercontent.com/mobinasri/fl...
# 21   https://raw.githubusercontent.com/mobinasri/fl...
# 22   https://raw.githubusercontent.com/mobinasri/fl...
# 23   https://raw.githubusercontent.com/mobinasri/fl...
# 24   https://raw.githubusercontent.com/mobinasri/fl...
# 25   https://raw.githubusercontent.com/mobinasri/fl...
# 26   https://raw.githubusercontent.com/mobinasri/fl...
# 27   https://raw.githubusercontent.com/mobinasri/fl...
# 28   https://raw.githubusercontent.com/mobinasri/fl...
# 29   https://raw.githubusercontent.com/mobinasri/fl...
# ..                                                 ...
# 223  https://raw.githubusercontent.com/mobinasri/fl...
# 224  https://raw.githubusercontent.com/mobinasri/fl...
# 225  https://raw.githubusercontent.com/mobinasri/fl...
# 226  https://raw.githubusercontent.com/mobinasri/fl...
# 227  https://raw.githubusercontent.com/mobinasri/fl...
# 228  https://raw.githubusercontent.com/mobinasri/fl...
# 229  https://raw.githubusercontent.com/mobinasri/fl...
# 230  https://raw.githubusercontent.com/mobinasri/fl...
# 231  https://raw.githubusercontent.com/mobinasri/fl...
# 232  https://raw.githubusercontent.com/mobinasri/fl...
# 233  https://raw.githubusercontent.com/mobinasri/fl...
# 234  https://raw.githubusercontent.com/mobinasri/fl...
# 235  https://raw.githubusercontent.com/mobinasri/fl...
# 236  https://raw.githubusercontent.com/mobinasri/fl...
# 237  https://raw.githubusercontent.com/mobinasri/fl...
# 238  https://raw.githubusercontent.com/mobinasri/fl...
# 239  https://raw.githubusercontent.com/mobinasri/fl...
# 240  https://raw.githubusercontent.com/mobinasri/fl...
# 241  https://raw.githubusercontent.com/mobinasri/fl...
# 242  https://raw.githubusercontent.com/mobinasri/fl...
# 243  https://raw.githubusercontent.com/mobinasri/fl...
# 244  https://raw.githubusercontent.com/mobinasri/fl...
# 245  https://raw.githubusercontent.com/mobinasri/fl...
# 246  https://raw.githubusercontent.com/mobinasri/fl...
# 247  https://raw.githubusercontent.com/mobinasri/fl...
# 248  https://raw.githubusercontent.com/mobinasri/fl...
# 249  https://raw.githubusercontent.com/mobinasri/fl...
# 250  https://raw.githubusercontent.com/mobinasri/fl...
# 251  https://raw.githubusercontent.com/mobinasri/fl...
# 252  https://raw.githubusercontent.com/mobinasri/fl...
#
# [253 rows x 15 columns]

# %%
merged_hifi_full_table.to_csv('hifi_full_reads_table.jan_12_2025.csv', index=False)

# %%
# !find .
# Out:
# .
# ./HPRC_PacBio_HiFi.file.index.csv.1
# ./hifi_full_reads_table.jan_12_2025.csv
# ./HPRC_PacBio_HiFi.file.index.csv
# ./make_hifi_table.ipynb
# ./.ipynb_checkpoints
# ./.ipynb_checkpoints/make_hifi_table-checkpoint.ipynb
