# %%
import numpy as np
import pandas as pd
import sys
import os
import re
BASE_DIR="/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc"

# %% [markdown]
# ### This notebook:
#
# #### Create HiFi and ONT table for censat batch2 data
#
# * There are some samples with new censat annotation from `/private/groups/hprc/qc/batch2/censat/batch2_censat_outputs_done.csv`
# * Makes diploid censat bed files and add links to the final tables
# * Takes read paths from tables
#     * `batch1_jan_12_2025/hmm_flagger/read_tables/hifi_full_reads_table.jan_12_2025.csv`
#     * `batch1/hmm_flagger/read_tables/ont_reads_table.csv`
#     * `batch1/hmm_flagger/read_tables/hifi_reads_table.csv`
# * Makes separate data tables for HiFi and ONT runs (both will contain diploid censat bed files)
# * Saves the final data tables in `hifi/` and `ont/` subdirectories and they will be used for creating input json files

# %%
# !ls
# Out:
# diploid_censat_beds  hifi  make_hmm_flagger_data_tables_batch2.ipynb

# %%
def mergeHaplotypeRows(censat_table):
    # Remove "_hap1" or "_hap2" from 'sample_id' and create a new column 'sample_name'
    censat_table["sample_name"] = censat_table["sample_id"].str.replace(r"_hap[12]$", "", regex=True)

    # make two tables one for hap1 and one for hap2
    censat_table_hap1 = censat_table[censat_table['sample_id'].str.endswith('_hap1', na=False)]
    censat_table_hap2 = censat_table[censat_table['sample_id'].str.endswith('_hap2', na=False)]

    # Merging the DataFrames on 'sample_name'
    censat_table_diploid = pd.merge(censat_table_hap1,
                                    censat_table_hap2,
                                    on='sample_name',
                                    suffixes=('_hap1', '_hap2'))
    censat_table_diploid = censat_table_diploid[["sample_name", 
                                                 "asm_hap1",
                                                 "asm_hap2",
                                                 "cenSatAnnotations_hap1",
                                                 "cenSatAnnotations_hap2"]]

    censat_table_diploid = censat_table_diploid.rename(columns={"sample_name":"sample_id"})
    return censat_table_diploid

# %%
def addDiploidCenSatAnnotation(censat_table_diploid, diploid_censat_dir, create_files):
    # add a column for saving diploid censat bed files
    censat_table_diploid["censat_diploid_bed"] = ""

    # make a directory for saving diploid censat bed files
    # !mkdir -p {diploid_censat_dir}

    censat_diploid_list = []
    additional_annotations_array_list = []
    # iterate over rows
    for i in range(len(censat_table_diploid)):
        sample = censat_table_diploid["sample_id"][i]
        censat_bed_hap1 = censat_table_diploid["cenSatAnnotations_hap1"][i]
        censat_bed_hap2 = censat_table_diploid["cenSatAnnotations_hap2"][i]

        if create_files:
            # concat hap1 and hap2 censat bed files into a single bed file
            # !cat {censat_bed_hap1} {censat_bed_hap2} | bedtools sort -i - > {diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.bed
            # !cat {censat_bed_hap1} {censat_bed_hap2} | bedtools sort -i - | grep -i "rDNA" | awk '{{print $$1"\t"$$2"\t"$$3}}' > {diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.rDNA.bed

        # add new bed to the table
        censat_diploid_list.append(f'{diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.bed')
        # just adding rDNA annotation as an additional annotation
        additional_annotations_array_list.append([f'{diploid_censat_dir}/{sample}_dip_hprc_r2_v1.cenSat.rDNA.bed'])

    censat_table_diploid["censat_diploid_bed"] = censat_diploid_list
    censat_table_diploid["additional_annotations_array"] = additional_annotations_array_list
    #censat_table_diploid.head()
    return censat_table_diploid

# %% [markdown]
# # Create HiFi and ONT table for censat batch2 data

# %%
censat_table_batch2 = pd.read_csv('/private/groups/hprc/qc/batch2/censat/batch2_censat_outputs_done.csv')
print("Number of rows:", len(censat_table_batch2), "Number of samples:", len(censat_table_batch2) / 2)
censat_table_batch2.head()
# Out:
# Number of rows: 40 Number of samples: 20.0
#       sample_id   sample  haplotype phasing assembly_method  \
# 0  HG01975_hap1  HG01975          1    trio         hifiasm
# 1  HG02602_hap1  HG02602          1    trio         hifiasm
# 2  HG04187_hap1  HG04187          1    trio         hifiasm
# 3  NA18879_hap1  NA18879          1     hic         hifiasm
# 4  NA20752_hap1  NA20752          1     hic         hifiasm
#
#   assembly_method_version assembly_date genbank_accession  \
# 0                  0.19.7       2024-12   GCA_046000135.1
# 1                  0.19.9       2024-12   GCA_046000095.1
# 2                  0.19.9       2024-12   GCA_046000115.1
# 3                  0.19.9       2024-12   GCA_046000005.1
# 4                  0.19.9       2024-12   GCA_046000145.1
#
#                                         assembly_md5  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                         assembly_fai  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                          ...                         rmRmskBigBed  \
# 0                        ...                                  NaN
# 1                        ...                                  NaN
# 2                        ...                                  NaN
# 3                        ...                                  NaN
# 4                        ...                                  NaN
#
#                                    repeatMaskerTarGZ  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                            rmOutFile  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                   rmFinalMaskedFasta  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                       rmRmskAlignBed  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                            rmRmskBed  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                                rmBed  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                          centromeres  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                         cenSatStrand  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                    cenSatAnnotations
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
# [5 rows x 28 columns]

# %%
# since in batch2 we have "assembly" column instead of "asm"
# let's rename it so that mergeHaplotypeRows() work properly
censat_table_batch2 = censat_table_batch2.rename(columns={"assembly": "asm"})

# merge rows for two haplotypes into one row with columns having _hap1 and _hap2 suffixes
censat_table_diploid_batch2 = mergeHaplotypeRows(censat_table_batch2)

# a directory for saving/getting diploid censat bed files
diploid_censat_dir_batch2 = f'{BASE_DIR}/batch2/hmm_flagger/diploid_censat_beds'
# I set create_files to False since I ran it once with True before
censat_table_diploid_batch2 = addDiploidCenSatAnnotation(censat_table_diploid = censat_table_diploid_batch2, 
                                                         diploid_censat_dir = diploid_censat_dir_batch2, 
                                                         create_files = False)

# %%
# !cat {BASE_DIR}/batch2/hmm_flagger/diploid_censat_beds/HG01975_dip_hprc_r2_v1.cenSat.rDNA.bed | head
# Out:
# HG01975#1#CM099804.1	35330208	35333289
# HG01975#1#CM099806.1	30102163	30105211
# HG01975#1#CM099806.1	31025828	31028888
# HG01975#1#JBJUVS010000002.1	2147	45912
# HG01975#1#JBJUVS010000002.1	54577	330802
# HG01975#1#JBJUVS010000002.1	2864167	2867245
# HG01975#1#JBJUVS010000004.1	19145	203683
# HG01975#1#JBJUVS010000004.1	6113313	6116368
# HG01975#1#JBJUVS010000005.1	24626	258972
# HG01975#1#JBJUVS010000005.1	2800717	2803795

# %% [markdown]
# ### ONT table for batch2

# %%
# parse ont reads table
ont_reads_table = pd.read_csv(f'{BASE_DIR}/batch1/hmm_flagger/read_tables/ont_reads_table.csv')

# merge with censat batch2 table
merged_ont_data_table_batch2 = pd.merge(censat_table_diploid_batch2, ont_reads_table, on='sample_id',  how='inner')

# %%
print(f"Number of rows for final ONT table: {len(merged_ont_data_table_batch2)}")
merged_ont_data_table_batch2["suffix_mapping"] = merged_ont_data_table_batch2["sequencing_chemistry"] + "_minimap2_2.28"
merged_ont_data_table_batch2
# Out:
# Number of rows for final ONT table: 12
#    sample_id                                           asm_hap1  \
# 0    HG01975  s3://human-pangenomics/submissions/DC27718F-5F...
# 1    HG02602  s3://human-pangenomics/submissions/DC27718F-5F...
# 2    HG04187  s3://human-pangenomics/submissions/DC27718F-5F...
# 3    NA18879  s3://human-pangenomics/submissions/DC27718F-5F...
# 4    HG02738  s3://human-pangenomics/submissions/DC27718F-5F...
# 5    HG00706  s3://human-pangenomics/submissions/DC27718F-5F...
# 6    HG03816  s3://human-pangenomics/submissions/DC27718F-5F...
# 7    HG02392  s3://human-pangenomics/submissions/DC27718F-5F...
# 8    HG02514  s3://human-pangenomics/submissions/DC27718F-5F...
# 9    HG02841  s3://human-pangenomics/submissions/DC27718F-5F...
# 10   HG02984  s3://human-pangenomics/submissions/DC27718F-5F...
# 11   HG03050  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                              asm_hap2  \
# 0   s3://human-pangenomics/submissions/DC27718F-5F...
# 1   s3://human-pangenomics/submissions/DC27718F-5F...
# 2   s3://human-pangenomics/submissions/DC27718F-5F...
# 3   s3://human-pangenomics/submissions/DC27718F-5F...
# 4   s3://human-pangenomics/submissions/DC27718F-5F...
# 5   s3://human-pangenomics/submissions/DC27718F-5F...
# 6   s3://human-pangenomics/submissions/DC27718F-5F...
# 7   s3://human-pangenomics/submissions/DC27718F-5F...
# 8   s3://human-pangenomics/submissions/DC27718F-5F...
# 9   s3://human-pangenomics/submissions/DC27718F-5F...
# 10  s3://human-pangenomics/submissions/DC27718F-5F...
# 11  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                cenSatAnnotations_hap1  \
# 0   /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1   /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2   /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3   /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4   /private/groups/hprc/qc/batch2/censat/HG02738_...
# 5   /private/groups/hprc/qc/batch2/censat/HG00706_...
# 6   /private/groups/hprc/qc/batch2/censat/HG03816_...
# 7   /private/groups/hprc/qc/batch2/censat/HG02392_...
# 8   /private/groups/hprc/qc/batch2/censat/HG02514_...
# 9   /private/groups/hprc/qc/batch2/censat/HG02841_...
# 10  /private/groups/hprc/qc/batch2/censat/HG02984_...
# 11  /private/groups/hprc/qc/batch2/censat/HG03050_...
#
#                                cenSatAnnotations_hap2  \
# 0   /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1   /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2   /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3   /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4   /private/groups/hprc/qc/batch2/censat/HG02738_...
# 5   /private/groups/hprc/qc/batch2/censat/HG00706_...
# 6   /private/groups/hprc/qc/batch2/censat/HG03816_...
# 7   /private/groups/hprc/qc/batch2/censat/HG02392_...
# 8   /private/groups/hprc/qc/batch2/censat/HG02514_...
# 9   /private/groups/hprc/qc/batch2/censat/HG02841_...
# 10  /private/groups/hprc/qc/batch2/censat/HG02984_...
# 11  /private/groups/hprc/qc/batch2/censat/HG03050_...
#
#                                    censat_diploid_bed  \
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                          additional_annotations_array  \
# 0   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 5   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 6   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 7   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 8   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 9   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 10  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 11  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                read_files_downsampled  \
# 0   ['s3://human-pangenomics/working/HPRC/HG01975/...
# 1   ['s3://human-pangenomics/working/HPRC/HG02602/...
# 2   ['s3://human-pangenomics/working/HPRC/HG04187/...
# 3   ['s3://human-pangenomics/working/HPRC/NA18879/...
# 4   ['s3://human-pangenomics/working/HPRC/HG02738/...
# 5   ['s3://human-pangenomics/working/HPRC/HG00706/...
# 6   ['s3://human-pangenomics/working/HPRC/HG03816/...
# 7   ['s3://human-pangenomics/working/HPRC/HG02392/...
# 8   ['s3://human-pangenomics/working/HPRC/HG02514/...
# 9   ['s3://human-pangenomics/working/HPRC/HG02841/...
# 10  ['s3://human-pangenomics/working/HPRC/HG02984/...
# 11  ['s3://human-pangenomics/working/HPRC/HG03050/...
#
#     number_of_read_files_downsampled  total_coverage_downsampled  \
# 0                                  3                       78.43
# 1                                  2                       61.43
# 2                                  4                       47.10
# 3                                  3                       54.67
# 4                                  3                       56.66
# 5                                  3                       72.21
# 6                                  3                       79.52
# 7                                  3                       76.80
# 8                                  3                       64.07
# 9                                  3                       59.53
# 10                                 3                       64.70
# 11                                 3                       60.55
#
#            ...           kmer_size  \
# 0          ...                  15
# 1          ...                  15
# 2          ...                  15
# 3          ...                  25
# 4          ...                  15
# 5          ...                  15
# 6          ...                  15
# 7          ...                  25
# 8          ...                  15
# 9          ...                  15
# 10         ...                  15
# 11         ...                  15
#
#                                            read_files  number_of_read_files  \
# 0   ['s3://human-pangenomics/working/HPRC/HG01975/...                     3
# 1   ['s3://human-pangenomics/working/HPRC/HG02602/...                     3
# 2   ['s3://human-pangenomics/working/HPRC/HG04187/...                     4
# 3   ['s3://human-pangenomics/working/HPRC/NA18879/...                     3
# 4   ['s3://human-pangenomics/working/HPRC/HG02738/...                     3
# 5   ['s3://human-pangenomics/working/HPRC/HG00706/...                     3
# 6   ['s3://human-pangenomics/working/HPRC/HG03816/...                     3
# 7   ['s3://human-pangenomics/working/HPRC/HG02392/...                     3
# 8   ['s3://human-pangenomics/working/HPRC/HG02514/...                     3
# 9   ['s3://human-pangenomics/working/HPRC/HG02841/...                     3
# 10  ['s3://human-pangenomics/working/HPRC/HG02984/...                     4
# 11  ['s3://human-pangenomics/working/HPRC/HG03050/...                     3
#
#    total_coverage                    coverage  number_of_cores_per_task  \
# 0           78.43       [33.07, 22.43, 22.93]                        21
# 1           83.09       [32.31, 29.12, 21.66]                        21
# 2           47.10  [7.78, 20.02, 18.44, 0.86]                        16
# 3           54.67       [18.49, 17.84, 18.34]                        21
# 4           56.66         [6.17, 21.49, 29.0]                        21
# 5           72.21       [22.45, 27.23, 22.53]                        21
# 6           79.52       [28.94, 20.57, 30.01]                        21
# 7           76.80        [24.26, 22.84, 29.7]                        21
# 8           64.07       [21.49, 22.59, 19.99]                        21
# 9           59.53       [19.14, 13.88, 26.51]                        21
# 10          71.35  [30.86, 23.24, 10.6, 6.65]                        16
# 11          60.55       [23.24, 15.72, 21.59]                        21
#
#    sequencing_chemistry  hmm_flagger_window_size  \
# 0                  R941                    16000
# 1                  R941                    16000
# 2                  R941                    16000
# 3                 R1041                     8000
# 4                  R941                    16000
# 5                  R941                    16000
# 6                  R941                    16000
# 7                 R1041                     8000
# 8                  R941                    16000
# 9                  R941                    16000
# 10                 R941                    16000
# 11                 R941                    16000
#
#                                 hmm_flagger_alpha_tsv       suffix_mapping
# 0   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 1   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 2   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 3   https://raw.githubusercontent.com/mobinasri/fl...  R1041_minimap2_2.28
# 4   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 5   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 6   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 7   https://raw.githubusercontent.com/mobinasri/fl...  R1041_minimap2_2.28
# 8   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 9   https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 10  https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
# 11  https://raw.githubusercontent.com/mobinasri/fl...   R941_minimap2_2.28
#
# [12 rows x 22 columns]

# %%
missing_samples = set(censat_table_diploid_batch2['sample_id']).difference(merged_ont_data_table_batch2['sample_id'])
print(f"These {len(missing_samples)} samples don't have ONT reads for censat batch 2: \n")
print("\n".join(missing_samples))
# Out:
# These 8 samples don't have ONT reads for censat batch 2:
#
# NA20752
# NA19159
# HG005
# HG02145
# NA19240
# HG00733
# HG01243
# NA20799

# %% [markdown]
# ### HiFi table for batch2

# %%
# parse hifi reads table (jan 12 2025 version containing both Revio and DeepConsensus)
hifi_full_reads_table = pd.read_csv(f'{BASE_DIR}/batch1_jan_12_2025/hmm_flagger/read_tables/hifi_full_reads_table.jan_12_2025.csv')

# parse hifi Deepconsensus reads table
# this table contains only DeepConsensus reads and I used it for batch1 of HMM-Flagger runs
# there are some samples with higher coverage in hifi_additional_reads_table
# so I prioritize hifi_full_reads_table
hifi_dc_reads_table = pd.read_csv(f'{BASE_DIR}/batch1/hmm_flagger/read_tables/hifi_reads_table.csv')

# merge with censat batch2 table
hifi_full_data_table_batch2 = pd.merge(censat_table_diploid_batch2, hifi_full_reads_table, on='sample_id',  how='inner')

# if there are some common samples between "hifi_additional_reads_table" and "hifi_reads_table"
# here I prioritize "hifi_additional_reads_table" over "hifi_reads_table"
# since the coverage is generally higher in the former one
samples_with_hifi_full_batch2 = hifi_full_data_table_batch2['sample_id']

hifi_dc_data_table_batch2 = pd.merge(censat_table_diploid_batch2, hifi_dc_reads_table, on='sample_id',  how='inner')
# remove common samples
hifi_dc_data_table_batch2 = hifi_dc_data_table_batch2[~hifi_dc_data_table_batch2['sample_id'].isin(samples_with_hifi_full_batch2)]

# %%
print(f"Number of rows in hifi full reads table (jan 12 2025 version) with censat batch2: {len(hifi_full_data_table_batch2)}")
hifi_full_data_table_batch2.head()
# Out:
# Number of rows in hifi full reads table (jan 12 2025 version) with censat batch2: 15
#   sample_id                                           asm_hap1  \
# 0   HG01975  s3://human-pangenomics/submissions/DC27718F-5F...
# 1   HG02602  s3://human-pangenomics/submissions/DC27718F-5F...
# 2   HG04187  s3://human-pangenomics/submissions/DC27718F-5F...
# 3   NA18879  s3://human-pangenomics/submissions/DC27718F-5F...
# 4   NA20752  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                             asm_hap2  \
# 0  s3://human-pangenomics/submissions/DC27718F-5F...
# 1  s3://human-pangenomics/submissions/DC27718F-5F...
# 2  s3://human-pangenomics/submissions/DC27718F-5F...
# 3  s3://human-pangenomics/submissions/DC27718F-5F...
# 4  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                               cenSatAnnotations_hap1  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                               cenSatAnnotations_hap2  \
# 0  /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1  /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2  /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3  /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4  /private/groups/hprc/qc/batch2/censat/NA20752_...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                         additional_annotations_array  \
# 0  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                               read_files_downsampled  \
# 0  ['s3://human-pangenomics/working/HPRC/HG01975/...
# 1  ['s3://human-pangenomics/working/HPRC/HG02602/...
# 2  ['s3://human-pangenomics/working/HPRC/HG04187/...
# 3  ['s3://human-pangenomics/working/HPRC/NA18879/...
# 4  ['s3://human-pangenomics/working/HPRC/NA20752/...
#
#    number_of_read_files_downsampled  total_coverage_downsampled  \
# 0                                 6                        58.8
# 1                                 7                        59.9
# 2                                 1                        28.4
# 3                                 5                        63.8
# 4                                 4                        65.5
#
#                          ...                          mapper_preset kmer_size  \
# 0                        ...                                lr:hqae        25
# 1                        ...                                lr:hqae        25
# 2                        ...                                lr:hqae        25
# 3                        ...                                lr:hqae        25
# 4                        ...                                lr:hqae        25
#
#                                           read_files number_of_read_files  \
# 0  ['s3://human-pangenomics/working/HPRC/HG01975/...                    6
# 1  ['s3://human-pangenomics/working/HPRC/HG02602/...                    7
# 2  ['s3://human-pangenomics/working/HPRC/HG04187/...                    1
# 3  ['s3://human-pangenomics/working/HPRC/NA18879/...                    5
# 4  ['s3://human-pangenomics/working/HPRC/NA20752/...                    4
#
#    total_coverage                              coverage  \
# 0            58.8    [12.1, 11.7, 1.9, 9.4, 11.7, 12.0]
# 1            59.9  [6.4, 8.1, 6.4, 11.7, 8.8, 9.5, 9.0]
# 2            28.4                                [28.4]
# 3            63.8        [10.9, 11.6, 11.4, 11.0, 18.9]
# 4            65.5              [15.5, 15.1, 13.6, 21.3]
#
#   number_of_cores_per_task                                   instrument_model  \
# 0                       10  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...
# 1                        9  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...
# 2                       64                                          ['Revio']
# 3                       12      ['Revio', 'Revio', 'Revio', 'Revio', 'Revio']
# 4                       16   ['Sequel II', 'Sequel II', 'Sequel II', 'Revio']
#
#   hmm_flagger_window_size                              hmm_flagger_alpha_tsv
# 0                   16000  https://raw.githubusercontent.com/mobinasri/fl...
# 1                   16000  https://raw.githubusercontent.com/mobinasri/fl...
# 2                   16000  https://raw.githubusercontent.com/mobinasri/fl...
# 3                   16000  https://raw.githubusercontent.com/mobinasri/fl...
# 4                   16000  https://raw.githubusercontent.com/mobinasri/fl...
#
# [5 rows x 21 columns]

# %%
print(f"Number of rows in hifi deepconsensus reads table with censat batch2: {len(hifi_dc_data_table_batch2)}")
hifi_dc_data_table_batch2.head()
# Out:
# Number of rows in hifi deepconsensus reads table with censat batch2: 3
#    sample_id                                           asm_hap1  \
# 4    HG02145  s3://human-pangenomics/submissions/DC27718F-5F...
# 12   HG01243  s3://human-pangenomics/submissions/DC27718F-5F...
# 13   NA19240  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                              asm_hap2  \
# 4   s3://human-pangenomics/submissions/DC27718F-5F...
# 12  s3://human-pangenomics/submissions/DC27718F-5F...
# 13  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                cenSatAnnotations_hap1  \
# 4   /private/groups/hprc/qc/batch2/censat/HG02145_...
# 12  /private/groups/hprc/qc/batch2/censat/HG01243_...
# 13  /private/groups/hprc/qc/batch2/censat/NA19240_...
#
#                                cenSatAnnotations_hap2  \
# 4   /private/groups/hprc/qc/batch2/censat/HG02145_...
# 12  /private/groups/hprc/qc/batch2/censat/HG01243_...
# 13  /private/groups/hprc/qc/batch2/censat/NA19240_...
#
#                                    censat_diploid_bed  \
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                          additional_annotations_array  \
# 4   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 12  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 13  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                            read_files  number_of_read_files  \
# 4   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 12  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 13  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
#
#     total_coverage                  coverage mapper_preset  kmer_size  \
# 4            43.28  [11.21, 8.8, 9.77, 13.5]       lr:hqae         25
# 12           42.18      [15.29, 13.1, 13.79]       lr:hqae         25
# 13           35.24       [12.44, 11.3, 11.5]       lr:hqae         25
#
#     number_of_cores_per_task  hmm_flagger_window_size  \
# 4                         16                    16000
# 12                        21                    16000
# 13                        21                    16000
#
#                                 hmm_flagger_alpha_tsv
# 4   https://raw.githubusercontent.com/mobinasri/fl...
# 12  https://raw.githubusercontent.com/mobinasri/fl...
# 13  https://raw.githubusercontent.com/mobinasri/fl...

# %%
# since we are going to use the columns that end with "_downsampled" for creating WDL json files
# and hifi DeepConsensus tables didnot have those I will make them here
hifi_dc_data_table_batch2["read_files_downsampled"] = hifi_dc_data_table_batch2["read_files"]
hifi_dc_data_table_batch2["total_coverage_downsampled"] = hifi_dc_data_table_batch2["total_coverage"]
hifi_dc_data_table_batch2["number_of_read_files_downsampled"] = hifi_dc_data_table_batch2["number_of_read_files"]
hifi_dc_data_table_batch2["number_of_cores_per_task_downsampled"] = hifi_dc_data_table_batch2["number_of_cores_per_task"]

# %%
# Concatenate vertically
merged_hifi_data_table_batch2 = pd.concat([hifi_full_data_table_batch2, hifi_dc_data_table_batch2], sort=False)
merged_hifi_data_table_batch2.index = np.arange(len(merged_hifi_data_table_batch2))
merged_hifi_data_table_batch2
# Out:
#    sample_id                                           asm_hap1  \
# 0    HG01975  s3://human-pangenomics/submissions/DC27718F-5F...
# 1    HG02602  s3://human-pangenomics/submissions/DC27718F-5F...
# 2    HG04187  s3://human-pangenomics/submissions/DC27718F-5F...
# 3    NA18879  s3://human-pangenomics/submissions/DC27718F-5F...
# 4    NA20752  s3://human-pangenomics/submissions/DC27718F-5F...
# 5    HG02738  s3://human-pangenomics/submissions/DC27718F-5F...
# 6    HG00706  s3://human-pangenomics/submissions/DC27718F-5F...
# 7    HG03816  s3://human-pangenomics/submissions/DC27718F-5F...
# 8    NA19159  s3://human-pangenomics/submissions/DC27718F-5F...
# 9    HG02392  s3://human-pangenomics/submissions/DC27718F-5F...
# 10   HG02514  s3://human-pangenomics/submissions/DC27718F-5F...
# 11   HG02841  s3://human-pangenomics/submissions/DC27718F-5F...
# 12   HG02984  s3://human-pangenomics/submissions/DC27718F-5F...
# 13   HG03050  s3://human-pangenomics/submissions/DC27718F-5F...
# 14   NA20799  s3://human-pangenomics/submissions/DC27718F-5F...
# 15   HG02145  s3://human-pangenomics/submissions/DC27718F-5F...
# 16   HG01243  s3://human-pangenomics/submissions/DC27718F-5F...
# 17   NA19240  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                              asm_hap2  \
# 0   s3://human-pangenomics/submissions/DC27718F-5F...
# 1   s3://human-pangenomics/submissions/DC27718F-5F...
# 2   s3://human-pangenomics/submissions/DC27718F-5F...
# 3   s3://human-pangenomics/submissions/DC27718F-5F...
# 4   s3://human-pangenomics/submissions/DC27718F-5F...
# 5   s3://human-pangenomics/submissions/DC27718F-5F...
# 6   s3://human-pangenomics/submissions/DC27718F-5F...
# 7   s3://human-pangenomics/submissions/DC27718F-5F...
# 8   s3://human-pangenomics/submissions/DC27718F-5F...
# 9   s3://human-pangenomics/submissions/DC27718F-5F...
# 10  s3://human-pangenomics/submissions/DC27718F-5F...
# 11  s3://human-pangenomics/submissions/DC27718F-5F...
# 12  s3://human-pangenomics/submissions/DC27718F-5F...
# 13  s3://human-pangenomics/submissions/DC27718F-5F...
# 14  s3://human-pangenomics/submissions/DC27718F-5F...
# 15  s3://human-pangenomics/submissions/DC27718F-5F...
# 16  s3://human-pangenomics/submissions/DC27718F-5F...
# 17  s3://human-pangenomics/submissions/DC27718F-5F...
#
#                                cenSatAnnotations_hap1  \
# 0   /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1   /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2   /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3   /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4   /private/groups/hprc/qc/batch2/censat/NA20752_...
# 5   /private/groups/hprc/qc/batch2/censat/HG02738_...
# 6   /private/groups/hprc/qc/batch2/censat/HG00706_...
# 7   /private/groups/hprc/qc/batch2/censat/HG03816_...
# 8   /private/groups/hprc/qc/batch2/censat/NA19159_...
# 9   /private/groups/hprc/qc/batch2/censat/HG02392_...
# 10  /private/groups/hprc/qc/batch2/censat/HG02514_...
# 11  /private/groups/hprc/qc/batch2/censat/HG02841_...
# 12  /private/groups/hprc/qc/batch2/censat/HG02984_...
# 13  /private/groups/hprc/qc/batch2/censat/HG03050_...
# 14  /private/groups/hprc/qc/batch2/censat/NA20799_...
# 15  /private/groups/hprc/qc/batch2/censat/HG02145_...
# 16  /private/groups/hprc/qc/batch2/censat/HG01243_...
# 17  /private/groups/hprc/qc/batch2/censat/NA19240_...
#
#                                cenSatAnnotations_hap2  \
# 0   /private/groups/hprc/qc/batch2/censat/HG01975_...
# 1   /private/groups/hprc/qc/batch2/censat/HG02602_...
# 2   /private/groups/hprc/qc/batch2/censat/HG04187_...
# 3   /private/groups/hprc/qc/batch2/censat/NA18879_...
# 4   /private/groups/hprc/qc/batch2/censat/NA20752_...
# 5   /private/groups/hprc/qc/batch2/censat/HG02738_...
# 6   /private/groups/hprc/qc/batch2/censat/HG00706_...
# 7   /private/groups/hprc/qc/batch2/censat/HG03816_...
# 8   /private/groups/hprc/qc/batch2/censat/NA19159_...
# 9   /private/groups/hprc/qc/batch2/censat/HG02392_...
# 10  /private/groups/hprc/qc/batch2/censat/HG02514_...
# 11  /private/groups/hprc/qc/batch2/censat/HG02841_...
# 12  /private/groups/hprc/qc/batch2/censat/HG02984_...
# 13  /private/groups/hprc/qc/batch2/censat/HG03050_...
# 14  /private/groups/hprc/qc/batch2/censat/NA20799_...
# 15  /private/groups/hprc/qc/batch2/censat/HG02145_...
# 16  /private/groups/hprc/qc/batch2/censat/HG01243_...
# 17  /private/groups/hprc/qc/batch2/censat/NA19240_...
#
#                                    censat_diploid_bed  \
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                          additional_annotations_array  \
# 0   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 5   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 6   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 7   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 8   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 9   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 10  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 11  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 12  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 13  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 14  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 15  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 16  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 17  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                read_files_downsampled  \
# 0   ['s3://human-pangenomics/working/HPRC/HG01975/...
# 1   ['s3://human-pangenomics/working/HPRC/HG02602/...
# 2   ['s3://human-pangenomics/working/HPRC/HG04187/...
# 3   ['s3://human-pangenomics/working/HPRC/NA18879/...
# 4   ['s3://human-pangenomics/working/HPRC/NA20752/...
# 5   ['s3://human-pangenomics/working/HPRC/HG02738/...
# 6   ['s3://human-pangenomics/working/HPRC/HG00706/...
# 7   ['s3://human-pangenomics/working/HPRC/HG03816/...
# 8   ['s3://human-pangenomics/working/HPRC/NA19159/...
# 9   ['s3://human-pangenomics/working/HPRC/HG02392/...
# 10  ['s3://human-pangenomics/working/HPRC/HG02514/...
# 11  ['s3://human-pangenomics/working/HPRC/HG02841/...
# 12  ['s3://human-pangenomics/working/HPRC/HG02984/...
# 13  ['s3://human-pangenomics/working/HPRC/HG03050/...
# 14  ['s3://human-pangenomics/working/HPRC/NA20799/...
# 15  ['s3://human-pangenomics/submissions/3A25CF8A-...
# 16  ['s3://human-pangenomics/submissions/3A25CF8A-...
# 17  ['s3://human-pangenomics/submissions/3A25CF8A-...
#
#     number_of_read_files_downsampled  total_coverage_downsampled  \
# 0                                  6                       58.80
# 1                                  7                       59.90
# 2                                  1                       28.40
# 3                                  5                       63.80
# 4                                  4                       65.50
# 5                                  6                       58.20
# 6                                  5                       61.10
# 7                                  5                       59.90
# 8                                  4                       52.54
# 9                                  4                       60.60
# 10                                 6                       54.64
# 11                                 8                       62.36
# 12                                 7                       58.74
# 13                                 6                       47.17
# 14                                 6                       60.93
# 15                                 4                       43.28
# 16                                 3                       42.18
# 17                                 3                       35.24
#
#                           ...                          mapper_preset  \
# 0                         ...                                lr:hqae
# 1                         ...                                lr:hqae
# 2                         ...                                lr:hqae
# 3                         ...                                lr:hqae
# 4                         ...                                lr:hqae
# 5                         ...                                lr:hqae
# 6                         ...                                lr:hqae
# 7                         ...                                lr:hqae
# 8                         ...                                lr:hqae
# 9                         ...                                lr:hqae
# 10                        ...                                lr:hqae
# 11                        ...                                lr:hqae
# 12                        ...                                lr:hqae
# 13                        ...                                lr:hqae
# 14                        ...                                lr:hqae
# 15                        ...                                lr:hqae
# 16                        ...                                lr:hqae
# 17                        ...                                lr:hqae
#
#    kmer_size                                         read_files  \
# 0         25  ['s3://human-pangenomics/working/HPRC/HG01975/...
# 1         25  ['s3://human-pangenomics/working/HPRC/HG02602/...
# 2         25  ['s3://human-pangenomics/working/HPRC/HG04187/...
# 3         25  ['s3://human-pangenomics/working/HPRC/NA18879/...
# 4         25  ['s3://human-pangenomics/working/HPRC/NA20752/...
# 5         25  ['s3://human-pangenomics/working/HPRC/HG02738/...
# 6         25  ['s3://human-pangenomics/working/HPRC/HG00706/...
# 7         25  ['s3://human-pangenomics/working/HPRC/HG03816/...
# 8         25  ['s3://human-pangenomics/working/HPRC/NA19159/...
# 9         25  ['s3://human-pangenomics/working/HPRC/HG02392/...
# 10        25  ['s3://human-pangenomics/working/HPRC/HG02514/...
# 11        25  ['s3://human-pangenomics/working/HPRC/HG02841/...
# 12        25  ['s3://human-pangenomics/working/HPRC/HG02984/...
# 13        25  ['s3://human-pangenomics/working/HPRC/HG03050/...
# 14        25  ['s3://human-pangenomics/working/HPRC/NA20799/...
# 15        25  ['s3://human-pangenomics/submissions/3A25CF8A-...
# 16        25  ['s3://human-pangenomics/submissions/3A25CF8A-...
# 17        25  ['s3://human-pangenomics/submissions/3A25CF8A-...
#
#    number_of_read_files  total_coverage  \
# 0                     6           58.80
# 1                     7           59.90
# 2                     1           28.40
# 3                     5           63.80
# 4                     4           65.50
# 5                     6           58.20
# 6                     5           61.10
# 7                     5           59.90
# 8                     4           52.54
# 9                     5           62.20
# 10                    6           54.64
# 11                    8           62.36
# 12                    7           58.74
# 13                    6           47.17
# 14                    6           60.93
# 15                    4           43.28
# 16                    3           42.18
# 17                    3           35.24
#
#                                           coverage number_of_cores_per_task  \
# 0               [12.1, 11.7, 1.9, 9.4, 11.7, 12.0]                       10
# 1             [6.4, 8.1, 6.4, 11.7, 8.8, 9.5, 9.0]                        9
# 2                                           [28.4]                       64
# 3                   [10.9, 11.6, 11.4, 11.0, 18.9]                       12
# 4                         [15.5, 15.1, 13.6, 21.3]                       16
# 5                 [7.2, 7.8, 7.4, 8.1, 15.8, 11.9]                       10
# 6                       [8.9, 7.8, 9.5, 9.5, 25.4]                       12
# 7                       [7.9, 8.5, 9.0, 8.6, 25.9]                       12
# 8                         [14.9, 14.9, 15.1, 7.64]                       16
# 9                     [21.4, 22.7, 12.2, 1.6, 4.3]                       12
# 10              [5.1, 10.2, 4.5, 10.0, 5.1, 19.74]                       10
# 11  [10.1, 10.3, 10.2, 2.9, 3.6, 8.52, 8.38, 8.36]                        8
# 12           [7.0, 8.4, 7.3, 6.4, 0.6, 5.6, 23.44]                        9
# 13              [11.5, 10.1, 3.0, 8.6, 3.5, 10.47]                       10
# 14            [11.6, 11.5, 10.8, 5.8, 12.09, 9.14]                       10
# 15                        [11.21, 8.8, 9.77, 13.5]                       16
# 16                            [15.29, 13.1, 13.79]                       21
# 17                             [12.44, 11.3, 11.5]                       21
#
#                                      instrument_model hmm_flagger_window_size  \
# 0   ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 1   ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 2                                           ['Revio']                   16000
# 3       ['Revio', 'Revio', 'Revio', 'Revio', 'Revio']                   16000
# 4    ['Sequel II', 'Sequel II', 'Sequel II', 'Revio']                   16000
# 5   ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 6   ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 7   ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 8    ['Sequel II', 'Sequel II', 'Sequel II', 'Revio']                   16000
# 9       ['Revio', 'Revio', 'Revio', 'Revio', 'Revio']                   16000
# 10  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 11  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 12  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 13  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 14  ['Sequel II', 'Sequel II', 'Sequel II', 'Seque...                   16000
# 15                                                NaN                   16000
# 16                                                NaN                   16000
# 17                                                NaN                   16000
#
#                                 hmm_flagger_alpha_tsv
# 0   https://raw.githubusercontent.com/mobinasri/fl...
# 1   https://raw.githubusercontent.com/mobinasri/fl...
# 2   https://raw.githubusercontent.com/mobinasri/fl...
# 3   https://raw.githubusercontent.com/mobinasri/fl...
# 4   https://raw.githubusercontent.com/mobinasri/fl...
# 5   https://raw.githubusercontent.com/mobinasri/fl...
# 6   https://raw.githubusercontent.com/mobinasri/fl...
# 7   https://raw.githubusercontent.com/mobinasri/fl...
# 8   https://raw.githubusercontent.com/mobinasri/fl...
# 9   https://raw.githubusercontent.com/mobinasri/fl...
# 10  https://raw.githubusercontent.com/mobinasri/fl...
# 11  https://raw.githubusercontent.com/mobinasri/fl...
# 12  https://raw.githubusercontent.com/mobinasri/fl...
# 13  https://raw.githubusercontent.com/mobinasri/fl...
# 14  https://raw.githubusercontent.com/mobinasri/fl...
# 15  https://raw.githubusercontent.com/mobinasri/fl...
# 16  https://raw.githubusercontent.com/mobinasri/fl...
# 17  https://raw.githubusercontent.com/mobinasri/fl...
#
# [18 rows x 21 columns]

# %%
missing_samples = set(censat_table_diploid_batch2['sample_id']).difference(merged_hifi_data_table_batch2['sample_id'])
print(f"These {len(missing_samples)} samples don't have HiFi reads for censat batch 2: \n")
print("\n".join(missing_samples))
# Out:
# These 2 samples don't have HiFi reads for censat batch 2:
#
# HG00733
# HG005

# %%
os.makedirs("ont", exist_ok=True)
merged_ont_data_table_batch2.to_csv('ont/hmm_flagger_ont_data_table.csv', index=False)

os.makedirs("hifi", exist_ok=True)
merged_hifi_data_table_batch2.to_csv('hifi/hmm_flagger_hifi_data_table.csv', index=False)
