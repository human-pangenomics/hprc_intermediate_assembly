# %%
import numpy as np
import pandas as pd
import sys
import os
import re

# %% [markdown]
# ### This notebook:
# - Opens `hprc_y1_annotation_table.output.csv`
# - Makes diploid censat bed files and add links to the final tables
# - Opens `Year1_assemblies_v2_genbank.index`
# - Adds assembly links to the final tables
# - Takes read paths from tables `/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/ont_reads_table.csv` and `/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/batch1/hmm_flagger/read_tables/hifi_reads_table.csv`
# - Makes separate data tables for HiFi and ONT runs (both will contain diploid censat bed files)
# - Saves the final data tables in `hifi/` and `ont/` subdirectories and they will be used for creating input json files

# %%
# !ls
# Out:
# hprc_y1_annotation_table.output.csv  Year1_assemblies_v2_genbank.index
# make_hmm_flagger_data_tables.ipynb

# %%
# copy censat annotation table here
# !cp ../censat/hprc_y1_annotation_table.output.csv .

# %%
# get the assembly table
#!wget https://raw.githubusercontent.com/human-pangenomics/HPP_Year1_Assemblies/refs/heads/main/assembly_index/Year1_assemblies_v2_genbank.index
# Out:
# --2024-12-06 19:12:13--  https://raw.githubusercontent.com/human-pangenomics/HPP_Year1_Assemblies/refs/heads/main/assembly_index/Year1_assemblies_v2_genbank.index
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34026 (33K) [text/plain]
# Saving to: ‘Year1_assemblies_v2_genbank.index.1’
#
# Year1_assemblies_v2 100%[===================>]  33.23K  --.-KB/s    in 0s
#
# 2024-12-06 19:12:13 (98.2 MB/s) - ‘Year1_assemblies_v2_genbank.index.1’ saved [34026/34026]

# %%
censat_table = pd.read_csv('hprc_y1_annotation_table.output.csv')
print("Number of rows:", len(censat_table))
censat_table.head()
# Out:
# Number of rows: 94
#           sample_id                         overlap_filtered_path_asat  \
# 0    HG002_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1    HG002_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  HG00438_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  HG00438_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4    HG005_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                     public_link_asat  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                     public_link_hsat  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                       public_link_rm  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                            aws_fasta  \
# 0  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 1  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 2  s3://human-pangenomics/working/HPRC/HG00438/as...
# 3  s3://human-pangenomics/working/HPRC/HG00438/as...
# 4  s3://human-pangenomics/working/HPRC_PLUS/HG005...
#
#                                    cenSatAnnotations
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...

# %%
# Remove "_hap1" or "_hap2" from 'sample_id' and create a new column 'sample_name'
censat_table["sample_name"] = censat_table["sample_id"].str.replace(r"_.*ernal$", "", regex=True)

# make two tables one for hap1 and one for hap2
censat_table_hap1 = censat_table[censat_table['sample_id'].str.endswith('_paternal', na=False)]
censat_table_hap2 = censat_table[censat_table['sample_id'].str.endswith('_maternal', na=False)]

#print(censat_table_hap1 )
# Merging the DataFrames on 'sample_name'
censat_table_diploid = pd.merge(censat_table_hap1,
                                censat_table_hap2,
                                on='sample_name',
                                suffixes=('_hap1', '_hap2'))
censat_table_diploid = censat_table_diploid[["sample_name",
                                             "cenSatAnnotations_hap1",
                                             "cenSatAnnotations_hap2"]]

censat_table_diploid = censat_table_diploid.rename(columns={"sample_name":"sample_id"})
censat_table_diploid
# Out:
#    sample_id                             cenSatAnnotations_hap1  \
# 0      HG002  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1    HG00438  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2      HG005                                                NaN
# 3    HG00621  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4    HG00673  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5    HG00733                                                NaN
# 6    HG00735  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7    HG00741  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8    HG01071  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9    HG01106  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10   HG01109  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11   HG01123  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12   HG01175  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13   HG01243  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14   HG01258  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15   HG01358  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16   HG01361  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17   HG01891  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18   HG01928  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 19   HG01952  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 20   HG01978  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 21   HG02055  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 22   HG02080  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 23   HG02109  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 24   HG02145                                                NaN
# 25   HG02148  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 26   HG02257  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 27   HG02486  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 28   HG02559  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 29   HG02572                                                NaN
# 30   HG02622  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 31   HG02630  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 32   HG02717  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 33   HG02723  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 34   HG02818  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 35   HG02886  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 36   HG03098  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 37   HG03453  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 38   HG03486  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 39   HG03492  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 40   HG03516  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 41   HG03540  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 42   HG03579  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 43   NA18906  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 44   NA19240  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 45   NA20129  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 46   NA21309  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                cenSatAnnotations_hap2
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 19  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 20  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 21  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 22  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 23  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 24  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 25  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 26  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 27  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 28  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 29                                                NaN
# 30  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 31  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 32  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 33  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 34                                                NaN
# 35  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 36  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 37  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 38  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 39  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 40  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 41  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 42  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 43  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 44  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 45  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 46  /private/groups/hprc/qc_hmm_flagger/hprc_inter...

# %%
# add a column for saving diploid censat bed files
censat_table_diploid["censat_diploid_bed"] = ""

# make a directory for saving diploid censat bed files
diploid_censat_dir = f'{os.getcwd()}/diploid_censat_beds'
# !rm -rf {diploid_censat_dir}
# !mkdir -p {diploid_censat_dir}

censat_diploid_list = []
additional_annotations_array_list = []
# iterate over rows
for i in range(len(censat_table_diploid)):
    sample = censat_table_diploid["sample_id"][i]
    censat_bed_hap1 = censat_table_diploid["cenSatAnnotations_hap1"][i]
    censat_bed_hap2 = censat_table_diploid["cenSatAnnotations_hap2"][i]
    
    if pd.isna(censat_bed_hap1) or pd.isna(censat_bed_hap2):
        censat_diploid_list.append(np.nan)
        additional_annotations_array_list.append([])
        print(f'{sample} is NaN')
        continue
    
    # concat hap1 and hap2 censat bed files into a single bed file
    # !cat {censat_bed_hap1} {censat_bed_hap2} | bedtools sort -i - > {diploid_censat_dir}/{sample}_dip_hprc_r1.cenSat.bed
    # !cat {censat_bed_hap1} {censat_bed_hap2} | bedtools sort -i - | grep -i "rDNA" | awk '{{print $$1"\t"$$2"\t"$$3}}' > {diploid_censat_dir}/{sample}_dip_hprc_r1.cenSat.rDNA.bed
    
    print(f'Merged {sample}')
    # add new bed to the table
    censat_diploid_list.append(f'{diploid_censat_dir}/{sample}_dip_hprc_r1.cenSat.bed')
    additional_annotations_array_list.append([f'{diploid_censat_dir}/{sample}_dip_hprc_r1.cenSat.rDNA.bed'])

censat_table_diploid["censat_diploid_bed"] = censat_diploid_list
censat_table_diploid["additional_annotations_array"] = additional_annotations_array_list
censat_table_diploid.head()
# Out:
# Merged HG002
# Merged HG00438
# HG005 is NaN
# Merged HG00621
# Merged HG00673
# HG00733 is NaN
# Merged HG00735
# Merged HG00741
# Merged HG01071
# Merged HG01106
# Merged HG01109
# Merged HG01123
# Merged HG01175
# Merged HG01243
# Merged HG01258
# Merged HG01358
# Merged HG01361
# Merged HG01891
# Merged HG01928
# Merged HG01952
# Merged HG01978
# Merged HG02055
# Merged HG02080
# Merged HG02109
# HG02145 is NaN
# Merged HG02148
# Merged HG02257
# Merged HG02486
# Merged HG02559
# HG02572 is NaN
# Merged HG02622
# Merged HG02630
# Merged HG02717
# Merged HG02723
# HG02818 is NaN
# Merged HG02886
# Merged HG03098
# Merged HG03453
# Merged HG03486
# Merged HG03492
# Merged HG03516
# Merged HG03540
# Merged HG03579
# Merged NA18906
# Merged NA19240
# Merged NA20129
# Merged NA21309
#   sample_id                             cenSatAnnotations_hap1  \
# 0     HG002  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   HG00438  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2     HG005                                                NaN
# 3   HG00621  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   HG00673  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                               cenSatAnnotations_hap2  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2                                                NaN
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                         additional_annotations_array
# 0  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2                                                 []
# 3  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...

# %%
list(censat_table_diploid["censat_diploid_bed"])[:5]
# Out:
# ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG002_dip_hprc_r1.cenSat.bed',
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00438_dip_hprc_r1.cenSat.bed',
#  nan,
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00621_dip_hprc_r1.cenSat.bed',
#  '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00673_dip_hprc_r1.cenSat.bed']

# %%
list(censat_table_diploid["additional_annotations_array"])[:5]
# Out:
# [['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG002_dip_hprc_r1.cenSat.rDNA.bed'],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00438_dip_hprc_r1.cenSat.rDNA.bed'],
#  [],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00621_dip_hprc_r1.cenSat.rDNA.bed'],
#  ['/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00673_dip_hprc_r1.cenSat.rDNA.bed']]

# %%
# !ls /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/
# Out:
# HG002_dip_hprc_r1.cenSat.bed	     HG02109_dip_hprc_r1.cenSat.bed
# HG002_dip_hprc_r1.cenSat.rDNA.bed    HG02109_dip_hprc_r1.cenSat.rDNA.bed
# HG00438_dip_hprc_r1.cenSat.bed	     HG02148_dip_hprc_r1.cenSat.bed
# HG00438_dip_hprc_r1.cenSat.rDNA.bed  HG02148_dip_hprc_r1.cenSat.rDNA.bed
# HG00621_dip_hprc_r1.cenSat.bed	     HG02257_dip_hprc_r1.cenSat.bed
# HG00621_dip_hprc_r1.cenSat.rDNA.bed  HG02257_dip_hprc_r1.cenSat.rDNA.bed
# HG00673_dip_hprc_r1.cenSat.bed	     HG02486_dip_hprc_r1.cenSat.bed
# HG00673_dip_hprc_r1.cenSat.rDNA.bed  HG02486_dip_hprc_r1.cenSat.rDNA.bed
# HG00735_dip_hprc_r1.cenSat.bed	     HG02559_dip_hprc_r1.cenSat.bed
# HG00735_dip_hprc_r1.cenSat.rDNA.bed  HG02559_dip_hprc_r1.cenSat.rDNA.bed
# HG00741_dip_hprc_r1.cenSat.bed	     HG02622_dip_hprc_r1.cenSat.bed
# HG00741_dip_hprc_r1.cenSat.rDNA.bed  HG02622_dip_hprc_r1.cenSat.rDNA.bed
# HG01071_dip_hprc_r1.cenSat.bed	     HG02630_dip_hprc_r1.cenSat.bed
# HG01071_dip_hprc_r1.cenSat.rDNA.bed  HG02630_dip_hprc_r1.cenSat.rDNA.bed
# HG01106_dip_hprc_r1.cenSat.bed	     HG02717_dip_hprc_r1.cenSat.bed
# HG01106_dip_hprc_r1.cenSat.rDNA.bed  HG02717_dip_hprc_r1.cenSat.rDNA.bed
# HG01109_dip_hprc_r1.cenSat.bed	     HG02723_dip_hprc_r1.cenSat.bed
# HG01109_dip_hprc_r1.cenSat.rDNA.bed  HG02723_dip_hprc_r1.cenSat.rDNA.bed
# HG01123_dip_hprc_r1.cenSat.bed	     HG02886_dip_hprc_r1.cenSat.bed
# HG01123_dip_hprc_r1.cenSat.rDNA.bed  HG02886_dip_hprc_r1.cenSat.rDNA.bed
# HG01175_dip_hprc_r1.cenSat.bed	     HG03098_dip_hprc_r1.cenSat.bed
# HG01175_dip_hprc_r1.cenSat.rDNA.bed  HG03098_dip_hprc_r1.cenSat.rDNA.bed
# HG01243_dip_hprc_r1.cenSat.bed	     HG03453_dip_hprc_r1.cenSat.bed
# HG01243_dip_hprc_r1.cenSat.rDNA.bed  HG03453_dip_hprc_r1.cenSat.rDNA.bed
# HG01258_dip_hprc_r1.cenSat.bed	     HG03486_dip_hprc_r1.cenSat.bed
# HG01258_dip_hprc_r1.cenSat.rDNA.bed  HG03486_dip_hprc_r1.cenSat.rDNA.bed
# HG01358_dip_hprc_r1.cenSat.bed	     HG03492_dip_hprc_r1.cenSat.bed
# HG01358_dip_hprc_r1.cenSat.rDNA.bed  HG03492_dip_hprc_r1.cenSat.rDNA.bed
# HG01361_dip_hprc_r1.cenSat.bed	     HG03516_dip_hprc_r1.cenSat.bed
# HG01361_dip_hprc_r1.cenSat.rDNA.bed  HG03516_dip_hprc_r1.cenSat.rDNA.bed
# HG01891_dip_hprc_r1.cenSat.bed	     HG03540_dip_hprc_r1.cenSat.bed
# HG01891_dip_hprc_r1.cenSat.rDNA.bed  HG03540_dip_hprc_r1.cenSat.rDNA.bed
# HG01928_dip_hprc_r1.cenSat.bed	     HG03579_dip_hprc_r1.cenSat.bed
# HG01928_dip_hprc_r1.cenSat.rDNA.bed  HG03579_dip_hprc_r1.cenSat.rDNA.bed
# HG01952_dip_hprc_r1.cenSat.bed	     NA18906_dip_hprc_r1.cenSat.bed
# HG01952_dip_hprc_r1.cenSat.rDNA.bed  NA18906_dip_hprc_r1.cenSat.rDNA.bed
# HG01978_dip_hprc_r1.cenSat.bed	     NA19240_dip_hprc_r1.cenSat.bed
# HG01978_dip_hprc_r1.cenSat.rDNA.bed  NA19240_dip_hprc_r1.cenSat.rDNA.bed
# HG02055_dip_hprc_r1.cenSat.bed	     NA20129_dip_hprc_r1.cenSat.bed
# HG02055_dip_hprc_r1.cenSat.rDNA.bed  NA20129_dip_hprc_r1.cenSat.rDNA.bed
# HG02080_dip_hprc_r1.cenSat.bed	     NA21309_dip_hprc_r1.cenSat.bed
# HG02080_dip_hprc_r1.cenSat.rDNA.bed  NA21309_dip_hprc_r1.cenSat.rDNA.bed

# %%
# !cat /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/hmm_flagger/diploid_censat_beds/HG00438_dip_hprc_r1.cenSat.rDNA.bed | head
# Out:
# HG00438#1#JAHBCB010000005.1	6212234	6215290
# HG00438#1#JAHBCB010000019.1	99653277	99656318
# HG00438#1#JAHBCB010000030.1	16813185	16816264
# HG00438#1#JAHBCB010000054.1	7155	14648
# HG00438#1#JAHBCB010000059.1	1217795	1632820
# HG00438#1#JAHBCB010000073.1	630955	634013
# HG00438#1#JAHBCB010000073.1	826391	829429
# HG00438#1#JAHBCB010000073.1	6142438	6192108
# HG00438#1#JAHBCB010000074.1	33659092	33662154
# HG00438#1#JAHBCB010000074.1	34624396	34627446

# %%
# read assembly hprc-r1 table
assembly_table = pd.read_csv("Year1_assemblies_v2_genbank.index",sep="\t")
assembly_table = assembly_table.rename(columns={"sample": "sample_id"})
assembly_table
# Out:
#                      sample_id  \
# 0                      HG00438
# 1                      HG00621
# 2                      HG00673
# 3                      HG00735
# 4                      HG00741
# 5                      HG01071
# 6                      HG01106
# 7                      HG01123
# 8                      HG01175
# 9                      HG01258
# 10                     HG01358
# 11                     HG01361
# 12                     HG01891
# 13                     HG01928
# 14                     HG01952
# 15                     HG01978
# 16                     HG02148
# 17                     HG02257
# 18                     HG02486
# 19                     HG02559
# 20                     HG02572
# 21                     HG02622
# 22                     HG02630
# 23                     HG02717
# 24                     HG02886
# 25                     HG03453
# 26                     HG03516
# 27                     HG03540
# 28                     HG03579
# 29                       HG002
# 30                       HG005
# 31                     HG00733
# 32                     HG01109
# 33                     HG01243
# 34                     HG02055
# 35                     HG02080
# 36                     HG02109
# 37                     HG02145
# 38                     HG02723
# 39                     HG02818
# 40                     HG03098
# 41                     HG03486
# 42                     HG03492
# 43                     NA18906
# 44                     NA19240
# 45                     NA20129
# 46                     NA21309
# 47                  CHM13_v1.1
# 48  GRCh38_no_alt_analysis_set
#
#                                        hap1_aws_fasta  \
# 0   s3://human-pangenomics/working/HPRC/HG00438/as...
# 1   s3://human-pangenomics/working/HPRC/HG00621/as...
# 2   s3://human-pangenomics/working/HPRC/HG00673/as...
# 3   s3://human-pangenomics/working/HPRC/HG00735/as...
# 4   s3://human-pangenomics/working/HPRC/HG00741/as...
# 5   s3://human-pangenomics/working/HPRC/HG01071/as...
# 6   s3://human-pangenomics/working/HPRC/HG01106/as...
# 7   s3://human-pangenomics/working/HPRC/HG01123/as...
# 8   s3://human-pangenomics/working/HPRC/HG01175/as...
# 9   s3://human-pangenomics/working/HPRC/HG01258/as...
# 10  s3://human-pangenomics/working/HPRC/HG01358/as...
# 11  s3://human-pangenomics/working/HPRC/HG01361/as...
# 12  s3://human-pangenomics/working/HPRC/HG01891/as...
# 13  s3://human-pangenomics/working/HPRC/HG01928/as...
# 14  s3://human-pangenomics/working/HPRC/HG01952/as...
# 15  s3://human-pangenomics/working/HPRC/HG01978/as...
# 16  s3://human-pangenomics/working/HPRC/HG02148/as...
# 17  s3://human-pangenomics/working/HPRC/HG02257/as...
# 18  s3://human-pangenomics/working/HPRC/HG02486/as...
# 19  s3://human-pangenomics/working/HPRC/HG02559/as...
# 20  s3://human-pangenomics/working/HPRC/HG02572/as...
# 21  s3://human-pangenomics/working/HPRC/HG02622/as...
# 22  s3://human-pangenomics/working/HPRC/HG02630/as...
# 23  s3://human-pangenomics/working/HPRC/HG02717/as...
# 24  s3://human-pangenomics/working/HPRC/HG02886/as...
# 25  s3://human-pangenomics/working/HPRC/HG03453/as...
# 26  s3://human-pangenomics/working/HPRC/HG03516/as...
# 27  s3://human-pangenomics/working/HPRC/HG03540/as...
# 28  s3://human-pangenomics/working/HPRC/HG03579/as...
# 29  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 30  s3://human-pangenomics/working/HPRC_PLUS/HG005...
# 31  s3://human-pangenomics/working/HPRC_PLUS/HG007...
# 32  s3://human-pangenomics/working/HPRC_PLUS/HG011...
# 33  s3://human-pangenomics/working/HPRC_PLUS/HG012...
# 34  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 35  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 36  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 37  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 38  s3://human-pangenomics/working/HPRC_PLUS/HG027...
# 39  s3://human-pangenomics/working/HPRC_PLUS/HG028...
# 40  s3://human-pangenomics/working/HPRC_PLUS/HG030...
# 41  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 42  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 43  s3://human-pangenomics/working/HPRC_PLUS/NA189...
# 44  s3://human-pangenomics/working/HPRC_PLUS/NA192...
# 45  s3://human-pangenomics/working/HPRC_PLUS/NA201...
# 46  s3://human-pangenomics/working/HPRC_PLUS/NA213...
# 47  s3://human-pangenomics/working/HPRC_PLUS/CHM13...
# 48  s3://human-pangenomics/working/HPRC_PLUS/GRCh3...
#
#                                        hap2_aws_fasta  \
# 0   s3://human-pangenomics/working/HPRC/HG00438/as...
# 1   s3://human-pangenomics/working/HPRC/HG00621/as...
# 2   s3://human-pangenomics/working/HPRC/HG00673/as...
# 3   s3://human-pangenomics/working/HPRC/HG00735/as...
# 4   s3://human-pangenomics/working/HPRC/HG00741/as...
# 5   s3://human-pangenomics/working/HPRC/HG01071/as...
# 6   s3://human-pangenomics/working/HPRC/HG01106/as...
# 7   s3://human-pangenomics/working/HPRC/HG01123/as...
# 8   s3://human-pangenomics/working/HPRC/HG01175/as...
# 9   s3://human-pangenomics/working/HPRC/HG01258/as...
# 10  s3://human-pangenomics/working/HPRC/HG01358/as...
# 11  s3://human-pangenomics/working/HPRC/HG01361/as...
# 12  s3://human-pangenomics/working/HPRC/HG01891/as...
# 13  s3://human-pangenomics/working/HPRC/HG01928/as...
# 14  s3://human-pangenomics/working/HPRC/HG01952/as...
# 15  s3://human-pangenomics/working/HPRC/HG01978/as...
# 16  s3://human-pangenomics/working/HPRC/HG02148/as...
# 17  s3://human-pangenomics/working/HPRC/HG02257/as...
# 18  s3://human-pangenomics/working/HPRC/HG02486/as...
# 19  s3://human-pangenomics/working/HPRC/HG02559/as...
# 20  s3://human-pangenomics/working/HPRC/HG02572/as...
# 21  s3://human-pangenomics/working/HPRC/HG02622/as...
# 22  s3://human-pangenomics/working/HPRC/HG02630/as...
# 23  s3://human-pangenomics/working/HPRC/HG02717/as...
# 24  s3://human-pangenomics/working/HPRC/HG02886/as...
# 25  s3://human-pangenomics/working/HPRC/HG03453/as...
# 26  s3://human-pangenomics/working/HPRC/HG03516/as...
# 27  s3://human-pangenomics/working/HPRC/HG03540/as...
# 28  s3://human-pangenomics/working/HPRC/HG03579/as...
# 29  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 30  s3://human-pangenomics/working/HPRC_PLUS/HG005...
# 31  s3://human-pangenomics/working/HPRC_PLUS/HG007...
# 32  s3://human-pangenomics/working/HPRC_PLUS/HG011...
# 33  s3://human-pangenomics/working/HPRC_PLUS/HG012...
# 34  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 35  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 36  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 37  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 38  s3://human-pangenomics/working/HPRC_PLUS/HG027...
# 39  s3://human-pangenomics/working/HPRC_PLUS/HG028...
# 40  s3://human-pangenomics/working/HPRC_PLUS/HG030...
# 41  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 42  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 43  s3://human-pangenomics/working/HPRC_PLUS/NA189...
# 44  s3://human-pangenomics/working/HPRC_PLUS/NA192...
# 45  s3://human-pangenomics/working/HPRC_PLUS/NA201...
# 46  s3://human-pangenomics/working/HPRC_PLUS/NA213...
# 47                                                NaN
# 48                                                NaN
#
#                                        hap1_gcp_fasta  \
# 0   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 1   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 2   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 3   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 4   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 5   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 6   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 7   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 8   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 9   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 10  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 11  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 12  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 13  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 14  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 15  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 16  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 17  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 18  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 19  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 20  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 21  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 22  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 23  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 24  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 25  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 26  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 27  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 28  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 29  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 30  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 31  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 32  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 33  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 34  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 35  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 36  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 37  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 38  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 39  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 40  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 41  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 42  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 43  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 44  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 45  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 46  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 47  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 48  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
#
#                                        hap2_gcp_fasta  \
# 0   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 1   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 2   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 3   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 4   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 5   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 6   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 7   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 8   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 9   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 10  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 11  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 12  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 13  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 14  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 15  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 16  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 17  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 18  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 19  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 20  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 21  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 22  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 23  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 24  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 25  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 26  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 27  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 28  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 29  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 30  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 31  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 32  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 33  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 34  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 35  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 36  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 37  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 38  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 39  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 40  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 41  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 42  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 43  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 44  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 45  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 46  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 47                                                NaN
# 48                                                NaN
#
#                                     hap1_fasta_sha256  \
# 0   a5840157a6995c5fbc08698e52b614fbdf6f57a7245db9...
# 1   bb7d30232f423cabf8d2ebf7443d15aa42bdbfe826424e...
# 2   9650cdb2f090bb94dcb81d0cf9be27e2565de0489dc0d7...
# 3   117cd1556d9b9ea796e29b30db2cb4c6e77e90c9f9b1c0...
# 4   e6121ba9df50914fb0459afd50a9527f7260f1fae8f9ec...
# 5   d5f5829d658e123a265459d7afa804537150febea6432d...
# 6   7c46227b41d8385d07e9d024515b9cc1f09df7fc1e1fae...
# 7   f514554f1998854e91c528da29b18fc730932805853ede...
# 8   0e7aab966b1c54f094d3d6a91db741ac230840fe87a987...
# 9   e7697b1b7c2a4188f76d827611caa3a1b55b499d7c8bfa...
# 10  b4ebe059741876e76ea43633a499e6dafb06d8876cb5f4...
# 11  01c848260b6414e260a31eb637a7a0f251d123d5781882...
# 12  9d9aa8e29e2fd24fd890aa1308dc13fb54acd8bec91d6a...
# 13  f394a6900c6ba13bb2b9e91ac3d2dcc4863fa5d1fc5a6c...
# 14  c6f0b80ab52d7c58c00fb4d59b46bb18569c00b3bf887a...
# 15  9f74231668c0295afc07ced515b987430c042ca5bb04be...
# 16  931d6a40b3240f27f6fdcff40820446939e9e4b369ae29...
# 17  75a5efb57e8cb460d4c353807b0e377ea4cbf8ab0b6027...
# 18  10116f1231a15778e8f4b06ae6fba96d377b075ca31576...
# 19  c6666f821d9ecda2b68079f45697b076f2f9f27f9adfbd...
# 20  54f2b02e3b367b534569eb83b0893109d63f6698510a76...
# 21  b7168c3b978aaefba812b9ffba93239eba00c070e59df9...
# 22  2f530c1a83ff1aa5e42711bf59af65bb1ef58038adce31...
# 23  6d7754c4c61594d5ea3aecf9cff9e916d17db4ec727634...
# 24  52f153046228ef4a5638f069ed8f1fcbb9f1a147581e8c...
# 25  216654a6de2dcb85fe1c658c26106efc04b9980ac2fd76...
# 26  4af17c33a89bf46570b4baf731891183377f50adfe47ba...
# 27  f54577e4ad56113fe88c20d0cf2b15270dee89a6be61b1...
# 28  4017846771e288f873e53783dfb28b29435f71f4afc82e...
# 29  ec46feb51b343f030aae3e7c4781463a36f059a031f4aa...
# 30  399e1bb4bf40f6b70152acd6f4cc8502fd50d0edef774d...
# 31  47f20b76eab03a22a1351e0e9efbd0ba43814911f9f17c...
# 32  86486001fe72e08e3006a984037b6b231bc38288f58dd9...
# 33  027f37f22639891d94363b810eb3e07614b9a40672c009...
# 34  82c22f2e036f932ee9250b4ede482e60862bbacf191c16...
# 35  d801ec8ddf2522f71e013a7d04de9822936535a0e3975c...
# 36  dae2a7f162d9fef43f0f45178473d702eeec5f6e279acc...
# 37  a3c7fb913aada514cb3f65076266ce6c7972034f7ab21c...
# 38  ea86c3cb0e20f69e8f8afbe3608889b57956652883ecae...
# 39  dd994add4f69cca7ab224e4432687a7ab86db0521a8a72...
# 40  4d306c8e8a3f8e0eb1722badb09886d0dac401747c3406...
# 41  666e46977bb17f9311cf0ec147b884407b81711b68f8d4...
# 42  ec35b2f88d4eee51ceea12cda6ccea9e41ed83576ba3c0...
# 43  f25083f23e1f6c6c68b5ceeaddbae02d1f4d0ae6233333...
# 44  237410a658b58c03286ed6c9915c2f9e86fac6126240cb...
# 45  f65fc08dfd2576b62bab9578e03b5a9c06df32cb9ccba0...
# 46  4106352f6a92ac6c6951435f94c5ca26b58e31d48fa0c3...
# 47  55df6143b2458c9fc2a987bd297a330c1bb28116ed8052...
# 48  fb4243ebb014caf27111f24dd62b7ce42160f28581da6f...
#
#                                     hap2_fasta_sha256
# 0   ca307e58dfba48336dd3a05d0ea59b87e3383a5a8c839e...
# 1   1180dda57e968c6f9cf1902981038141f0905b395d44ea...
# 2   0eef54ceca964b5a65c046529e5e433f0cb1a19d6d8a19...
# 3   fdde1ce9c6f27c8d963eef5228ca657c65e89f95ece894...
# 4   a756fc30621e5e887ce5bee0e3a76d4ab9093c846f90ac...
# 5   5e67e97c0275d46ad4b75b14365d1fd5000ed44cfc7597...
# 6   13416e10902dd12476dedeb637c4b5a23c8b4d6e5f6704...
# 7   7b2144e0c1a08d5fbe179f8668fada2242bead7cfd12d0...
# 8   4023f8a4eac5fd0705d54278b674a7b3ddadbaec391e8f...
# 9   97e8ece8b4a108be376025747d377f003270dadebcc84e...
# 10  3ab91edde9c57f2d0a9238b161122cdaeb48bb87030abe...
# 11  1c5a60c6bdb77177c701448da5040a1dfc47b9c57dbf53...
# 12  9c439c0e28fa9b9e2a515ea75adaef8e156460851aa91f...
# 13  58fc6831a094299d6913b7d24b495790e70195badddec4...
# 14  5b556ba7058119a135522443eac72f1a084772da2c4209...
# 15  94c18d5b4470a8c6baaa7f62b0683f19c0014b2153c427...
# 16  7cec12342242d476e1e31b5d456c8eea6ffce07b43a422...
# 17  febe94c80a4f319f7db03d87b344e387933dfa66609bda...
# 18  62e351be300c24daf8134d9d4a2fee302444dbfa45c3e0...
# 19  65152219bd5add93081b21b26719a83a63a0eef8cfa75b...
# 20  c790e80eafdf11790b349a09c43106aa7671c019955519...
# 21  fe3d091c2a223bee155e40d46328410425a58f4971dbd7...
# 22  b65d2f534ddbfedcac74c80932e25201b45dde2a2e9c65...
# 23  90118c064532b848c572fb9050708c8d53ccce687633ce...
# 24  d973517af237d330aa21c4493935aa553422333f4b341c...
# 25  90270031da8ec5bfddf339a3eb7b37c8a5326adf6ecb51...
# 26  2111e2c19f255d1d4fff49acddfd26d88ff250eafed707...
# 27  d34b271a2d0a152367a88bb1cc44984c960c76440d514a...
# 28  3c7235b26eb89845ab264c83f7e6f2f1103152d186ed1c...
# 29  9e0b7ae6b0727a8828cef61c7b216eabdb2f098fcd2940...
# 30  8a9b715d91685b7db161e878ab205fb7a149794ecf79b3...
# 31  c2963af8e63111ade4810bccfa059166db948f491551c2...
# 32  0aa368ac4d5dbe028f6fda70685193ea5ac80b7c890ff4...
# 33  8052aba721d0d48d65ecaae0abdd1fa4584a85cdde414e...
# 34  769b69075228a32ce5933ffa03fcdb89ed167376889793...
# 35  d48a5052a29556cca10b4d90c839bd22ec818882baa9a6...
# 36  1367b63eb84facbc32063513bf9dd8211065ce925c03e7...
# 37  bc9d3539c1cb2dbabdfb5df89710c53d2a7ce8246da877...
# 38  0d144481c6e3049466cad75179aa2c93382a864642d245...
# 39  d54ba5c3d724015704dcc360e96452cba167a37f8ecc99...
# 40  853d1f3f3359d6499f1fb7a9a9c77654cda675a19fb117...
# 41  3c99085badabfff138857d5a7f17750ca2faaf72d6be21...
# 42  65e038a0afc14b2d9fbc5c5cf1d99f77de324821a4b2d0...
# 43  1f5d8d95193fa1869b1b3c7142d4c7c4037f92002100c7...
# 44  dc5e5c02889f12b1e435f8d8ba2d8615202e3ec049c5af...
# 45  55f0bdbf8cee4fcabd1cb17d87171ec00b991d09f4ad29...
# 46  215104789395396865d5d2e3e668991f4439a274a60cdf...
# 47                                                NaN
# 48                                                NaN

# %%
# read ont and hifi reads table
hifi_reads_table = pd.read_csv('../../batch1/hmm_flagger/read_tables/hifi_reads_table.csv')
ont_reads_table = pd.read_csv('../../batch1/hmm_flagger/read_tables/ont_reads_table.csv')

# %%
# merge with censat table
ont_data_table = pd.merge(censat_table_diploid, ont_reads_table, on='sample_id',  how='inner')
hifi_data_table = pd.merge(censat_table_diploid, hifi_reads_table, on='sample_id',  how='inner')

# merge with assembly table
ont_data_table = pd.merge(assembly_table, ont_data_table, on='sample_id',  how='inner')
hifi_data_table = pd.merge(assembly_table, hifi_data_table, on='sample_id',  how='inner')

# %%
print(f"Number of rows for final HiFi table: {len(hifi_data_table)}")
hifi_data_table
# Out:
# Number of rows for final HiFi table: 44
#    sample_id                                     hap1_aws_fasta  \
# 0    HG00438  s3://human-pangenomics/working/HPRC/HG00438/as...
# 1    HG00621  s3://human-pangenomics/working/HPRC/HG00621/as...
# 2    HG00673  s3://human-pangenomics/working/HPRC/HG00673/as...
# 3    HG00735  s3://human-pangenomics/working/HPRC/HG00735/as...
# 4    HG00741  s3://human-pangenomics/working/HPRC/HG00741/as...
# 5    HG01071  s3://human-pangenomics/working/HPRC/HG01071/as...
# 6    HG01106  s3://human-pangenomics/working/HPRC/HG01106/as...
# 7    HG01123  s3://human-pangenomics/working/HPRC/HG01123/as...
# 8    HG01175  s3://human-pangenomics/working/HPRC/HG01175/as...
# 9    HG01258  s3://human-pangenomics/working/HPRC/HG01258/as...
# 10   HG01358  s3://human-pangenomics/working/HPRC/HG01358/as...
# 11   HG01361  s3://human-pangenomics/working/HPRC/HG01361/as...
# 12   HG01891  s3://human-pangenomics/working/HPRC/HG01891/as...
# 13   HG01928  s3://human-pangenomics/working/HPRC/HG01928/as...
# 14   HG01952  s3://human-pangenomics/working/HPRC/HG01952/as...
# 15   HG01978  s3://human-pangenomics/working/HPRC/HG01978/as...
# 16   HG02148  s3://human-pangenomics/working/HPRC/HG02148/as...
# 17   HG02257  s3://human-pangenomics/working/HPRC/HG02257/as...
# 18   HG02486  s3://human-pangenomics/working/HPRC/HG02486/as...
# 19   HG02559  s3://human-pangenomics/working/HPRC/HG02559/as...
# 20   HG02572  s3://human-pangenomics/working/HPRC/HG02572/as...
# 21   HG02622  s3://human-pangenomics/working/HPRC/HG02622/as...
# 22   HG02630  s3://human-pangenomics/working/HPRC/HG02630/as...
# 23   HG02717  s3://human-pangenomics/working/HPRC/HG02717/as...
# 24   HG02886  s3://human-pangenomics/working/HPRC/HG02886/as...
# 25   HG03453  s3://human-pangenomics/working/HPRC/HG03453/as...
# 26   HG03516  s3://human-pangenomics/working/HPRC/HG03516/as...
# 27   HG03540  s3://human-pangenomics/working/HPRC/HG03540/as...
# 28   HG03579  s3://human-pangenomics/working/HPRC/HG03579/as...
# 29   HG01109  s3://human-pangenomics/working/HPRC_PLUS/HG011...
# 30   HG01243  s3://human-pangenomics/working/HPRC_PLUS/HG012...
# 31   HG02055  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 32   HG02080  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 33   HG02109  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 34   HG02145  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 35   HG02723  s3://human-pangenomics/working/HPRC_PLUS/HG027...
# 36   HG02818  s3://human-pangenomics/working/HPRC_PLUS/HG028...
# 37   HG03098  s3://human-pangenomics/working/HPRC_PLUS/HG030...
# 38   HG03486  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 39   HG03492  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 40   NA18906  s3://human-pangenomics/working/HPRC_PLUS/NA189...
# 41   NA19240  s3://human-pangenomics/working/HPRC_PLUS/NA192...
# 42   NA20129  s3://human-pangenomics/working/HPRC_PLUS/NA201...
# 43   NA21309  s3://human-pangenomics/working/HPRC_PLUS/NA213...
#
#                                        hap2_aws_fasta  \
# 0   s3://human-pangenomics/working/HPRC/HG00438/as...
# 1   s3://human-pangenomics/working/HPRC/HG00621/as...
# 2   s3://human-pangenomics/working/HPRC/HG00673/as...
# 3   s3://human-pangenomics/working/HPRC/HG00735/as...
# 4   s3://human-pangenomics/working/HPRC/HG00741/as...
# 5   s3://human-pangenomics/working/HPRC/HG01071/as...
# 6   s3://human-pangenomics/working/HPRC/HG01106/as...
# 7   s3://human-pangenomics/working/HPRC/HG01123/as...
# 8   s3://human-pangenomics/working/HPRC/HG01175/as...
# 9   s3://human-pangenomics/working/HPRC/HG01258/as...
# 10  s3://human-pangenomics/working/HPRC/HG01358/as...
# 11  s3://human-pangenomics/working/HPRC/HG01361/as...
# 12  s3://human-pangenomics/working/HPRC/HG01891/as...
# 13  s3://human-pangenomics/working/HPRC/HG01928/as...
# 14  s3://human-pangenomics/working/HPRC/HG01952/as...
# 15  s3://human-pangenomics/working/HPRC/HG01978/as...
# 16  s3://human-pangenomics/working/HPRC/HG02148/as...
# 17  s3://human-pangenomics/working/HPRC/HG02257/as...
# 18  s3://human-pangenomics/working/HPRC/HG02486/as...
# 19  s3://human-pangenomics/working/HPRC/HG02559/as...
# 20  s3://human-pangenomics/working/HPRC/HG02572/as...
# 21  s3://human-pangenomics/working/HPRC/HG02622/as...
# 22  s3://human-pangenomics/working/HPRC/HG02630/as...
# 23  s3://human-pangenomics/working/HPRC/HG02717/as...
# 24  s3://human-pangenomics/working/HPRC/HG02886/as...
# 25  s3://human-pangenomics/working/HPRC/HG03453/as...
# 26  s3://human-pangenomics/working/HPRC/HG03516/as...
# 27  s3://human-pangenomics/working/HPRC/HG03540/as...
# 28  s3://human-pangenomics/working/HPRC/HG03579/as...
# 29  s3://human-pangenomics/working/HPRC_PLUS/HG011...
# 30  s3://human-pangenomics/working/HPRC_PLUS/HG012...
# 31  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 32  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 33  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 34  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 35  s3://human-pangenomics/working/HPRC_PLUS/HG027...
# 36  s3://human-pangenomics/working/HPRC_PLUS/HG028...
# 37  s3://human-pangenomics/working/HPRC_PLUS/HG030...
# 38  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 39  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 40  s3://human-pangenomics/working/HPRC_PLUS/NA189...
# 41  s3://human-pangenomics/working/HPRC_PLUS/NA192...
# 42  s3://human-pangenomics/working/HPRC_PLUS/NA201...
# 43  s3://human-pangenomics/working/HPRC_PLUS/NA213...
#
#                                        hap1_gcp_fasta  \
# 0   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 1   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 2   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 3   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 4   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 5   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 6   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 7   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 8   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 9   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 10  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 11  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 12  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 13  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 14  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 15  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 16  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 17  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 18  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 19  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 20  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 21  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 22  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 23  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 24  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 25  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 26  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 27  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 28  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 29  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 30  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 31  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 32  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 33  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 34  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 35  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 36  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 37  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 38  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 39  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 40  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 41  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 42  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 43  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
#
#                                        hap2_gcp_fasta  \
# 0   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 1   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 2   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 3   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 4   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 5   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 6   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 7   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 8   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 9   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 10  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 11  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 12  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 13  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 14  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 15  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 16  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 17  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 18  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 19  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 20  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 21  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 22  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 23  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 24  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 25  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 26  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 27  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 28  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 29  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 30  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 31  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 32  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 33  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 34  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 35  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 36  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 37  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 38  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 39  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 40  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 41  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 42  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 43  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
#
#                                     hap1_fasta_sha256  \
# 0   a5840157a6995c5fbc08698e52b614fbdf6f57a7245db9...
# 1   bb7d30232f423cabf8d2ebf7443d15aa42bdbfe826424e...
# 2   9650cdb2f090bb94dcb81d0cf9be27e2565de0489dc0d7...
# 3   117cd1556d9b9ea796e29b30db2cb4c6e77e90c9f9b1c0...
# 4   e6121ba9df50914fb0459afd50a9527f7260f1fae8f9ec...
# 5   d5f5829d658e123a265459d7afa804537150febea6432d...
# 6   7c46227b41d8385d07e9d024515b9cc1f09df7fc1e1fae...
# 7   f514554f1998854e91c528da29b18fc730932805853ede...
# 8   0e7aab966b1c54f094d3d6a91db741ac230840fe87a987...
# 9   e7697b1b7c2a4188f76d827611caa3a1b55b499d7c8bfa...
# 10  b4ebe059741876e76ea43633a499e6dafb06d8876cb5f4...
# 11  01c848260b6414e260a31eb637a7a0f251d123d5781882...
# 12  9d9aa8e29e2fd24fd890aa1308dc13fb54acd8bec91d6a...
# 13  f394a6900c6ba13bb2b9e91ac3d2dcc4863fa5d1fc5a6c...
# 14  c6f0b80ab52d7c58c00fb4d59b46bb18569c00b3bf887a...
# 15  9f74231668c0295afc07ced515b987430c042ca5bb04be...
# 16  931d6a40b3240f27f6fdcff40820446939e9e4b369ae29...
# 17  75a5efb57e8cb460d4c353807b0e377ea4cbf8ab0b6027...
# 18  10116f1231a15778e8f4b06ae6fba96d377b075ca31576...
# 19  c6666f821d9ecda2b68079f45697b076f2f9f27f9adfbd...
# 20  54f2b02e3b367b534569eb83b0893109d63f6698510a76...
# 21  b7168c3b978aaefba812b9ffba93239eba00c070e59df9...
# 22  2f530c1a83ff1aa5e42711bf59af65bb1ef58038adce31...
# 23  6d7754c4c61594d5ea3aecf9cff9e916d17db4ec727634...
# 24  52f153046228ef4a5638f069ed8f1fcbb9f1a147581e8c...
# 25  216654a6de2dcb85fe1c658c26106efc04b9980ac2fd76...
# 26  4af17c33a89bf46570b4baf731891183377f50adfe47ba...
# 27  f54577e4ad56113fe88c20d0cf2b15270dee89a6be61b1...
# 28  4017846771e288f873e53783dfb28b29435f71f4afc82e...
# 29  86486001fe72e08e3006a984037b6b231bc38288f58dd9...
# 30  027f37f22639891d94363b810eb3e07614b9a40672c009...
# 31  82c22f2e036f932ee9250b4ede482e60862bbacf191c16...
# 32  d801ec8ddf2522f71e013a7d04de9822936535a0e3975c...
# 33  dae2a7f162d9fef43f0f45178473d702eeec5f6e279acc...
# 34  a3c7fb913aada514cb3f65076266ce6c7972034f7ab21c...
# 35  ea86c3cb0e20f69e8f8afbe3608889b57956652883ecae...
# 36  dd994add4f69cca7ab224e4432687a7ab86db0521a8a72...
# 37  4d306c8e8a3f8e0eb1722badb09886d0dac401747c3406...
# 38  666e46977bb17f9311cf0ec147b884407b81711b68f8d4...
# 39  ec35b2f88d4eee51ceea12cda6ccea9e41ed83576ba3c0...
# 40  f25083f23e1f6c6c68b5ceeaddbae02d1f4d0ae6233333...
# 41  237410a658b58c03286ed6c9915c2f9e86fac6126240cb...
# 42  f65fc08dfd2576b62bab9578e03b5a9c06df32cb9ccba0...
# 43  4106352f6a92ac6c6951435f94c5ca26b58e31d48fa0c3...
#
#                                     hap2_fasta_sha256  \
# 0   ca307e58dfba48336dd3a05d0ea59b87e3383a5a8c839e...
# 1   1180dda57e968c6f9cf1902981038141f0905b395d44ea...
# 2   0eef54ceca964b5a65c046529e5e433f0cb1a19d6d8a19...
# 3   fdde1ce9c6f27c8d963eef5228ca657c65e89f95ece894...
# 4   a756fc30621e5e887ce5bee0e3a76d4ab9093c846f90ac...
# 5   5e67e97c0275d46ad4b75b14365d1fd5000ed44cfc7597...
# 6   13416e10902dd12476dedeb637c4b5a23c8b4d6e5f6704...
# 7   7b2144e0c1a08d5fbe179f8668fada2242bead7cfd12d0...
# 8   4023f8a4eac5fd0705d54278b674a7b3ddadbaec391e8f...
# 9   97e8ece8b4a108be376025747d377f003270dadebcc84e...
# 10  3ab91edde9c57f2d0a9238b161122cdaeb48bb87030abe...
# 11  1c5a60c6bdb77177c701448da5040a1dfc47b9c57dbf53...
# 12  9c439c0e28fa9b9e2a515ea75adaef8e156460851aa91f...
# 13  58fc6831a094299d6913b7d24b495790e70195badddec4...
# 14  5b556ba7058119a135522443eac72f1a084772da2c4209...
# 15  94c18d5b4470a8c6baaa7f62b0683f19c0014b2153c427...
# 16  7cec12342242d476e1e31b5d456c8eea6ffce07b43a422...
# 17  febe94c80a4f319f7db03d87b344e387933dfa66609bda...
# 18  62e351be300c24daf8134d9d4a2fee302444dbfa45c3e0...
# 19  65152219bd5add93081b21b26719a83a63a0eef8cfa75b...
# 20  c790e80eafdf11790b349a09c43106aa7671c019955519...
# 21  fe3d091c2a223bee155e40d46328410425a58f4971dbd7...
# 22  b65d2f534ddbfedcac74c80932e25201b45dde2a2e9c65...
# 23  90118c064532b848c572fb9050708c8d53ccce687633ce...
# 24  d973517af237d330aa21c4493935aa553422333f4b341c...
# 25  90270031da8ec5bfddf339a3eb7b37c8a5326adf6ecb51...
# 26  2111e2c19f255d1d4fff49acddfd26d88ff250eafed707...
# 27  d34b271a2d0a152367a88bb1cc44984c960c76440d514a...
# 28  3c7235b26eb89845ab264c83f7e6f2f1103152d186ed1c...
# 29  0aa368ac4d5dbe028f6fda70685193ea5ac80b7c890ff4...
# 30  8052aba721d0d48d65ecaae0abdd1fa4584a85cdde414e...
# 31  769b69075228a32ce5933ffa03fcdb89ed167376889793...
# 32  d48a5052a29556cca10b4d90c839bd22ec818882baa9a6...
# 33  1367b63eb84facbc32063513bf9dd8211065ce925c03e7...
# 34  bc9d3539c1cb2dbabdfb5df89710c53d2a7ce8246da877...
# 35  0d144481c6e3049466cad75179aa2c93382a864642d245...
# 36  d54ba5c3d724015704dcc360e96452cba167a37f8ecc99...
# 37  853d1f3f3359d6499f1fb7a9a9c77654cda675a19fb117...
# 38  3c99085badabfff138857d5a7f17750ca2faaf72d6be21...
# 39  65e038a0afc14b2d9fbc5c5cf1d99f77de324821a4b2d0...
# 40  1f5d8d95193fa1869b1b3c7142d4c7c4037f92002100c7...
# 41  dc5e5c02889f12b1e435f8d8ba2d8615202e3ec049c5af...
# 42  55f0bdbf8cee4fcabd1cb17d87171ec00b991d09f4ad29...
# 43  215104789395396865d5d2e3e668991f4439a274a60cdf...
#
#                                cenSatAnnotations_hap1  \
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 19  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 20                                                NaN
# 21  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 22  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 23  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 24  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 25  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 26  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 27  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 28  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 29  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 30  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 31  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 32  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 33  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 34                                                NaN
# 35  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 36  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 37  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 38  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 39  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 40  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 41  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 42  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 43  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                cenSatAnnotations_hap2  \
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 19  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 20                                                NaN
# 21  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 22  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 23  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 24  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 25  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 26  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 27  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 28  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 29  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 30  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 31  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 32  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 33  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 34  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 35  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 36                                                NaN
# 37  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 38  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 39  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 40  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 41  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 42  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 43  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                    censat_diploid_bed  \
# 0   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 19  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 20                                                NaN
# 21  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 22  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 23  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 24  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 25  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 26  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 27  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 28  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 29  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 30  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 31  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 32  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 33  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 34                                                NaN
# 35  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 36                                                NaN
# 37  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 38  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 39  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 40  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 41  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 42  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 43  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                          additional_annotations_array  \
# 0   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 1   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 2   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 3   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 4   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 5   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 6   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 7   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 8   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 9   [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 10  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 11  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 12  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 13  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 14  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 15  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 16  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 17  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 18  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 19  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 20                                                 []
# 21  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 22  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 23  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 24  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 25  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 26  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 27  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 28  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 29  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 30  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 31  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 32  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 33  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 34                                                 []
# 35  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 36                                                 []
# 37  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 38  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 39  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 40  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 41  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 42  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
# 43  [/private/groups/hprc/qc_hmm_flagger/hprc_inte...
#
#                                            read_files  number_of_read_files  \
# 0   ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 1   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 2   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 3   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 4   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 5   ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 6   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 7   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 8   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 9   ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 10  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 11  ['s3://human-pangenomics/submissions/3A25CF8A-...                     7
# 12  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 13  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 14  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 15  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 16  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 17  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 18  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 19  ['s3://human-pangenomics/submissions/3A25CF8A-...                     5
# 20  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 21  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 22  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 23  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 24  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 25  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 26  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 27  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 28  ['s3://human-pangenomics/submissions/3A25CF8A-...                     6
# 29  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 30  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 31  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 32  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 33  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 34  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 35  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 36  ['s3://human-pangenomics/submissions/3A25CF8A-...                     7
# 37  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 38  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 39  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 40  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
# 41  ['s3://human-pangenomics/submissions/3A25CF8A-...                     3
# 42  ['s3://human-pangenomics/submissions/3A25CF8A-...                     5
# 43  ['s3://human-pangenomics/submissions/3A25CF8A-...                     4
#
#     total_coverage                                          coverage  \
# 0            77.69        [13.81, 11.36, 12.69, 13.34, 14.44, 12.05]
# 1            47.91                      [12.56, 11.73, 11.66, 11.96]
# 2            48.60                      [11.26, 12.62, 13.05, 11.67]
# 3            52.77                      [14.19, 13.15, 13.45, 11.98]
# 4            47.85                      [12.21, 11.52, 12.37, 11.75]
# 5            74.09        [11.63, 10.41, 10.92, 10.97, 17.15, 13.01]
# 6            56.29                      [14.76, 13.11, 14.04, 14.38]
# 7            45.64                        [13.0, 10.57, 9.53, 12.54]
# 8            45.91                      [11.48, 12.92, 10.59, 10.92]
# 9            42.84                      [10.12, 11.49, 10.04, 11.19]
# 10           45.10                      [11.44, 12.55, 10.96, 10.15]
# 11           82.08  [12.57, 12.65, 10.89, 10.91, 2.66, 15.76, 16.64]
# 12           43.59                       [10.29, 11.4, 11.36, 10.54]
# 13           70.54         [10.85, 10.95, 9.89, 10.69, 13.85, 14.31]
# 14           49.61                      [12.62, 12.62, 12.51, 11.86]
# 15           78.70         [12.25, 12.17, 12.98, 12.62, 16.2, 12.48]
# 16           47.00                       [14.68, 11.07, 9.99, 11.26]
# 17           42.89                       [7.99, 12.22, 11.55, 11.13]
# 18           47.34            [7.08, 10.14, 10.38, 9.08, 10.26, 0.4]
# 19           51.80                [2.73, 13.01, 12.37, 10.96, 12.73]
# 20           36.84                         [9.85, 10.28, 8.06, 8.65]
# 21           57.05                        [14.4, 14.2, 14.37, 14.08]
# 22           58.00                      [15.04, 14.48, 14.37, 14.11]
# 23           81.55          [14.04, 13.51, 13.66, 13.4, 15.6, 11.34]
# 24           54.51                      [13.37, 14.36, 13.27, 13.51]
# 25           59.97                      [15.13, 15.53, 14.85, 14.46]
# 26           69.90          [13.07, 12.82, 8.45, 10.1, 15.21, 10.25]
# 27           58.53                      [15.01, 14.59, 14.66, 14.27]
# 28           84.47        [12.94, 14.54, 14.68, 14.19, 16.84, 11.28]
# 29           41.38                             [15.59, 13.55, 12.24]
# 30           42.18                              [15.29, 13.1, 13.79]
# 31           48.55                       [11.19, 12.6, 11.71, 13.05]
# 32           40.46                              [12.09, 15.2, 13.17]
# 33           35.37                             [12.06, 10.59, 12.72]
# 34           43.28                          [11.21, 8.8, 9.77, 13.5]
# 35           52.77                      [13.01, 12.87, 13.77, 13.12]
# 36           44.11        [2.57, 2.89, 2.83, 10.0, 9.75, 10.27, 5.8]
# 37           42.06                              [15.25, 14.31, 12.5]
# 38           47.80                      [12.01, 12.22, 12.33, 11.24]
# 39           40.11                              [12.4, 13.65, 14.06]
# 40           51.45                      [12.68, 13.23, 12.52, 13.02]
# 41           35.24                               [12.44, 11.3, 11.5]
# 42           42.33                 [10.52, 11.08, 11.16, 3.26, 6.31]
# 43           45.34                       [11.84, 13.56, 13.32, 6.62]
#
#    mapper_preset  kmer_size  number_of_cores_per_task  \
# 0        lr:hqae         25                        10
# 1        lr:hqae         25                        16
# 2        lr:hqae         25                        16
# 3        lr:hqae         25                        16
# 4        lr:hqae         25                        16
# 5        lr:hqae         25                        10
# 6        lr:hqae         25                        16
# 7        lr:hqae         25                        16
# 8        lr:hqae         25                        16
# 9        lr:hqae         25                        16
# 10       lr:hqae         25                        16
# 11       lr:hqae         25                         9
# 12       lr:hqae         25                        16
# 13       lr:hqae         25                        10
# 14       lr:hqae         25                        16
# 15       lr:hqae         25                        10
# 16       lr:hqae         25                        16
# 17       lr:hqae         25                        16
# 18       lr:hqae         25                        10
# 19       lr:hqae         25                        12
# 20       lr:hqae         25                        16
# 21       lr:hqae         25                        16
# 22       lr:hqae         25                        16
# 23       lr:hqae         25                        10
# 24       lr:hqae         25                        16
# 25       lr:hqae         25                        16
# 26       lr:hqae         25                        10
# 27       lr:hqae         25                        16
# 28       lr:hqae         25                        10
# 29       lr:hqae         25                        21
# 30       lr:hqae         25                        21
# 31       lr:hqae         25                        16
# 32       lr:hqae         25                        21
# 33       lr:hqae         25                        21
# 34       lr:hqae         25                        16
# 35       lr:hqae         25                        16
# 36       lr:hqae         25                         9
# 37       lr:hqae         25                        21
# 38       lr:hqae         25                        16
# 39       lr:hqae         25                        21
# 40       lr:hqae         25                        16
# 41       lr:hqae         25                        21
# 42       lr:hqae         25                        12
# 43       lr:hqae         25                        16
#
#     hmm_flagger_window_size                              hmm_flagger_alpha_tsv
# 0                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 1                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 2                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 3                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 4                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 5                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 6                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 7                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 8                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 9                     16000  https://raw.githubusercontent.com/mobinasri/fl...
# 10                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 11                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 12                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 13                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 14                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 15                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 16                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 17                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 18                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 19                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 20                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 21                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 22                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 23                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 24                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 25                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 26                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 27                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 28                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 29                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 30                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 31                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 32                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 33                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 34                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 35                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 36                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 37                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 38                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 39                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 40                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 41                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 42                    16000  https://raw.githubusercontent.com/mobinasri/fl...
# 43                    16000  https://raw.githubusercontent.com/mobinasri/fl...

# %%
print(f"Number of rows for final ONT table: {len(ont_data_table)}")
ont_data_table.head()
# Out:
# Number of rows for final ONT table: 29
#   sample_id                                     hap1_aws_fasta  \
# 0   HG00438  s3://human-pangenomics/working/HPRC/HG00438/as...
# 1   HG00621  s3://human-pangenomics/working/HPRC/HG00621/as...
# 2   HG00673  s3://human-pangenomics/working/HPRC/HG00673/as...
# 3   HG00735  s3://human-pangenomics/working/HPRC/HG00735/as...
# 4   HG00741  s3://human-pangenomics/working/HPRC/HG00741/as...
#
#                                       hap2_aws_fasta  \
# 0  s3://human-pangenomics/working/HPRC/HG00438/as...
# 1  s3://human-pangenomics/working/HPRC/HG00621/as...
# 2  s3://human-pangenomics/working/HPRC/HG00673/as...
# 3  s3://human-pangenomics/working/HPRC/HG00735/as...
# 4  s3://human-pangenomics/working/HPRC/HG00741/as...
#
#                                       hap1_gcp_fasta  \
# 0  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 1  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 2  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 3  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 4  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
#
#                                       hap2_gcp_fasta  \
# 0  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 1  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 2  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 3  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
# 4  gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/w...
#
#                                    hap1_fasta_sha256  \
# 0  a5840157a6995c5fbc08698e52b614fbdf6f57a7245db9...
# 1  bb7d30232f423cabf8d2ebf7443d15aa42bdbfe826424e...
# 2  9650cdb2f090bb94dcb81d0cf9be27e2565de0489dc0d7...
# 3  117cd1556d9b9ea796e29b30db2cb4c6e77e90c9f9b1c0...
# 4  e6121ba9df50914fb0459afd50a9527f7260f1fae8f9ec...
#
#                                    hap2_fasta_sha256  \
# 0  ca307e58dfba48336dd3a05d0ea59b87e3383a5a8c839e...
# 1  1180dda57e968c6f9cf1902981038141f0905b395d44ea...
# 2  0eef54ceca964b5a65c046529e5e433f0cb1a19d6d8a19...
# 3  fdde1ce9c6f27c8d963eef5228ca657c65e89f95ece894...
# 4  a756fc30621e5e887ce5bee0e3a76d4ab9093c846f90ac...
#
#                               cenSatAnnotations_hap1  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                               cenSatAnnotations_hap2  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                   censat_diploid_bed  \
# 0  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                          ...                         mapper_preset kmer_size  \
# 0                        ...                               map-ont        15
# 1                        ...                               map-ont        15
# 2                        ...                               map-ont        15
# 3                        ...                               map-ont        15
# 4                        ...                               map-ont        15
#
#                                           read_files  number_of_read_files  \
# 0  ['s3://human-pangenomics/working/HPRC/HG00438/...                    10
# 1  ['s3://human-pangenomics/working/HPRC/HG00621/...                     5
# 2  ['s3://human-pangenomics/working/HPRC/HG00673/...                     5
# 3  ['s3://human-pangenomics/working/HPRC/HG00735/...                     6
# 4  ['s3://human-pangenomics/working/HPRC/HG00741/...                     5
#
#    total_coverage                                           coverage  \
# 0          136.65  [11.58, 10.73, 12.37, 13.42, 8.81, 16.42, 12.1...
# 1           66.23                  [20.57, 18.99, 13.75, 5.59, 7.33]
# 2           61.89                  [17.46, 15.78, 9.64, 10.33, 8.68]
# 3           66.34            [20.58, 13.91, 5.29, 7.36, 10.58, 8.62]
# 4           81.66                 [21.22, 22.77, 12.59, 13.8, 11.28]
#
#    number_of_cores_per_task sequencing_chemistry  hmm_flagger_window_size  \
# 0                         6                 R941                    16000
# 1                        12                 R941                    16000
# 2                        12                 R941                    16000
# 3                        10                 R941                    16000
# 4                        12                 R941                    16000
#
#                                hmm_flagger_alpha_tsv
# 0  https://raw.githubusercontent.com/mobinasri/fl...
# 1  https://raw.githubusercontent.com/mobinasri/fl...
# 2  https://raw.githubusercontent.com/mobinasri/fl...
# 3  https://raw.githubusercontent.com/mobinasri/fl...
# 4  https://raw.githubusercontent.com/mobinasri/fl...
#
# [5 rows x 25 columns]

# %%
os.makedirs("ont", exist_ok=True)
ont_data_table.to_csv('ont/hmm_flagger_ont_data_table.csv', index=False)

os.makedirs("hifi", exist_ok=True)
hifi_data_table.to_csv('hifi/hmm_flagger_hifi_data_table.csv', index=False)
