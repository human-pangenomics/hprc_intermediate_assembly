# %%
import numpy as np
import pandas as pd
import sys
import os
import re

# %% [markdown]
# ### This notebook:
# - Opens `Year1_assemblies_v2_genbank_ASat.index`, `Year1_assemblies_v2_genbank_HSat.index`, `Year1_assemblies_v2_genbank_Repeat_Masker.index` and `Year1_assemblies_v2_genbank.index `
# - Downloads asat annoations
# - Run `https://raw.githubusercontent.com/fedorrik/HumAS-HMMER_for_AnVIL/refs/heads/main/overlap_filter.py` on all asat bed files to remove overlapping tracks
# - Add the local paths to the new asat annotations to the final table
# - Final table will contain the links to all annotations and assembly fasta files
# - It can be used to create a censat bed file

# %%
os.getcwd()
# Out:
# '/private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat'

# %%
#!wget https://raw.githubusercontent.com/human-pangenomics/HPP_Year1_Assemblies/refs/heads/main/annotation_index/Year1_assemblies_v2_genbank_ASat.index
#!wget https://raw.githubusercontent.com/human-pangenomics/HPP_Year1_Assemblies/refs/heads/main/annotation_index/Year1_assemblies_v2_genbank_HSat.index
#!wget https://raw.githubusercontent.com/human-pangenomics/HPP_Year1_Assemblies/refs/heads/main/annotation_index/Year1_assemblies_v2_genbank_Repeat_Masker.index
#!wget https://raw.githubusercontent.com/human-pangenomics/HPP_Year1_Assemblies/refs/heads/main/assembly_index/Year1_assemblies_v2_genbank.index    
#!wget https://raw.githubusercontent.com/fedorrik/HumAS-HMMER_for_AnVIL/refs/heads/main/overlap_filter.py

# %%
# !ls
# Out:
# asat_overlap_filtered
# empty.bed
# hprc_y1_annotation_table.csv
# hprc_y1_input_mapping.csv
# hprc_y1_samples.txt
# make_censat_hprc_r1_table.ipynb
# overlap_filter.py
# overlap_filter.py.1
# runs_toil_slurm
# run_summarize_asat_sf.sh
# submission_asat_summary_5784206_5784206_4294967294.log
# submissions
# summarize_asat_sf.sh
# tmp
# Year1_assemblies_v2_genbank_ASat.index
# Year1_assemblies_v2_genbank_HSat.index
# Year1_assemblies_v2_genbank.index
# Year1_assemblies_v2_genbank_Repeat_Masker.index

# %%
asat_index_table = pd.read_csv("Year1_assemblies_v2_genbank_ASat.index",sep="\t")
hsat_index_table = pd.read_csv("Year1_assemblies_v2_genbank_HSat.index",sep="\t")
rm_index_table = pd.read_csv("Year1_assemblies_v2_genbank_Repeat_Masker.index",sep="\t")

# %%
asat_index_table["public_link"] = asat_index_table["file_location"].str.replace("s3://","https://s3-us-west-2.amazonaws.com/").str.replace("+","%2B")
hsat_index_table["public_link"] = hsat_index_table["file_location"].str.replace("s3://","https://s3-us-west-2.amazonaws.com/")
rm_index_table["public_link"] = rm_index_table["file_location"].str.replace("s3://","https://s3-us-west-2.amazonaws.com/")

# %%
asat_index_table["sample_id"] = asat_index_table['sample'] + "_" + asat_index_table['haplotype']
print("Number of rows (ASat):", len(asat_index_table))
asat_index_table.head()
# Out:
# Number of rows (ASat): 94
#     sample haplotype                                      file_location  \
# 0    HG002  maternal  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 1    HG002  paternal  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 2  HG00438  maternal  s3://human-pangenomics/working/HPRC/HG00438/as...
# 3  HG00438  paternal  s3://human-pangenomics/working/HPRC/HG00438/as...
# 4    HG005  maternal  s3://human-pangenomics/working/HPRC_PLUS/HG005...
#
#                                          public_link         sample_id
# 0  https://s3-us-west-2.amazonaws.com/human-pange...    HG002_maternal
# 1  https://s3-us-west-2.amazonaws.com/human-pange...    HG002_paternal
# 2  https://s3-us-west-2.amazonaws.com/human-pange...  HG00438_maternal
# 3  https://s3-us-west-2.amazonaws.com/human-pange...  HG00438_paternal
# 4  https://s3-us-west-2.amazonaws.com/human-pange...    HG005_maternal

# %%
hsat_index_table["sample_id"] = hsat_index_table['sample'] + "_" + hsat_index_table['haplotype']
print("Number of rows (HSat):", len(hsat_index_table))
hsat_index_table.head()
# Out:
# Number of rows (HSat): 94
#     sample haplotype                                      file_location  \
# 0    HG002  maternal  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 1    HG002  paternal  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 2  HG00438  maternal  s3://human-pangenomics/working/HPRC/HG00438/as...
# 3  HG00438  paternal  s3://human-pangenomics/working/HPRC/HG00438/as...
# 4    HG005  maternal  s3://human-pangenomics/working/HPRC_PLUS/HG005...
#
#                                          public_link         sample_id
# 0  https://s3-us-west-2.amazonaws.com/human-pange...    HG002_maternal
# 1  https://s3-us-west-2.amazonaws.com/human-pange...    HG002_paternal
# 2  https://s3-us-west-2.amazonaws.com/human-pange...  HG00438_maternal
# 3  https://s3-us-west-2.amazonaws.com/human-pange...  HG00438_paternal
# 4  https://s3-us-west-2.amazonaws.com/human-pange...    HG005_maternal

# %%
rm_index_table["sample_id"] = rm_index_table['sample'] + "_" + rm_index_table['haplotype']
print("Number of rows (RM):", len(rm_index_table))
rm_index_table.head()
# Out:
# Number of rows (RM): 94
#     sample haplotype                                      file_location  \
# 0    HG002  maternal  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 1    HG002  paternal  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 2  HG00438  maternal  s3://human-pangenomics/working/HPRC/HG00438/as...
# 3  HG00438  paternal  s3://human-pangenomics/working/HPRC/HG00438/as...
# 4    HG005  maternal  s3://human-pangenomics/working/HPRC_PLUS/HG005...
#
#                                          public_link         sample_id
# 0  https://s3-us-west-2.amazonaws.com/human-pange...    HG002_maternal
# 1  https://s3-us-west-2.amazonaws.com/human-pange...    HG002_paternal
# 2  https://s3-us-west-2.amazonaws.com/human-pange...  HG00438_maternal
# 3  https://s3-us-west-2.amazonaws.com/human-pange...  HG00438_paternal
# 4  https://s3-us-west-2.amazonaws.com/human-pange...    HG005_maternal

# %%
#!rm -rf asat_overlap_filtered && mkdir -p asat_overlap_filtered
asat_paths_overlap_filtered = []
for asat_link in asat_index_table["public_link"]:
    in_filename = os.path.basename(asat_link).replace("%2B","+")
    out_filename = in_filename.replace(".bed", ".overlap_filtered.bed")
    # download asat bed file
    #!cd asat_overlap_filtered && wget {asat_link}
    # run overlap_filter script
    #!python3 overlap_filter.py asat_overlap_filtered/{in_filename} >  asat_overlap_filtered/{out_filename}
    # remove original bed file
    #!rm -rf asat_overlap_filtered/{in_filename}
    # append new file path to the list
    asat_paths_overlap_filtered.append(f'{os.getcwd()}/asat_overlap_filtered/{out_filename}')
    print(asat_paths_overlap_filtered[-1])
# make a new column for overlap-filtered bed files
asat_index_table["overlap_filtered_path_asat"] = asat_paths_overlap_filtered
# Out:
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG002-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG002-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00438-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00438-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG005-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG005-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00621-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00621-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00673-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00673-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00733-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00733-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00735-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00735-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00741-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG00741-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01071-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01071-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01106-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01106-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01109-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01109-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01123-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01123-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01175-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01175-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01243-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01243-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01258-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01258-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01358-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01358-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01361-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01361-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01891-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01891-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01928-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01928-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01952-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01952-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01978-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG01978-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02055-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02055-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02080-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02080-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02109-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02109-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02145-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02145-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02148-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02148-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02257-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02257-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02486-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02486-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02559-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02559-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02572-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02572-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02622-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02622-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02630-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02630-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02717-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02717-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02723-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02723-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02818-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02818-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02886-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG02886-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03098-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03098-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03453-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03453-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03486-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03486-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03492-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03492-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03516-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03516-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03540-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03540-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03579-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-HG03579-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA18906-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA18906-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA19240-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA19240-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA20129-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA20129-paternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA21309-maternal.overlap_filtered.bed
# /private/groups/hprc/qc_hmm_flagger/hprc_intermediate_assembly/assembly_qc/hprc_r1/censat/asat_overlap_filtered/AS-HOR+SF-vs-NA21309-paternal.overlap_filtered.bed

# %%
annotation_table = asat_index_table.merge(hsat_index_table, on="sample_id", suffixes = ("_asat", "_hsat"))
rm_index_table = rm_index_table.add_suffix("_rm")
rm_index_table = rm_index_table.rename(columns={"sample_id_rm": "sample_id"})
annotation_table = rm_index_table.merge(annotation_table, on="sample_id")
annotation_table = annotation_table[["sample_id", "overlap_filtered_path_asat","public_link_asat", "public_link_hsat", "public_link_rm"]]
annotation_table
# Out:
#            sample_id                         overlap_filtered_path_asat  \
# 0     HG002_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1     HG002_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2   HG00438_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3   HG00438_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4     HG005_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 5     HG005_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 6   HG00621_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 7   HG00621_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 8   HG00673_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 9   HG00673_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 10  HG00733_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 11  HG00733_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 12  HG00735_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 13  HG00735_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 14  HG00741_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 15  HG00741_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 16  HG01071_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 17  HG01071_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 18  HG01106_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 19  HG01106_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 20  HG01109_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 21  HG01109_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 22  HG01123_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 23  HG01123_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 24  HG01175_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 25  HG01175_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 26  HG01243_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 27  HG01243_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 28  HG01258_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 29  HG01258_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# ..               ...                                                ...
# 64  HG02717_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 65  HG02717_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 66  HG02723_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 67  HG02723_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 68  HG02818_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 69  HG02818_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 70  HG02886_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 71  HG02886_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 72  HG03098_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 73  HG03098_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 74  HG03453_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 75  HG03453_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 76  HG03486_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 77  HG03486_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 78  HG03492_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 79  HG03492_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 80  HG03516_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 81  HG03516_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 82  HG03540_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 83  HG03540_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 84  HG03579_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 85  HG03579_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 86  NA18906_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 87  NA18906_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 88  NA19240_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 89  NA19240_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 90  NA20129_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 91  NA20129_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 92  NA21309_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 93  NA21309_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                      public_link_asat  \
# 0   https://s3-us-west-2.amazonaws.com/human-pange...
# 1   https://s3-us-west-2.amazonaws.com/human-pange...
# 2   https://s3-us-west-2.amazonaws.com/human-pange...
# 3   https://s3-us-west-2.amazonaws.com/human-pange...
# 4   https://s3-us-west-2.amazonaws.com/human-pange...
# 5   https://s3-us-west-2.amazonaws.com/human-pange...
# 6   https://s3-us-west-2.amazonaws.com/human-pange...
# 7   https://s3-us-west-2.amazonaws.com/human-pange...
# 8   https://s3-us-west-2.amazonaws.com/human-pange...
# 9   https://s3-us-west-2.amazonaws.com/human-pange...
# 10  https://s3-us-west-2.amazonaws.com/human-pange...
# 11  https://s3-us-west-2.amazonaws.com/human-pange...
# 12  https://s3-us-west-2.amazonaws.com/human-pange...
# 13  https://s3-us-west-2.amazonaws.com/human-pange...
# 14  https://s3-us-west-2.amazonaws.com/human-pange...
# 15  https://s3-us-west-2.amazonaws.com/human-pange...
# 16  https://s3-us-west-2.amazonaws.com/human-pange...
# 17  https://s3-us-west-2.amazonaws.com/human-pange...
# 18  https://s3-us-west-2.amazonaws.com/human-pange...
# 19  https://s3-us-west-2.amazonaws.com/human-pange...
# 20  https://s3-us-west-2.amazonaws.com/human-pange...
# 21  https://s3-us-west-2.amazonaws.com/human-pange...
# 22  https://s3-us-west-2.amazonaws.com/human-pange...
# 23  https://s3-us-west-2.amazonaws.com/human-pange...
# 24  https://s3-us-west-2.amazonaws.com/human-pange...
# 25  https://s3-us-west-2.amazonaws.com/human-pange...
# 26  https://s3-us-west-2.amazonaws.com/human-pange...
# 27  https://s3-us-west-2.amazonaws.com/human-pange...
# 28  https://s3-us-west-2.amazonaws.com/human-pange...
# 29  https://s3-us-west-2.amazonaws.com/human-pange...
# ..                                                ...
# 64  https://s3-us-west-2.amazonaws.com/human-pange...
# 65  https://s3-us-west-2.amazonaws.com/human-pange...
# 66  https://s3-us-west-2.amazonaws.com/human-pange...
# 67  https://s3-us-west-2.amazonaws.com/human-pange...
# 68  https://s3-us-west-2.amazonaws.com/human-pange...
# 69  https://s3-us-west-2.amazonaws.com/human-pange...
# 70  https://s3-us-west-2.amazonaws.com/human-pange...
# 71  https://s3-us-west-2.amazonaws.com/human-pange...
# 72  https://s3-us-west-2.amazonaws.com/human-pange...
# 73  https://s3-us-west-2.amazonaws.com/human-pange...
# 74  https://s3-us-west-2.amazonaws.com/human-pange...
# 75  https://s3-us-west-2.amazonaws.com/human-pange...
# 76  https://s3-us-west-2.amazonaws.com/human-pange...
# 77  https://s3-us-west-2.amazonaws.com/human-pange...
# 78  https://s3-us-west-2.amazonaws.com/human-pange...
# 79  https://s3-us-west-2.amazonaws.com/human-pange...
# 80  https://s3-us-west-2.amazonaws.com/human-pange...
# 81  https://s3-us-west-2.amazonaws.com/human-pange...
# 82  https://s3-us-west-2.amazonaws.com/human-pange...
# 83  https://s3-us-west-2.amazonaws.com/human-pange...
# 84  https://s3-us-west-2.amazonaws.com/human-pange...
# 85  https://s3-us-west-2.amazonaws.com/human-pange...
# 86  https://s3-us-west-2.amazonaws.com/human-pange...
# 87  https://s3-us-west-2.amazonaws.com/human-pange...
# 88  https://s3-us-west-2.amazonaws.com/human-pange...
# 89  https://s3-us-west-2.amazonaws.com/human-pange...
# 90  https://s3-us-west-2.amazonaws.com/human-pange...
# 91  https://s3-us-west-2.amazonaws.com/human-pange...
# 92  https://s3-us-west-2.amazonaws.com/human-pange...
# 93  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                      public_link_hsat  \
# 0   https://s3-us-west-2.amazonaws.com/human-pange...
# 1   https://s3-us-west-2.amazonaws.com/human-pange...
# 2   https://s3-us-west-2.amazonaws.com/human-pange...
# 3   https://s3-us-west-2.amazonaws.com/human-pange...
# 4   https://s3-us-west-2.amazonaws.com/human-pange...
# 5   https://s3-us-west-2.amazonaws.com/human-pange...
# 6   https://s3-us-west-2.amazonaws.com/human-pange...
# 7   https://s3-us-west-2.amazonaws.com/human-pange...
# 8   https://s3-us-west-2.amazonaws.com/human-pange...
# 9   https://s3-us-west-2.amazonaws.com/human-pange...
# 10  https://s3-us-west-2.amazonaws.com/human-pange...
# 11  https://s3-us-west-2.amazonaws.com/human-pange...
# 12  https://s3-us-west-2.amazonaws.com/human-pange...
# 13  https://s3-us-west-2.amazonaws.com/human-pange...
# 14  https://s3-us-west-2.amazonaws.com/human-pange...
# 15  https://s3-us-west-2.amazonaws.com/human-pange...
# 16  https://s3-us-west-2.amazonaws.com/human-pange...
# 17  https://s3-us-west-2.amazonaws.com/human-pange...
# 18  https://s3-us-west-2.amazonaws.com/human-pange...
# 19  https://s3-us-west-2.amazonaws.com/human-pange...
# 20  https://s3-us-west-2.amazonaws.com/human-pange...
# 21  https://s3-us-west-2.amazonaws.com/human-pange...
# 22  https://s3-us-west-2.amazonaws.com/human-pange...
# 23  https://s3-us-west-2.amazonaws.com/human-pange...
# 24  https://s3-us-west-2.amazonaws.com/human-pange...
# 25  https://s3-us-west-2.amazonaws.com/human-pange...
# 26  https://s3-us-west-2.amazonaws.com/human-pange...
# 27  https://s3-us-west-2.amazonaws.com/human-pange...
# 28  https://s3-us-west-2.amazonaws.com/human-pange...
# 29  https://s3-us-west-2.amazonaws.com/human-pange...
# ..                                                ...
# 64  https://s3-us-west-2.amazonaws.com/human-pange...
# 65  https://s3-us-west-2.amazonaws.com/human-pange...
# 66  https://s3-us-west-2.amazonaws.com/human-pange...
# 67  https://s3-us-west-2.amazonaws.com/human-pange...
# 68  https://s3-us-west-2.amazonaws.com/human-pange...
# 69  https://s3-us-west-2.amazonaws.com/human-pange...
# 70  https://s3-us-west-2.amazonaws.com/human-pange...
# 71  https://s3-us-west-2.amazonaws.com/human-pange...
# 72  https://s3-us-west-2.amazonaws.com/human-pange...
# 73  https://s3-us-west-2.amazonaws.com/human-pange...
# 74  https://s3-us-west-2.amazonaws.com/human-pange...
# 75  https://s3-us-west-2.amazonaws.com/human-pange...
# 76  https://s3-us-west-2.amazonaws.com/human-pange...
# 77  https://s3-us-west-2.amazonaws.com/human-pange...
# 78  https://s3-us-west-2.amazonaws.com/human-pange...
# 79  https://s3-us-west-2.amazonaws.com/human-pange...
# 80  https://s3-us-west-2.amazonaws.com/human-pange...
# 81  https://s3-us-west-2.amazonaws.com/human-pange...
# 82  https://s3-us-west-2.amazonaws.com/human-pange...
# 83  https://s3-us-west-2.amazonaws.com/human-pange...
# 84  https://s3-us-west-2.amazonaws.com/human-pange...
# 85  https://s3-us-west-2.amazonaws.com/human-pange...
# 86  https://s3-us-west-2.amazonaws.com/human-pange...
# 87  https://s3-us-west-2.amazonaws.com/human-pange...
# 88  https://s3-us-west-2.amazonaws.com/human-pange...
# 89  https://s3-us-west-2.amazonaws.com/human-pange...
# 90  https://s3-us-west-2.amazonaws.com/human-pange...
# 91  https://s3-us-west-2.amazonaws.com/human-pange...
# 92  https://s3-us-west-2.amazonaws.com/human-pange...
# 93  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                        public_link_rm
# 0   https://s3-us-west-2.amazonaws.com/human-pange...
# 1   https://s3-us-west-2.amazonaws.com/human-pange...
# 2   https://s3-us-west-2.amazonaws.com/human-pange...
# 3   https://s3-us-west-2.amazonaws.com/human-pange...
# 4   https://s3-us-west-2.amazonaws.com/human-pange...
# 5   https://s3-us-west-2.amazonaws.com/human-pange...
# 6   https://s3-us-west-2.amazonaws.com/human-pange...
# 7   https://s3-us-west-2.amazonaws.com/human-pange...
# 8   https://s3-us-west-2.amazonaws.com/human-pange...
# 9   https://s3-us-west-2.amazonaws.com/human-pange...
# 10  https://s3-us-west-2.amazonaws.com/human-pange...
# 11  https://s3-us-west-2.amazonaws.com/human-pange...
# 12  https://s3-us-west-2.amazonaws.com/human-pange...
# 13  https://s3-us-west-2.amazonaws.com/human-pange...
# 14  https://s3-us-west-2.amazonaws.com/human-pange...
# 15  https://s3-us-west-2.amazonaws.com/human-pange...
# 16  https://s3-us-west-2.amazonaws.com/human-pange...
# 17  https://s3-us-west-2.amazonaws.com/human-pange...
# 18  https://s3-us-west-2.amazonaws.com/human-pange...
# 19  https://s3-us-west-2.amazonaws.com/human-pange...
# 20  https://s3-us-west-2.amazonaws.com/human-pange...
# 21  https://s3-us-west-2.amazonaws.com/human-pange...
# 22  https://s3-us-west-2.amazonaws.com/human-pange...
# 23  https://s3-us-west-2.amazonaws.com/human-pange...
# 24  https://s3-us-west-2.amazonaws.com/human-pange...
# 25  https://s3-us-west-2.amazonaws.com/human-pange...
# 26  https://s3-us-west-2.amazonaws.com/human-pange...
# 27  https://s3-us-west-2.amazonaws.com/human-pange...
# 28  https://s3-us-west-2.amazonaws.com/human-pange...
# 29  https://s3-us-west-2.amazonaws.com/human-pange...
# ..                                                ...
# 64  https://s3-us-west-2.amazonaws.com/human-pange...
# 65  https://s3-us-west-2.amazonaws.com/human-pange...
# 66  https://s3-us-west-2.amazonaws.com/human-pange...
# 67  https://s3-us-west-2.amazonaws.com/human-pange...
# 68  https://s3-us-west-2.amazonaws.com/human-pange...
# 69  https://s3-us-west-2.amazonaws.com/human-pange...
# 70  https://s3-us-west-2.amazonaws.com/human-pange...
# 71  https://s3-us-west-2.amazonaws.com/human-pange...
# 72  https://s3-us-west-2.amazonaws.com/human-pange...
# 73  https://s3-us-west-2.amazonaws.com/human-pange...
# 74  https://s3-us-west-2.amazonaws.com/human-pange...
# 75  https://s3-us-west-2.amazonaws.com/human-pange...
# 76  https://s3-us-west-2.amazonaws.com/human-pange...
# 77  https://s3-us-west-2.amazonaws.com/human-pange...
# 78  https://s3-us-west-2.amazonaws.com/human-pange...
# 79  https://s3-us-west-2.amazonaws.com/human-pange...
# 80  https://s3-us-west-2.amazonaws.com/human-pange...
# 81  https://s3-us-west-2.amazonaws.com/human-pange...
# 82  https://s3-us-west-2.amazonaws.com/human-pange...
# 83  https://s3-us-west-2.amazonaws.com/human-pange...
# 84  https://s3-us-west-2.amazonaws.com/human-pange...
# 85  https://s3-us-west-2.amazonaws.com/human-pange...
# 86  https://s3-us-west-2.amazonaws.com/human-pange...
# 87  https://s3-us-west-2.amazonaws.com/human-pange...
# 88  https://s3-us-west-2.amazonaws.com/human-pange...
# 89  https://s3-us-west-2.amazonaws.com/human-pange...
# 90  https://s3-us-west-2.amazonaws.com/human-pange...
# 91  https://s3-us-west-2.amazonaws.com/human-pange...
# 92  https://s3-us-west-2.amazonaws.com/human-pange...
# 93  https://s3-us-west-2.amazonaws.com/human-pange...
#
# [94 rows x 5 columns]

# %%
asm_index_table = pd.read_csv("Year1_assemblies_v2_genbank.index",sep="\t")
asm_index_table = pd.melt(asm_index_table, 
                          id_vars=["sample"], 
                          value_vars=["hap1_aws_fasta", "hap2_aws_fasta"],
                          var_name="haplotype",
                          value_name="aws_fasta")
asm_index_table["sample_id"] = asm_index_table["sample"] + "_" +asm_index_table["haplotype"].str.extract(r'(hap\d)')[0]
asm_index_table["sample_id"] = asm_index_table["sample_id"].str.replace("_hap1", "_paternal", regex=False)
asm_index_table["sample_id"] = asm_index_table["sample_id"].str.replace("_hap2", "_maternal", regex=False)
asm_index_table = asm_index_table.drop(columns=["sample", "haplotype"])
asm_index_table
# Out:
#                                             aws_fasta  \
# 0   s3://human-pangenomics/working/HPRC/HG00438/as...
# 1   s3://human-pangenomics/working/HPRC/HG00621/as...
# 2   s3://human-pangenomics/working/HPRC/HG00673/as...
# 3   s3://human-pangenomics/working/HPRC/HG00735/as...
# 4   s3://human-pangenomics/working/HPRC/HG00741/as...
# 5   s3://human-pangenomics/working/HPRC/HG01071/as...
# 6   s3://human-pangenomics/working/HPRC/HG01106/as...
# 7   s3://human-pangenomics/working/HPRC/HG01123/as...
# 8   s3://human-pangenomics/working/HPRC/HG01175/as...
# 9   s3://human-pangenomics/working/HPRC/HG01258/as...
# 10  s3://human-pangenomics/working/HPRC/HG01358/as...
# 11  s3://human-pangenomics/working/HPRC/HG01361/as...
# 12  s3://human-pangenomics/working/HPRC/HG01891/as...
# 13  s3://human-pangenomics/working/HPRC/HG01928/as...
# 14  s3://human-pangenomics/working/HPRC/HG01952/as...
# 15  s3://human-pangenomics/working/HPRC/HG01978/as...
# 16  s3://human-pangenomics/working/HPRC/HG02148/as...
# 17  s3://human-pangenomics/working/HPRC/HG02257/as...
# 18  s3://human-pangenomics/working/HPRC/HG02486/as...
# 19  s3://human-pangenomics/working/HPRC/HG02559/as...
# 20  s3://human-pangenomics/working/HPRC/HG02572/as...
# 21  s3://human-pangenomics/working/HPRC/HG02622/as...
# 22  s3://human-pangenomics/working/HPRC/HG02630/as...
# 23  s3://human-pangenomics/working/HPRC/HG02717/as...
# 24  s3://human-pangenomics/working/HPRC/HG02886/as...
# 25  s3://human-pangenomics/working/HPRC/HG03453/as...
# 26  s3://human-pangenomics/working/HPRC/HG03516/as...
# 27  s3://human-pangenomics/working/HPRC/HG03540/as...
# 28  s3://human-pangenomics/working/HPRC/HG03579/as...
# 29  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# ..                                                ...
# 68  s3://human-pangenomics/working/HPRC/HG02559/as...
# 69  s3://human-pangenomics/working/HPRC/HG02572/as...
# 70  s3://human-pangenomics/working/HPRC/HG02622/as...
# 71  s3://human-pangenomics/working/HPRC/HG02630/as...
# 72  s3://human-pangenomics/working/HPRC/HG02717/as...
# 73  s3://human-pangenomics/working/HPRC/HG02886/as...
# 74  s3://human-pangenomics/working/HPRC/HG03453/as...
# 75  s3://human-pangenomics/working/HPRC/HG03516/as...
# 76  s3://human-pangenomics/working/HPRC/HG03540/as...
# 77  s3://human-pangenomics/working/HPRC/HG03579/as...
# 78  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 79  s3://human-pangenomics/working/HPRC_PLUS/HG005...
# 80  s3://human-pangenomics/working/HPRC_PLUS/HG007...
# 81  s3://human-pangenomics/working/HPRC_PLUS/HG011...
# 82  s3://human-pangenomics/working/HPRC_PLUS/HG012...
# 83  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 84  s3://human-pangenomics/working/HPRC_PLUS/HG020...
# 85  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 86  s3://human-pangenomics/working/HPRC_PLUS/HG021...
# 87  s3://human-pangenomics/working/HPRC_PLUS/HG027...
# 88  s3://human-pangenomics/working/HPRC_PLUS/HG028...
# 89  s3://human-pangenomics/working/HPRC_PLUS/HG030...
# 90  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 91  s3://human-pangenomics/working/HPRC_PLUS/HG034...
# 92  s3://human-pangenomics/working/HPRC_PLUS/NA189...
# 93  s3://human-pangenomics/working/HPRC_PLUS/NA192...
# 94  s3://human-pangenomics/working/HPRC_PLUS/NA201...
# 95  s3://human-pangenomics/working/HPRC_PLUS/NA213...
# 96                                                NaN
# 97                                                NaN
#
#                               sample_id
# 0                      HG00438_paternal
# 1                      HG00621_paternal
# 2                      HG00673_paternal
# 3                      HG00735_paternal
# 4                      HG00741_paternal
# 5                      HG01071_paternal
# 6                      HG01106_paternal
# 7                      HG01123_paternal
# 8                      HG01175_paternal
# 9                      HG01258_paternal
# 10                     HG01358_paternal
# 11                     HG01361_paternal
# 12                     HG01891_paternal
# 13                     HG01928_paternal
# 14                     HG01952_paternal
# 15                     HG01978_paternal
# 16                     HG02148_paternal
# 17                     HG02257_paternal
# 18                     HG02486_paternal
# 19                     HG02559_paternal
# 20                     HG02572_paternal
# 21                     HG02622_paternal
# 22                     HG02630_paternal
# 23                     HG02717_paternal
# 24                     HG02886_paternal
# 25                     HG03453_paternal
# 26                     HG03516_paternal
# 27                     HG03540_paternal
# 28                     HG03579_paternal
# 29                       HG002_paternal
# ..                                  ...
# 68                     HG02559_maternal
# 69                     HG02572_maternal
# 70                     HG02622_maternal
# 71                     HG02630_maternal
# 72                     HG02717_maternal
# 73                     HG02886_maternal
# 74                     HG03453_maternal
# 75                     HG03516_maternal
# 76                     HG03540_maternal
# 77                     HG03579_maternal
# 78                       HG002_maternal
# 79                       HG005_maternal
# 80                     HG00733_maternal
# 81                     HG01109_maternal
# 82                     HG01243_maternal
# 83                     HG02055_maternal
# 84                     HG02080_maternal
# 85                     HG02109_maternal
# 86                     HG02145_maternal
# 87                     HG02723_maternal
# 88                     HG02818_maternal
# 89                     HG03098_maternal
# 90                     HG03486_maternal
# 91                     HG03492_maternal
# 92                     NA18906_maternal
# 93                     NA19240_maternal
# 94                     NA20129_maternal
# 95                     NA21309_maternal
# 96                  CHM13_v1.1_maternal
# 97  GRCh38_no_alt_analysis_set_maternal
#
# [98 rows x 2 columns]

# %%
annotation_table = annotation_table.merge(asm_index_table, on="sample_id")
print("Number of rows in final table: ", len(annotation_table))
annotation_table.head()
# Out:
# Number of rows in final table:  94
#           sample_id                         overlap_filtered_path_asat  \
# 0    HG002_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 1    HG002_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 2  HG00438_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 3  HG00438_paternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
# 4    HG005_maternal  /private/groups/hprc/qc_hmm_flagger/hprc_inter...
#
#                                     public_link_asat  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                     public_link_hsat  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                       public_link_rm  \
# 0  https://s3-us-west-2.amazonaws.com/human-pange...
# 1  https://s3-us-west-2.amazonaws.com/human-pange...
# 2  https://s3-us-west-2.amazonaws.com/human-pange...
# 3  https://s3-us-west-2.amazonaws.com/human-pange...
# 4  https://s3-us-west-2.amazonaws.com/human-pange...
#
#                                            aws_fasta
# 0  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 1  s3://human-pangenomics/working/HPRC_PLUS/HG002...
# 2  s3://human-pangenomics/working/HPRC/HG00438/as...
# 3  s3://human-pangenomics/working/HPRC/HG00438/as...
# 4  s3://human-pangenomics/working/HPRC_PLUS/HG005...

# %%
annotation_table.to_csv('hprc_y1_annotation_table.csv', index=False)
